# %%
import numpy as np
import pandas as pd
import os
from numpy import save
from numpy import load
import matplotlib.pyplot as plt
from numpy import argmax

from tensorflow import keras
from keras import models
from keras.models import Sequential
from keras.layers import LSTM, TimeDistributed, RepeatVector, Dense

import librosa
import torch
from transformers import Wav2Vec2ForCTC, Wav2Vec2Tokenizer

import IPython.display as display

# Importing Wav2Vec pretrained model

tokenizer = Wav2Vec2Tokenizer.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")
# Out:
# 2022-09-15 00:51:20.140096: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-15 00:51:20.200123: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-09-15 00:51:20.216335: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-15 00:51:20.483341: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/digit/miniconda3/envs/keras/lib/
# 2022-09-15 00:51:20.483376: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/digit/miniconda3/envs/keras/lib/
# 2022-09-15 00:51:20.483379: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Wav2Vec2CTCTokenizer'.
# The class this function is called from is 'Wav2Vec2Tokenizer'.
# /home/digit/miniconda3/envs/keras/lib/python3.9/site-packages/transformers/models/wav2vec2/tokenization_wav2vec2.py:754: FutureWarning: The class `Wav2Vec2Tokenizer` is deprecated and will be removed in version 5 of Transformers. Please use `Wav2Vec2Processor` or `Wav2Vec2CTCTokenizer` instead.
#   warnings.warn(
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # MODEL TRAINED WITHOUT MOVE PEN: TEST ON MOVE PEN

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_01_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_01_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0                             1
# 0     MOVE THE FORK TO THE RIGHT    MOVE THE FORK TO THE RIGHT
# 1               ROTATE THE KNIFE           WROT TAKE THE PHINE
# 2                THIS IS A SPOON                 THIS IS A PEN
# 3     MOVE THE FORK TO THE RIGHT     MOVE THE FORK TO THE LEFT
# 4            MOVE THE SPOON DOWN    MOVE THE SPOON TO THE LEFT
# 5                 HIS IS A SPURN               THIS IS A PHONE
# 6     MOVED THE FORK TO THE LEFT      MOVE THE PEN TO THE LEFT
# 7               ROTATE THE SPOON              RO TAKE THE FORK
# 8                    LUSA PHONAP   MOVE THE PHONE TO THE RIGHT
# 9                THIS IS A SPOON               THIS IS A SPOON
# 10   MOVE THE PHONE TO THE RIGHT               MOVE THE PEN UP
# 11                THIS IS A FORK                THIS IS A FORK
# 12    MOVE THE FORK TO THE RIGHT    MOVE THE FORK TO THE RIGHT
# 13               THIS IS A PHONE                THIS IS A FORK
# 14    MOVE THE PHONE TO THE LEFT             MOVE THE SPOON UP
# 15               THIS IS A SPOON                TIS IS A SPOON
# 16             MOVE THE SPOON UP              OVE THE SPOON UP
# 17               THIS IS A PHONE                THIS IS A FORK
# 18               THIS IS A SPOON               THIS IS A SPOON
# 19               THIS IS A FORRK           MOVE THE SPOON DOWN
# 20      OVED THE PAN TO THE LEFT   MOVE THE PHONE TO THE RIGHT
# 21                THIS IS A FORK                THIS IS A FOWN
# 22               THIS IS A KNIFE     MOVE THE PAN TO THE RIGHT
# 23                 THIS IS A PEN                HIS IS A KNIFE
# 24                MO THE FORECOP            MOVE THE FORK DOWN
# 25              ROTATH THE KNIFE           WROT TAKE THE PHINE
# 26     MOVES THE PEN TO THE LEFT            MOVHE THE KNIFE AP
# 27              MOVED THE PHONAP   MOVE THE PHONE TO THE RIGHT
# 28               OO THE FORE COP             OVE THE FORK DOWN
# 29               THIS IS A SPOON               THIS IS A SPOON
# 30               ROTATE THE FAWN              ROTATE THE SPOON
# 31  MOVED THE SPOON TO THE RIGHT             MOVE THE SPOON UP
# 32             MOVE THE SPOON UP  MOOTH THE PHONE TO THE RIGHT
# 33               THIS IS A PHONE               THIS IS A PHONE
# 34                ROTATE THE PEN              ROTATE KHE UPOEN
# 35                THIS IS A FORK     MOVE THE PEN TO THE RIGHT
# 36                THIS IS A FAWN               THIS IS A PHONE
# 37                 THIS IS A PEN               THIS IS A PHONE
# 38               THIS IS A SPOON               THIS IS A SPOON
# 39              MOO THE KNIFE UP           MOVE THE PHONE DOWN
# 40                 THIS IS A PEN                 THIS IS A PEN
# 41    MOVED THE FORK TO THE LEFT      OVE THE FORK TO THE LEFT
# 42              MOVE THE FOREGAP    MOVE THE FORK TO THE RIGHT
# 43    MOVE THE KNIFE TO THE LEFT            MOVHE THE KNIFE AP
# 44               THIS IS A PHONE               THIS IS A PHONE
# 45               THIS IS A KNIFE               THIS IS A KNIFE
# 46               THIS IS A PHONE                THIS IS A FORK
# 47               THIS IS A KNIFE          MOOVE THE KNIFE DOWN
# 48                THIS IS A FORK               THIS IS A SPOON
# 49    MOVE THE FALL TO THE RIGHT             OV THE SPOON DOWN
# 50             MOVE THE SPOON UP   MOVED THE SPOON TO THE LEFT
# 51                THIS IS A FORK                THIS IS A FORK
# 52                THIS IS A FORK               THIS IS A KNIFE
# 53               THIS IS A SPERN           MOVE THE SPOON DOWN
# 54                MOVE THE KNIFE    MOVE THE KNIFE TO THE LEFT
# 55               THIS IS A PHONE                 THIS IS A PAN
# 56                 THIS IS A PEN                 IS IS A SPOON
# 57               THIS IS A PHONE          ROTATHE TE THE SPOON
# 58               ROTADE THE FORK               ROTATE THE FORK
# 59               THIS IS A KNIFE                 THIS IS A PEN
# 60                THIS IS A FOWN                THIS IS A FORK
# 61               THIS IS A SPOON   MOVED THE SPOON TO THE LEFT
# 62               THIS IS A KNIFE                 HIS IS A FORK
# 63               THIS IS A SPOON           MOVE THE SPOON DOWN
# 64               THIS IS A SPOON           MOVE THE SPOON DOWN
# 65               THIS IS A SPERN           MOVE THE SPOON DOWN
# 66               THIS IS A SPOON               THIS IS A KNIFE
# 67                    LUCE PANAP                  IS IS A FARM
# 68             MOVED THE FORECUP              MOVE THE FORECUP
# 69                 THIS IS A PEN                 THIS IS A PEN
# 70                    LUCE PANAP               MOVE THE PENNOB
# 71    MOVED THE FORK TO THE LEFT      OVE THE FORK TO THE LEFT
# 72    MOVHE THE FORK TO THE LEFT   MOVE THE SPOON TO THE RIGHT
# 73   MOVE THE KNIFE TO THE RIGHT            MOOVE THE KNIFE UP
# 74               THIS IS A KNIFE               THIS IS A PHONE
# 75             MOVE THE PEN DOWN             MOVE THE PEN DOWN
# 76     MOVE THE FORK TO THE LEFT     MOVE THE FORK TO THE LEFT
# 77               THIS IS A PHONE    MOVE THE SPOON TO THE LEFT
# 78                THIS IS A FORK               THIS IS A SPOON
# 79    MOVE THE KNIFE TO THE LEFT   MOVE THE KNIFE TO THE RIGHT
# 80               MOVE THE PENDOW                 O THE FORECUP
# 81               THIS IS A PHONE               THIS IS A PHONE
# 82             RO TAKE THE SPOON              RO TAKE THE FORK
# 83   MOVE THE KNIFE TO THE RIGHT                  MOE THE NIFA
# 84               MOE THE PENKNOB   MOVE THE PHONE TO THE RIGHT
# 85              WROAKE THE KNIFE             MOVE THE KNIFE UP
# 86               THIS IS A PHONE                THIS IS A FOWN
# 87        O THE PAN TO THE RIGHT           MOVE THE PHONE DOWN
# 88                 THIS IS A TAN                 THIS IS A TAN
# 89                THIS IS A FOWN                THIS IS A FORK
# 90              MOVED THE PHONUP   MOVE THE PHONE TO THE RIGHT
# 91             MOVE THE SPOON UP             MOVE THE SPOON UP
# 92               THIS IS A SPURN               THIS IS A SPOON
# 93               THIS IS A SPOON               THIS IS A SPOON
# 94                      MUCIFONA     MOVE THE SPON TO THE LEFT
# 95                THIS IS A FORK               ROTATE THE FORT
# 96               THIS IS A KNIFE               THIS IS A KNIFE
# 97                THIS IS A FORK               THIS IS A KNIFE
# 98               THIS IS A KNIFE               THIS IS A KNIFE
# 99                THIS IS A FORK               THIS IS A PHONE

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_02_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_02_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_03_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_03_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0                             1
# 0     MOVE THE FORK TO THE RIGHT    MOVE THE FORK TO THE RIGHT
# 1               ROTATE THE KNIFE              OVE THE KNIFE UP
# 2                THIS IS A SPOON               THIS IS A SPOON
# 3     MOVE THE FORK TO THE RIGHT    MOVE THE FORK TO THE RIGHT
# 4            MOVE THE SPOON DOWN           MOVE THE SPOON DOWN
# 5                 HIS IS A SPURN               THIS IS A SPURN
# 6     MOVED THE FORK TO THE LEFT              MOVE THE FORECOP
# 7               ROTATE THE SPOON              ROTATE THE SPOON
# 8                    LUSA PHONAP           MOVE THE PHONE DOWN
# 9                THIS IS A SPOON               THIS IS A SPOON
# 10   MOVE THE PHONE TO THE RIGHT   MOVE THE PHONE TO THE RIGHT
# 11                THIS IS A FORK                THIS IS A FORK
# 12    MOVE THE FORK TO THE RIGHT    MOVE THE FORK TO THE RIGHT
# 13               THIS IS A PHONE                THIS IS A FOAM
# 14    MOVE THE PHONE TO THE LEFT             MOVE THE PHONE UP
# 15               THIS IS A SPOON               THIS IS A SPOON
# 16             MOVE THE SPOON UP   MOVE THE SPOON TO THE RIGHT
# 17               THIS IS A PHONE               THIS IS A PHONE
# 18               THIS IS A SPOON               THIS IS A SPOON
# 19               THIS IS A FORRK                THIS IS A FORK
# 20      OVED THE PAN TO THE LEFT               MOVE THE PAN UP
# 21                THIS IS A FORK               THIS IS A FORKN
# 22               THIS IS A KNIFE               THIS IS A KNIFE
# 23                 THIS IS A PEN                 THIS IS A PEN
# 24                MO THE FORECOP             MOVES THE FORECUP
# 25              ROTATH THE KNIFE              OVE THE KNIFE UP
# 26     MOVES THE PEN TO THE LEFT       MOVES A PEN TO THE LEFT
# 27              MOVED THE PHONAP             MOVE THE PHONE UP
# 28               OO THE FORE COP     OVE THE FORK TO THE RIGHT
# 29               THIS IS A SPOON               THIS IS A SPOON
# 30               ROTATE THE FAWN               ROTATE THE FAWN
# 31  MOVED THE SPOON TO THE RIGHT  MOVED THE SPOON TO THE RIGHT
# 32             MOVE THE SPOON UP             MOVE THE SPOON UP
# 33               THIS IS A PHONE               THIS IS A PHONE
# 34                ROTATE THE PEN                ROTATE THE PEN
# 35                THIS IS A FORK                THIS IS A FORK
# 36                THIS IS A FAWN               THIS IS A PHAWN
# 37                 THIS IS A PEN               THIS IS A KNIFE
# 38               THIS IS A SPOON               THIS IS A SPOON
# 39              MOO THE KNIFE UP             MOVE THE KNIFE UP
# 40                 THIS IS A PEN                 THIS IS A PEN
# 41    MOVED THE FORK TO THE LEFT      OVE THE FORK TO THE LEFT
# 42              MOVE THE FOREGAP              MOVE THE FORECUP
# 43    MOVE THE KNIFE TO THE LEFT        MO THE PEN TO THE LEFT
# 44               THIS IS A PHONE               THIS IS A PHONE
# 45               THIS IS A KNIFE               THIS IS A KNIFE
# 46               THIS IS A PHONE               THIS IS A PHONE
# 47               THIS IS A KNIFE               THIS IS A KNIFE
# 48                THIS IS A FORK                THIS IS A FORK
# 49    MOVE THE FALL TO THE RIGHT  MOVED THE PHONE TO THE RIGHT
# 50             MOVE THE SPOON UP              MOO THE SPOON UP
# 51                THIS IS A FORK                 HIS IS A FORK
# 52                THIS IS A FORK                THIS IS A FONE
# 53               THIS IS A SPERN               THIS IS A SPERM
# 54                MOVE THE KNIFE                MOVE THE KNIFE
# 55               THIS IS A PHONE                   IUCA PHONAP
# 56                 THIS IS A PEN                 THIS IS A PEN
# 57               THIS IS A PHONE                 IS IS A PHONE
# 58               ROTADE THE FORK               ROTAE THE FORRK
# 59               THIS IS A KNIFE                THIS IS A FORK
# 60                THIS IS A FOWN                 MUVEEPHONE UP
# 61               THIS IS A SPOON               THIS IS A SPOON
# 62               THIS IS A KNIFE                  O TH KNIFE T
# 63               THIS IS A SPOON               THIS IS A SPOON
# 64               THIS IS A SPOON               THIS IS A SPOON
# 65               THIS IS A SPERN               THIS IS A SPERN
# 66               THIS IS A SPOON               THIS IS A SPOON
# 67                    LUCE PANAP                    LUSE PENUP
# 68             MOVED THE FORECUP    MOVE THE FORK TO THE RIGHT
# 69                 THIS IS A PEN                 THIS IS A PIN
# 70                    LUCE PANAP                    LUSE PENUP
# 71    MOVED THE FORK TO THE LEFT      OVE THE FORK TO THE LEFT
# 72    MOVHE THE FORK TO THE LEFT     MOVE THE FORK TO THE LEFT
# 73   MOVE THE KNIFE TO THE RIGHT   MOVE THE PHONE TO THE RIGHT
# 74               THIS IS A KNIFE               THIS IS A KNIFE
# 75             MOVE THE PEN DOWN      OVE THE FORK TO THE LEFT
# 76     MOVE THE FORK TO THE LEFT    MOTHE THE FORK TO THE LEFT
# 77               THIS IS A PHONE                HIS IS A PHONE
# 78                THIS IS A FORK               THIS IS A FORKN
# 79    MOVE THE KNIFE TO THE LEFT    MOVE THE SPOON TO THE LEFT
# 80               MOVE THE PENDOW             MOVE THE PEN DOWN
# 81               THIS IS A PHONE                THIS IS A PHON
# 82             RO TAKE THE SPOON             RO TAKE THE SPOON
# 83   MOVE THE KNIFE TO THE RIGHT           MOVE THE KNIFE DOWN
# 84               MOE THE PENKNOB               MOVE THE PENNOB
# 85              WROAKE THE KNIFE              ROTATE THE KNIFE
# 86               THIS IS A PHONE               THIS IS A PHONE
# 87        O THE PAN TO THE RIGHT                 U THE FORECUP
# 88                 THIS IS A TAN                 THIS IS A PEN
# 89                THIS IS A FOWN               THIS IS A PHONE
# 90              MOVED THE PHONUP             MOVE THE PHONE UP
# 91             MOVE THE SPOON UP               THIS IS A SPOON
# 92               THIS IS A SPURN               THIS IS A SPOON
# 93               THIS IS A SPOON               THIS IS A SPOON
# 94                      MUCIFONA              MOO A PHONE DOWN
# 95                THIS IS A FORK               THIS IS A PHONE
# 96               THIS IS A KNIFE               THIS IS A KNIFE
# 97                THIS IS A FORK                 THIS IS A FOR
# 98               THIS IS A KNIFE               THIS IS A KNIFE
# 99                THIS IS A FORK                THIS IS A FORK

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_04_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_04_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0                            1
# 0     MOVE THE FORK TO THE RIGHT   MOVE THE PHONE TO THE LEFT
# 1               ROTATE THE KNIFE           WROUTATE THE SPOON
# 2                THIS IS A SPOON              THIS IS A SPERM
# 3     MOVE THE FORK TO THE RIGHT   MOVE THE FORK TO THE RIGHT
# 4            MOVE THE SPOON DOWN                IS IS A SPOON
# 5                 HIS IS A SPURN               THIS IS A FOAM
# 6     MOVED THE FORK TO THE LEFT   MOVE THE FORK TO THE RIGHT
# 7               ROTATE THE SPOON             ROTATE THE SPOON
# 8                    LUSA PHONAP           MOVES THE PHONE UP
# 9                THIS IS A SPOON              THIS IS A SPOON
# 10   MOVE THE PHONE TO THE RIGHT  MOVE THE SPOON TO THE RIGHT
# 11                THIS IS A FORK                HIS IS A FORK
# 12    MOVE THE FORK TO THE RIGHT   MOVE THE FORK TO THE RIGHT
# 13               THIS IS A PHONE              THIS IS A PHONE
# 14    MOVE THE PHONE TO THE LEFT    OVE THE SORK TO THE RIGHT
# 15               THIS IS A SPOON             IS TISE THE FORE
# 16             MOVE THE SPOON UP            MOVE THE SPOON UP
# 17               THIS IS A PHONE    MOVE THE FORK TO THE LEFT
# 18               THIS IS A SPOON              THIS IS A SPOON
# 19               THIS IS A FORRK              THIS IS A KNIFE
# 20      OVED THE PAN TO THE LEFT    MOVED THE PAN TO THE LEFT
# 21                THIS IS A FORK               THIS IS A FORK
# 22               THIS IS A KNIFE  MOVES THE SPOON TO THE LEFT
# 23                 THIS IS A PEN               HIS IS A KNIFE
# 24                MO THE FORECOP            MOVES THE FORECUP
# 25              ROTATH THE KNIFE           WROUTATE THE SPOON
# 26     MOVES THE PEN TO THE LEFT    MOVES THE PEN TO THE LEFT
# 27              MOVED THE PHONAP   MOVE THE PHONE TO THE LEFT
# 28               OO THE FORE COP               OO THE FORECUP
# 29               THIS IS A SPOON              THIS IS A SPOON
# 30               ROTATE THE FAWN              ROTATE THE FAWN
# 31  MOVED THE SPOON TO THE RIGHT  MOVE THE SPOON TO THE RIGHT
# 32             MOVE THE SPOON UP            MOVE THE SPOON UP
# 33               THIS IS A PHONE              THIS IS A PHONE
# 34                ROTATE THE PEN             ROTATE THE SPOON
# 35                THIS IS A FORK               THIS IS A FORK
# 36                THIS IS A FAWN               THIS IS A FOAM
# 37                 THIS IS A PEN            R OU TAKE THE PEN
# 38               THIS IS A SPOON              THIS IS A SPOON
# 39              MOO THE KNIFE UP          MOVE THE KNIFE DOWN
# 40                 THIS IS A PEN              THIS IS A KNIFE
# 41    MOVED THE FORK TO THE LEFT     OVE THE FORK TO THE LEFT
# 42              MOVE THE FOREGAP             MOVE THE FORECUP
# 43    MOVE THE KNIFE TO THE LEFT   MOVE THE KNIFE TO THE LEFT
# 44               THIS IS A PHONE              THIS IS A PHONE
# 45               THIS IS A KNIFE              THIS IS A PHAWN
# 46               THIS IS A PHONE                IS IS A SPOON
# 47               THIS IS A KNIFE               THIS IS A FORK
# 48                THIS IS A FORK               THIS IS A FORK
# 49    MOVE THE FALL TO THE RIGHT   OVE THE PHONE TO THE RIGHT
# 50             MOVE THE SPOON UP                IS IS A SPOON
# 51                THIS IS A FORK               THIS IS A FORK
# 52                THIS IS A FORK               THIS IS A FORK
# 53               THIS IS A SPERN              THIS IS A SPERM
# 54                MOVE THE KNIFE               MOVE THE KNIFE
# 55               THIS IS A PHONE                THIS IS A PIN
# 56                 THIS IS A PEN                HIS IS A FORK
# 57               THIS IS A PHONE              THIS IS A PHONE
# 58               ROTADE THE FORK              ROTADE THE FORK
# 59               THIS IS A KNIFE                HIS IS A FORK
# 60                THIS IS A FOWN              THIS IS A PHONE
# 61               THIS IS A SPOON              THIS IS A PHONE
# 62               THIS IS A KNIFE                HIS IS A FORK
# 63               THIS IS A SPOON              THIS IS A SPOON
# 64               THIS IS A SPOON             OVE THE SPOON UP
# 65               THIS IS A SPERN              THIS IS A SPERM
# 66               THIS IS A SPOON              THIS IS A SPOON
# 67                    LUCE PANAP                   LUSE PENAP
# 68             MOVED THE FORECUP           MOVE THE FORK DOWN
# 69                 THIS IS A PEN              THIS IS A PHONE
# 70                    LUCE PANAP                    LUSIPENUP
# 71    MOVED THE FORK TO THE LEFT            O  THE SPOON DOWN
# 72    MOVHE THE FORK TO THE LEFT   MOVED THE FORK TO THE LEFT
# 73   MOVE THE KNIFE TO THE RIGHT               HIS IS A KNIFE
# 74               THIS IS A KNIFE               THIS IS A FORK
# 75             MOVE THE PEN DOWN                THIS IS A PEN
# 76     MOVE THE FORK TO THE LEFT   MOTHE THE FORK TO THE LEFT
# 77               THIS IS A PHONE  MOVE THE PHONE TO THE RIGHT
# 78                THIS IS A FORK               THIS IS A FORK
# 79    MOVE THE KNIFE TO THE LEFT          MOVE THE KNIFE DOWN
# 80               MOVE THE PENDOW            MOVE THE PEN DOWN
# 81               THIS IS A PHONE              THIS IS A SPOON
# 82             RO TAKE THE SPOON                 O THE PHONUP
# 83   MOVE THE KNIFE TO THE RIGHT  MOVE THE KNIFE TO THE RIGHT
# 84               MOE THE PENKNOB            MOVE THE PEN DOWN
# 85              WROAKE THE KNIFE            OH THE SPOON DOWN
# 86               THIS IS A PHONE                IS IS A SPOON
# 87        O THE PAN TO THE RIGHT    MOVE THE PEN TO THE RIGHT
# 88                 THIS IS A TAN                THIS IS A PEN
# 89                THIS IS A FOWN    MOVE THE FORK TO THE LEFT
# 90              MOVED THE PHONUP   MOVE THE PHONE TO THE LEFT
# 91             MOVE THE SPOON UP            MOVE THE SPOON AP
# 92               THIS IS A SPURN                IS IS A SPOON
# 93               THIS IS A SPOON              THIS IS A SPOON
# 94                      MUCIFONA                MUVEEPHONE UP
# 95                THIS IS A FORK               THIS IS A FORK
# 96               THIS IS A KNIFE              THIS IS A KNIFE
# 97                THIS IS A FORK                THIS IS A FOR
# 98               THIS IS A KNIFE              THIS IS A PHONE
# 99                THIS IS A FORK               THIS IS A FORK

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_05_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_05_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0 1
# 0     MOVE THE FORK TO THE RIGHT
# 1               ROTATE THE KNIFE
# 2                THIS IS A SPOON
# 3     MOVE THE FORK TO THE RIGHT
# 4            MOVE THE SPOON DOWN
# 5                 HIS IS A SPURN
# 6     MOVED THE FORK TO THE LEFT
# 7               ROTATE THE SPOON
# 8                    LUSA PHONAP
# 9                THIS IS A SPOON
# 10   MOVE THE PHONE TO THE RIGHT
# 11                THIS IS A FORK
# 12    MOVE THE FORK TO THE RIGHT
# 13               THIS IS A PHONE
# 14    MOVE THE PHONE TO THE LEFT
# 15               THIS IS A SPOON
# 16             MOVE THE SPOON UP
# 17               THIS IS A PHONE
# 18               THIS IS A SPOON
# 19               THIS IS A FORRK
# 20      OVED THE PAN TO THE LEFT
# 21                THIS IS A FORK
# 22               THIS IS A KNIFE
# 23                 THIS IS A PEN
# 24                MO THE FORECOP
# 25              ROTATH THE KNIFE
# 26     MOVES THE PEN TO THE LEFT
# 27              MOVED THE PHONAP
# 28               OO THE FORE COP
# 29               THIS IS A SPOON
# 30               ROTATE THE FAWN
# 31  MOVED THE SPOON TO THE RIGHT
# 32             MOVE THE SPOON UP
# 33               THIS IS A PHONE
# 34                ROTATE THE PEN
# 35                THIS IS A FORK
# 36                THIS IS A FAWN
# 37                 THIS IS A PEN
# 38               THIS IS A SPOON
# 39              MOO THE KNIFE UP
# 40                 THIS IS A PEN
# 41    MOVED THE FORK TO THE LEFT
# 42              MOVE THE FOREGAP
# 43    MOVE THE KNIFE TO THE LEFT
# 44               THIS IS A PHONE
# 45               THIS IS A KNIFE
# 46               THIS IS A PHONE
# 47               THIS IS A KNIFE
# 48                THIS IS A FORK
# 49    MOVE THE FALL TO THE RIGHT
# 50             MOVE THE SPOON UP
# 51                THIS IS A FORK
# 52                THIS IS A FORK
# 53               THIS IS A SPERN
# 54                MOVE THE KNIFE
# 55               THIS IS A PHONE
# 56                 THIS IS A PEN
# 57               THIS IS A PHONE
# 58               ROTADE THE FORK
# 59               THIS IS A KNIFE
# 60                THIS IS A FOWN
# 61               THIS IS A SPOON
# 62               THIS IS A KNIFE
# 63               THIS IS A SPOON
# 64               THIS IS A SPOON
# 65               THIS IS A SPERN
# 66               THIS IS A SPOON
# 67                    LUCE PANAP
# 68             MOVED THE FORECUP
# 69                 THIS IS A PEN
# 70                    LUCE PANAP
# 71    MOVED THE FORK TO THE LEFT
# 72    MOVHE THE FORK TO THE LEFT
# 73   MOVE THE KNIFE TO THE RIGHT
# 74               THIS IS A KNIFE
# 75             MOVE THE PEN DOWN
# 76     MOVE THE FORK TO THE LEFT
# 77               THIS IS A PHONE
# 78                THIS IS A FORK
# 79    MOVE THE KNIFE TO THE LEFT
# 80               MOVE THE PENDOW
# 81               THIS IS A PHONE
# 82             RO TAKE THE SPOON
# 83   MOVE THE KNIFE TO THE RIGHT
# 84               MOE THE PENKNOB
# 85              WROAKE THE KNIFE
# 86               THIS IS A PHONE
# 87        O THE PAN TO THE RIGHT
# 88                 THIS IS A TAN
# 89                THIS IS A FOWN
# 90              MOVED THE PHONUP
# 91             MOVE THE SPOON UP
# 92               THIS IS A SPURN
# 93               THIS IS A SPOON
# 94                      MUCIFONA
# 95                THIS IS A FORK
# 96               THIS IS A KNIFE
# 97                THIS IS A FORK
# 98               THIS IS A KNIFE
# 99                THIS IS A FORK

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_06_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_06_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0                            1
# 0     MOVE THE FORK TO THE RIGHT   MOVE THE FORK TO THE RIGHT
# 1               ROTATE THE KNIFE            WROTATE THE KNIFE
# 2                THIS IS A SPOON              THIS IS A SPOON
# 3     MOVE THE FORK TO THE RIGHT   MOVE THE FORK TO THE RIGHT
# 4            MOVE THE SPOON DOWN          MOVE THE SPOON DOWN
# 5                 HIS IS A SPURN              THIS IS A SPERN
# 6     MOVED THE FORK TO THE LEFT    MOVE THE FORK TO THE LEFT
# 7               ROTATE THE SPOON             ROTATE THE SPOON
# 8                    LUSA PHONAP           MOVES THE PHONE UP
# 9                THIS IS A SPOON              THIS IS A SPOON
# 10   MOVE THE PHONE TO THE RIGHT  MOVE THE PHONE TO THE RIGHT
# 11                THIS IS A FORK               THIS IS A FORK
# 12    MOVE THE FORK TO THE RIGHT   MOVE THE FORK TO THE RIGHT
# 13               THIS IS A PHONE              THIS IS A PHONE
# 14    MOVE THE PHONE TO THE LEFT            MOVE THE PHONE UP
# 15               THIS IS A SPOON              THIS IS A SPOON
# 16             MOVE THE SPOON UP            MOVE THE SPOON UP
# 17               THIS IS A PHONE              THIS IS A PHONE
# 18               THIS IS A SPOON              THIS IS A SPOON
# 19               THIS IS A FORRK               THIS IS A FORK
# 20      OVED THE PAN TO THE LEFT     OVED THE PAN TO THE LEFT
# 21                THIS IS A FORK               THIS IS A FORK
# 22               THIS IS A KNIFE              THIS IS A KNIFE
# 23                 THIS IS A PEN                THIS IS A PEN
# 24                MO THE FORECOP              MOO THE FORECOP
# 25              ROTATH THE KNIFE            WROTATE THE KNIFE
# 26     MOVES THE PEN TO THE LEFT      MOVES A PEN TO THE LEFT
# 27              MOVED THE PHONAP            MOVE THE PHONE UP
# 28               OO THE FORE COP                U THE FORECUP
# 29               THIS IS A SPOON              THIS IS A SPOON
# 30               ROTATE THE FAWN               ROTATE THE FOT
# 31  MOVED THE SPOON TO THE RIGHT         MOVED THE SPOON DOWN
# 32             MOVE THE SPOON UP            MOVE THE SPOON UP
# 33               THIS IS A PHONE              THIS IS A PHONE
# 34                ROTATE THE PEN               ROTATE THE PEN
# 35                THIS IS A FORK               THIS IS A FORK
# 36                THIS IS A FAWN              THIS IS A PHAWN
# 37                 THIS IS A PEN                THIS IS A PEN
# 38               THIS IS A SPOON              THIS IS A SPOON
# 39              MOO THE KNIFE UP    MOVE THE PEN TO THE RIGHT
# 40                 THIS IS A PEN                THIS IS A PEN
# 41    MOVED THE FORK TO THE LEFT     OVE THE FORK TO THE LEFT
# 42              MOVE THE FOREGAP             MOVE THE FORECUP
# 43    MOVE THE KNIFE TO THE LEFT  MOVED THE KNIFE TO THE LEFT
# 44               THIS IS A PHONE              THIS IS A PHONE
# 45               THIS IS A KNIFE              THIS IS A KNIFE
# 46               THIS IS A PHONE               THIS IS A PONE
# 47               THIS IS A KNIFE              THIS IS A KNIFE
# 48                THIS IS A FORK               THIS IS A FORK
# 49    MOVE THE FALL TO THE RIGHT            OVE THE FALM DOWN
# 50             MOVE THE SPOON UP             MOO THE SPOON UP
# 51                THIS IS A FORK               THIS IS A FORK
# 52                THIS IS A FORK                THIS IS A FOR
# 53               THIS IS A SPERN              THIS IS A SPERM
# 54                MOVE THE KNIFE               MOVE THE KNIFE
# 55               THIS IS A PHONE              THIS IS A PHONE
# 56                 THIS IS A PEN                THIS IS A PEN
# 57               THIS IS A PHONE              THIS IS A PHONE
# 58               ROTADE THE FORK              ROTAE THE FORRK
# 59               THIS IS A KNIFE              THIS IS A KNIFE
# 60                THIS IS A FOWN                     MUCIFONA
# 61               THIS IS A SPOON              THIS IS A SPOON
# 62               THIS IS A KNIFE              THIS IS A KNIFE
# 63               THIS IS A SPOON              THIS IS A SPOON
# 64               THIS IS A SPOON              THIS IS A SPOON
# 65               THIS IS A SPERN               THIS IS A SPON
# 66               THIS IS A SPOON              THIS IS A SPOON
# 67                    LUCE PANAP                   LUSE PENUP
# 68             MOVED THE FORECUP            MOVED THE FORECUP
# 69                 THIS IS A PEN                THIS IS A PEN
# 70                    LUCE PANAP                    LUSIPENUP
# 71    MOVED THE FORK TO THE LEFT     OVE THE FORK TO THE LEFT
# 72    MOVHE THE FORK TO THE LEFT   MOVED THE FORK TO THE LEFT
# 73   MOVE THE KNIFE TO THE RIGHT  MOVE THE KNIFE TO THE RIGHT
# 74               THIS IS A KNIFE                THIS IS A NIE
# 75             MOVE THE PEN DOWN             OVE THE PEN DOWN
# 76     MOVE THE FORK TO THE LEFT   MOTHE THE FORK TO THE LEFT
# 77               THIS IS A PHONE              THIS IS A PHONE
# 78                THIS IS A FORK               THIS IS A FORK
# 79    MOVE THE KNIFE TO THE LEFT   MOVE THE KNIFE TO THE LEFT
# 80               MOVE THE PENDOW            MOVE THE PEN DOWN
# 81               THIS IS A PHONE              THIS IS A PHONE
# 82             RO TAKE THE SPOON     O THE PHONE TO THE RIGHT
# 83   MOVE THE KNIFE TO THE RIGHT  MOVE THE KNIFE TO THE RIGHT
# 84               MOE THE PENKNOB            MOVE THE PEN DOWN
# 85              WROAKE THE KNIFE              ROTATE THE NIFE
# 86               THIS IS A PHONE              THIS IS A PHONE
# 87        O THE PAN TO THE RIGHT      UE THE PEN TO THE RIGHT
# 88                 THIS IS A TAN                THIS IS A PEN
# 89                THIS IS A FOWN              THIS IS A PHONE
# 90              MOVED THE PHONUP            MOVE THE PHONE UP
# 91             MOVE THE SPOON UP            MOVE THE SPOON UP
# 92               THIS IS A SPURN              THIS IS A SPOON
# 93               THIS IS A SPOON              THIS IS A SPOON
# 94                      MUCIFONA           MOVES THE PHONE UP
# 95                THIS IS A FORK               THIS IS A FORK
# 96               THIS IS A KNIFE              THIS IS A KNIFE
# 97                THIS IS A FORK                THIS IS A FOR
# 98               THIS IS A KNIFE              THIS IS A KNIFE
# 99                THIS IS A FORK               THIS IS A FORK

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_07_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_07_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0 1
# 0     MOVE THE FORK TO THE RIGHT
# 1               ROTATE THE KNIFE
# 2                THIS IS A SPOON
# 3     MOVE THE FORK TO THE RIGHT
# 4            MOVE THE SPOON DOWN
# 5                 HIS IS A SPURN
# 6     MOVED THE FORK TO THE LEFT
# 7               ROTATE THE SPOON
# 8                    LUSA PHONAP
# 9                THIS IS A SPOON
# 10   MOVE THE PHONE TO THE RIGHT
# 11                THIS IS A FORK
# 12    MOVE THE FORK TO THE RIGHT
# 13               THIS IS A PHONE
# 14    MOVE THE PHONE TO THE LEFT
# 15               THIS IS A SPOON
# 16             MOVE THE SPOON UP
# 17               THIS IS A PHONE
# 18               THIS IS A SPOON
# 19               THIS IS A FORRK
# 20      OVED THE PAN TO THE LEFT
# 21                THIS IS A FORK
# 22               THIS IS A KNIFE
# 23                 THIS IS A PEN
# 24                MO THE FORECOP
# 25              ROTATH THE KNIFE
# 26     MOVES THE PEN TO THE LEFT
# 27              MOVED THE PHONAP
# 28               OO THE FORE COP
# 29               THIS IS A SPOON
# 30               ROTATE THE FAWN
# 31  MOVED THE SPOON TO THE RIGHT
# 32             MOVE THE SPOON UP
# 33               THIS IS A PHONE
# 34                ROTATE THE PEN
# 35                THIS IS A FORK
# 36                THIS IS A FAWN
# 37                 THIS IS A PEN
# 38               THIS IS A SPOON
# 39              MOO THE KNIFE UP
# 40                 THIS IS A PEN
# 41    MOVED THE FORK TO THE LEFT
# 42              MOVE THE FOREGAP
# 43    MOVE THE KNIFE TO THE LEFT
# 44               THIS IS A PHONE
# 45               THIS IS A KNIFE
# 46               THIS IS A PHONE
# 47               THIS IS A KNIFE
# 48                THIS IS A FORK
# 49    MOVE THE FALL TO THE RIGHT
# 50             MOVE THE SPOON UP
# 51                THIS IS A FORK
# 52                THIS IS A FORK
# 53               THIS IS A SPERN
# 54                MOVE THE KNIFE
# 55               THIS IS A PHONE
# 56                 THIS IS A PEN
# 57               THIS IS A PHONE
# 58               ROTADE THE FORK
# 59               THIS IS A KNIFE
# 60                THIS IS A FOWN
# 61               THIS IS A SPOON
# 62               THIS IS A KNIFE
# 63               THIS IS A SPOON
# 64               THIS IS A SPOON
# 65               THIS IS A SPERN
# 66               THIS IS A SPOON
# 67                    LUCE PANAP
# 68             MOVED THE FORECUP
# 69                 THIS IS A PEN
# 70                    LUCE PANAP
# 71    MOVED THE FORK TO THE LEFT
# 72    MOVHE THE FORK TO THE LEFT
# 73   MOVE THE KNIFE TO THE RIGHT
# 74               THIS IS A KNIFE
# 75             MOVE THE PEN DOWN
# 76     MOVE THE FORK TO THE LEFT
# 77               THIS IS A PHONE
# 78                THIS IS A FORK
# 79    MOVE THE KNIFE TO THE LEFT
# 80               MOVE THE PENDOW
# 81               THIS IS A PHONE
# 82             RO TAKE THE SPOON
# 83   MOVE THE KNIFE TO THE RIGHT
# 84               MOE THE PENKNOB
# 85              WROAKE THE KNIFE
# 86               THIS IS A PHONE
# 87        O THE PAN TO THE RIGHT
# 88                 THIS IS A TAN
# 89                THIS IS A FOWN
# 90              MOVED THE PHONUP
# 91             MOVE THE SPOON UP
# 92               THIS IS A SPURN
# 93               THIS IS A SPOON
# 94                      MUCIFONA
# 95                THIS IS A FORK
# 96               THIS IS A KNIFE
# 97                THIS IS A FORK
# 98               THIS IS A KNIFE
# 99                THIS IS A FORK

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_08_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_08_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0         1
# 0     MOVE THE FORK TO THE RIGHT
# 1               ROTATE THE KNIFE
# 2                THIS IS A SPOON
# 3     MOVE THE FORK TO THE RIGHT        TH
# 4            MOVE THE SPOON DOWN
# 5                 HIS IS A SPURN
# 6     MOVED THE FORK TO THE LEFT
# 7               ROTATE THE SPOON
# 8                    LUSA PHONAP
# 9                THIS IS A SPOON
# 10   MOVE THE PHONE TO THE RIGHT
# 11                THIS IS A FORK
# 12    MOVE THE FORK TO THE RIGHT
# 13               THIS IS A PHONE
# 14    MOVE THE PHONE TO THE LEFT
# 15               THIS IS A SPOON
# 16             MOVE THE SPOON UP
# 17               THIS IS A PHONE         S
# 18               THIS IS A SPOON
# 19               THIS IS A FORRK
# 20      OVED THE PAN TO THE LEFT
# 21                THIS IS A FORK
# 22               THIS IS A KNIFE
# 23                 THIS IS A PEN
# 24                MO THE FORECOP
# 25              ROTATH THE KNIFE
# 26     MOVES THE PEN TO THE LEFT
# 27              MOVED THE PHONAP
# 28               OO THE FORE COP
# 29               THIS IS A SPOON
# 30               ROTATE THE FAWN         V
# 31  MOVED THE SPOON TO THE RIGHT
# 32             MOVE THE SPOON UP
# 33               THIS IS A PHONE
# 34                ROTATE THE PEN
# 35                THIS IS A FORK
# 36                THIS IS A FAWN
# 37                 THIS IS A PEN
# 38               THIS IS A SPOON
# 39              MOO THE KNIFE UP
# 40                 THIS IS A PEN
# 41    MOVED THE FORK TO THE LEFT
# 42              MOVE THE FOREGAP
# 43    MOVE THE KNIFE TO THE LEFT
# 44               THIS IS A PHONE
# 45               THIS IS A KNIFE
# 46               THIS IS A PHONE
# 47               THIS IS A KNIFE
# 48                THIS IS A FORK
# 49    MOVE THE FALL TO THE RIGHT  IO THTHE
# 50             MOVE THE SPOON UP
# 51                THIS IS A FORK
# 52                THIS IS A FORK       ISO
# 53               THIS IS A SPERN
# 54                MOVE THE KNIFE
# 55               THIS IS A PHONE
# 56                 THIS IS A PEN
# 57               THIS IS A PHONE
# 58               ROTADE THE FORK
# 59               THIS IS A KNIFE
# 60                THIS IS A FOWN
# 61               THIS IS A SPOON
# 62               THIS IS A KNIFE
# 63               THIS IS A SPOON
# 64               THIS IS A SPOON
# 65               THIS IS A SPERN
# 66               THIS IS A SPOON
# 67                    LUCE PANAP
# 68             MOVED THE FORECUP
# 69                 THIS IS A PEN
# 70                    LUCE PANAP
# 71    MOVED THE FORK TO THE LEFT
# 72    MOVHE THE FORK TO THE LEFT
# 73   MOVE THE KNIFE TO THE RIGHT
# 74               THIS IS A KNIFE
# 75             MOVE THE PEN DOWN
# 76     MOVE THE FORK TO THE LEFT
# 77               THIS IS A PHONE
# 78                THIS IS A FORK
# 79    MOVE THE KNIFE TO THE LEFT      VTHE
# 80               MOVE THE PENDOW
# 81               THIS IS A PHONE
# 82             RO TAKE THE SPOON
# 83   MOVE THE KNIFE TO THE RIGHT
# 84               MOE THE PENKNOB
# 85              WROAKE THE KNIFE
# 86               THIS IS A PHONE
# 87        O THE PAN TO THE RIGHT
# 88                 THIS IS A TAN
# 89                THIS IS A FOWN         S
# 90              MOVED THE PHONUP
# 91             MOVE THE SPOON UP
# 92               THIS IS A SPURN
# 93               THIS IS A SPOON
# 94                      MUCIFONA
# 95                THIS IS A FORK
# 96               THIS IS A KNIFE
# 97                THIS IS A FORK
# 98               THIS IS A KNIFE
# 99                THIS IS A FORK

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_09_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_09_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0                            1
# 0     MOVE THE FORK TO THE RIGHT   MOVE THE FORK TO THE RIGHT
# 1               ROTATE THE KNIFE              ROTAKE THE FORK
# 2                THIS IS A SPOON              THIS IS A SPOON
# 3     MOVE THE FORK TO THE RIGHT   MOVE THE FORK TO THE RIGHT
# 4            MOVE THE SPOON DOWN         MOVED THE SPOON DOWN
# 5                 HIS IS A SPURN              THIS IS A SPURN
# 6     MOVED THE FORK TO THE LEFT    MOVE THE FORK TO THE LEFT
# 7               ROTATE THE SPOON             ROTATE THE SPOON
# 8                    LUSA PHONAP                MUVEEPHONE UP
# 9                THIS IS A SPOON              THIS IS A SPOON
# 10   MOVE THE PHONE TO THE RIGHT            MOVE THE PHONE UP
# 11                THIS IS A FORK              THIS IS A FORRK
# 12    MOVE THE FORK TO THE RIGHT   MOVE THE FORK TO THE RIGHT
# 13               THIS IS A PHONE               THIS IS A FONE
# 14    MOVE THE PHONE TO THE LEFT  MOVE THE PHONE TO THE RIGHT
# 15               THIS IS A SPOON              THIS IS A SPOON
# 16             MOVE THE SPOON UP            MOVE THE SPOON UP
# 17               THIS IS A PHONE              THIS IS A PHONE
# 18               THIS IS A SPOON              THIS IS A SPOON
# 19               THIS IS A FORRK               THIS IS A FORK
# 20      OVED THE PAN TO THE LEFT     OVED THE PAN TO THE LEFT
# 21                THIS IS A FORK               THIS IS A FORK
# 22               THIS IS A KNIFE              THIS IS A KNIFE
# 23                 THIS IS A PEN                THIS IS A PEN
# 24                MO THE FORECOP              MOE THE FORECOP
# 25              ROTATH THE KNIFE              ROTAKE THE FORK
# 26     MOVES THE PEN TO THE LEFT   MOVES THE PEN TO THE RIGHT
# 27              MOVED THE PHONAP             MOVE THE FAWN UP
# 28               OO THE FORE COP            OVE THE SORK DOWN
# 29               THIS IS A SPOON              THIS IS A SPOON
# 30               ROTATE THE FAWN              ROTATE THE FAWN
# 31  MOVED THE SPOON TO THE RIGHT         MOVED THE SPOON DOWN
# 32             MOVE THE SPOON UP            MOVE THE SPOON UP
# 33               THIS IS A PHONE              THIS IS A PHONE
# 34                ROTATE THE PEN               ROTATE THE PEN
# 35                THIS IS A FORK               THIS IS A FORK
# 36                THIS IS A FAWN               THIS IS A PHON
# 37                 THIS IS A PEN                THIS IS A PEN
# 38               THIS IS A SPOON              THIS IS A SPOON
# 39              MOO THE KNIFE UP  MOVE THE KNIFE TO THE RIGHT
# 40                 THIS IS A PEN                THIS IS A PEN
# 41    MOVED THE FORK TO THE LEFT     OVE THE FORK TO THE LEFT
# 42              MOVE THE FOREGAP             MOVE THE FORECAP
# 43    MOVE THE KNIFE TO THE LEFT   MOVE THE KNIFE TO THE LEFT
# 44               THIS IS A PHONE              THIS IS A PHONE
# 45               THIS IS A KNIFE              THIS IS A KNIFE
# 46               THIS IS A PHONE              THIS IS A PHONE
# 47               THIS IS A KNIFE              THIS IS A KNIFE
# 48                THIS IS A FORK               THIS IS A FORK
# 49    MOVE THE FALL TO THE RIGHT               OV THE PHON UP
# 50             MOVE THE SPOON UP  MOVED THE SPOON TO THE LEFT
# 51                THIS IS A FORK              THIS IS A KNIFE
# 52                THIS IS A FORK               THIS IS A FORK
# 53               THIS IS A SPERN               THIS IS A FORK
# 54                MOVE THE KNIFE               MOVE THE KNIFE
# 55               THIS IS A PHONE              THIS IS A PHONE
# 56                 THIS IS A PEN                THIS IS A PEN
# 57               THIS IS A PHONE              THIS IS A PHONE
# 58               ROTADE THE FORK              ROTAE THE FORRK
# 59               THIS IS A KNIFE              THIS IS A KNIFE
# 60                THIS IS A FOWN              THIS IS A PHONE
# 61               THIS IS A SPOON              THIS IS A SPOON
# 62               THIS IS A KNIFE              THIS IS A KNIFE
# 63               THIS IS A SPOON              THIS IS A SPOON
# 64               THIS IS A SPOON              THIS IS A SPOON
# 65               THIS IS A SPERN              THIS IS A SPERM
# 66               THIS IS A SPOON              THIS IS A SPOON
# 67                    LUCE PANAP                   LUSE PENUP
# 68             MOVED THE FORECUP            MOVED THE FORECUP
# 69                 THIS IS A PEN                THIS IS A PIN
# 70                    LUCE PANAP                  IS IS A PEN
# 71    MOVED THE FORK TO THE LEFT     OVE THE FORK TO THE LEFT
# 72    MOVHE THE FORK TO THE LEFT   MOVED THE FORK TO THE LEFT
# 73   MOVE THE KNIFE TO THE RIGHT  MOVE THE KNIFE TO THE RIGHT
# 74               THIS IS A KNIFE                THIS IS A NIE
# 75             MOVE THE PEN DOWN             OVE THE PEN DOWN
# 76     MOVE THE FORK TO THE LEFT    MOVE THE FORK TO THE LEFT
# 77               THIS IS A PHONE               HIS IS A PHONE
# 78                THIS IS A FORK               THIS IS A FORK
# 79    MOVE THE KNIFE TO THE LEFT   MOVE THE KNIFE TO THE LEFT
# 80               MOVE THE PENDOW            MOVE THE PEN DOWN
# 81               THIS IS A PHONE               THIS IS A PHON
# 82             RO TAKE THE SPOON             ROTAKE THE SPOON
# 83   MOVE THE KNIFE TO THE RIGHT  MOVE THE KNIFE TO THE RIGHT
# 84               MOE THE PENKNOB              MOVE THE PENNOB
# 85              WROAKE THE KNIFE             ROTATE THE KNIFE
# 86               THIS IS A PHONE              THIS IS A PHAWN
# 87        O THE PAN TO THE RIGHT                 U THE PEN UP
# 88                 THIS IS A TAN                THIS IS A PEN
# 89                THIS IS A FOWN              THIS IS A PHONE
# 90              MOVED THE PHONUP             MOVE THE FAWN UP
# 91             MOVE THE SPOON UP          MOVE THE SPOON DOWN
# 92               THIS IS A SPURN              THIS IS A SPOON
# 93               THIS IS A SPOON              THIS IS A SPOON
# 94                      MUCIFONA               LUCA FOUND OUT
# 95                THIS IS A FORK               THIS IS A FOWN
# 96               THIS IS A KNIFE              THIS IS A KNIFE
# 97                THIS IS A FORK                THIS IS A FOR
# 98               THIS IS A KNIFE              THIS IS A KNIFE
# 99                THIS IS A FORK               THIS IS A FORK

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_10_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_10_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0                             1
# 0     MOVE THE FORK TO THE RIGHT    MOVE THE FORK TO THE RIGHT
# 1               ROTATE THE KNIFE             MOVE THE PEN DOWN
# 2                THIS IS A SPOON                THIS IS A FOWN
# 3     MOVE THE FORK TO THE RIGHT              MOVE THE FORECAP
# 4            MOVE THE SPOON DOWN   MOVE THE SPOON TO THE RIGHT
# 5                 HIS IS A SPURN               THIS IS A SPURN
# 6     MOVED THE FORK TO THE LEFT     MOVE THE FORK TO THE LEFT
# 7               ROTATE THE SPOON              ROTATE THE SPOON
# 8                    LUSA PHONAP                THIS IS A FOWN
# 9                THIS IS A SPOON               THIS IS A SPOON
# 10   MOVE THE PHONE TO THE RIGHT           MOVE THE PHONE DOWN
# 11                THIS IS A FORK                THIS IS A FORK
# 12    MOVE THE FORK TO THE RIGHT    MOVE THE FORK TO THE RIGHT
# 13               THIS IS A PHONE               THIS IS A PHONE
# 14    MOVE THE PHONE TO THE LEFT           MOVE THE PHONE DOWN
# 15               THIS IS A SPOON               THIS IS A SPOON
# 16             MOVE THE SPOON UP             MOVE THE SPOON UP
# 17               THIS IS A PHONE                 THIS IS A PEN
# 18               THIS IS A SPOON               THIS IS A FFORK
# 19               THIS IS A FORRK                THIS IS A FORK
# 20      OVED THE PAN TO THE LEFT      OVED THE PAN TO THE LEFT
# 21                THIS IS A FORK                THIS IS A FORK
# 22               THIS IS A KNIFE                 THIS IS A PEN
# 23                 THIS IS A PEN                 THIS IS A PEN
# 24                MO THE FORECOP     MOVE THE FORK TO THE LEFT
# 25              ROTATH THE KNIFE             MOVE THE PEN DOWN
# 26     MOVES THE PEN TO THE LEFT      LOOSE A PEN TO THE RIGHT
# 27              MOVED THE PHONAP             MOVE THE PHONE UP
# 28               OO THE FORE COP             OVE THE FORK DOWN
# 29               THIS IS A SPOON               THIS IS A SPOON
# 30               ROTATE THE FAWN                ROTATE THE FON
# 31  MOVED THE SPOON TO THE RIGHT    MOVE THE SPOON TO THE LEFT
# 32             MOVE THE SPOON UP             MOVE THE SPOON UP
# 33               THIS IS A PHONE                 THIS IS A PEN
# 34                ROTATE THE PEN                ROTATE THE PEN
# 35                THIS IS A FORK                THIS IS A FORK
# 36                THIS IS A FAWN                THIS IS A PHON
# 37                 THIS IS A PEN                 THIS IS A PEN
# 38               THIS IS A SPOON               THIS IS A SPOON
# 39              MOO THE KNIFE UP             MOVE THE KNIFE UP
# 40                 THIS IS A PEN                 THIS IS A PEN
# 41    MOVED THE FORK TO THE LEFT      OVE THE FORK TO THE LEFT
# 42              MOVE THE FOREGAP                THIS IS A FORK
# 43    MOVE THE KNIFE TO THE LEFT   MOVED THE KNIFE TO THE LEFT
# 44               THIS IS A PHONE               THIS IS A PHONE
# 45               THIS IS A KNIFE               THIS IS A KNIFE
# 46               THIS IS A PHONE    MOVE THE PHONE TO THE LEFT
# 47               THIS IS A KNIFE               THIS IS A PHONE
# 48                THIS IS A FORK                THIS IS A FORK
# 49    MOVE THE FALL TO THE RIGHT  MOVED THE PHONE TO THE RIGHT
# 50             MOVE THE SPOON UP             MOVE THE SPOON UP
# 51                THIS IS A FORK               THIS IS A KNIFE
# 52                THIS IS A FORK                THIS IS A FORK
# 53               THIS IS A SPERN               THIS IS A SPERN
# 54                MOVE THE KNIFE   MOVE THE KNIFE TO THE RIGHT
# 55               THIS IS A PHONE                THIS IS A FOWN
# 56                 THIS IS A PEN                 THIS IS A PEN
# 57               THIS IS A PHONE               THIS IS A SPOON
# 58               ROTADE THE FORK    MOVED THE FORK TO THE LEFT
# 59               THIS IS A KNIFE               THIS IS A KNIFE
# 60                THIS IS A FOWN                THIS IS A FOWN
# 61               THIS IS A SPOON               THIS IS A SPOON
# 62               THIS IS A KNIFE               THIS IS A KNIFE
# 63               THIS IS A SPOON               THIS IS A SPOON
# 64               THIS IS A SPOON               THIS IS A SPOON
# 65               THIS IS A SPERN               THIS IS A SPERM
# 66               THIS IS A SPOON               THIS IS A SPOON
# 67                    LUCE PANAP    MOVE THE KNIFE TO THE LEFT
# 68             MOVED THE FORECUP                THIS IS A FORK
# 69                 THIS IS A PEN                 THIS IS A PEN
# 70                    LUCE PANAP                 THIS IS A PEN
# 71    MOVED THE FORK TO THE LEFT      OVE THE FORK TO THE LEFT
# 72    MOVHE THE FORK TO THE LEFT    MOVED THE FORK TO THE LEFT
# 73   MOVE THE KNIFE TO THE RIGHT             MOVE THE KNIFE UP
# 74               THIS IS A KNIFE                 THIS IS A NIE
# 75             MOVE THE PEN DOWN              OVE THE PEN DOWN
# 76     MOVE THE FORK TO THE LEFT     MOVE THE FORK TO THE LEFT
# 77               THIS IS A PHONE                HIS IS A PHONE
# 78                THIS IS A FORK                THIS IS A FORK
# 79    MOVE THE KNIFE TO THE LEFT    MOVE THE FORK TO THE RIGHT
# 80               MOVE THE PENDOW             MOVE THE PEN DOWN
# 81               THIS IS A PHONE               THIS IS A PHONE
# 82             RO TAKE THE SPOON           MOVE THE SPOON DOWN
# 83   MOVE THE KNIFE TO THE RIGHT   MOVE THE KNIFE TO THE RIGHT
# 84               MOE THE PENKNOB     MOVE THE PEN TO THE RIGHT
# 85              WROAKE THE KNIFE               ROTATE THE NICE
# 86               THIS IS A PHONE               THIS IS A PHAWN
# 87        O THE PAN TO THE RIGHT      OVED THE PAN TO THE LEFT
# 88                 THIS IS A TAN                THIS IS A FARM
# 89                THIS IS A FOWN                 THIS IS A PEN
# 90              MOVED THE PHONUP             MOVE THE PHONE UP
# 91             MOVE THE SPOON UP            MOVE THE SPOON OUP
# 92               THIS IS A SPURN               THIS IS A SPOON
# 93               THIS IS A SPOON               THIS IS A SPOON
# 94                      MUCIFONA     OVES THE PEN TO THE RIGHT
# 95                THIS IS A FORK                THIS IS A FORK
# 96               THIS IS A KNIFE              ROTATE THE KNIFE
# 97                THIS IS A FORK                 THIS IS A FOR
# 98               THIS IS A KNIFE               THIS IS A KNIFE
# 99                THIS IS A FORK                 THIS IS A FOR

# %%
pd.DataFrame(out)
# Out:
#                                0                             1
# 0     MOVE THE FORK TO THE RIGHT    MOVE THE FORK TO THE RIGHT
# 1               ROTATE THE KNIFE             MOVE THE PEN DOWN
# 2                THIS IS A SPOON                THIS IS A FOWN
# 3     MOVE THE FORK TO THE RIGHT              MOVE THE FORECAP
# 4            MOVE THE SPOON DOWN   MOVE THE SPOON TO THE RIGHT
# 5                 HIS IS A SPURN               THIS IS A SPURN
# 6     MOVED THE FORK TO THE LEFT     MOVE THE FORK TO THE LEFT
# 7               ROTATE THE SPOON              ROTATE THE SPOON
# 8                    LUSA PHONAP                THIS IS A FOWN
# 9                THIS IS A SPOON               THIS IS A SPOON
# 10   MOVE THE PHONE TO THE RIGHT           MOVE THE PHONE DOWN
# 11                THIS IS A FORK                THIS IS A FORK
# 12    MOVE THE FORK TO THE RIGHT    MOVE THE FORK TO THE RIGHT
# 13               THIS IS A PHONE               THIS IS A PHONE
# 14    MOVE THE PHONE TO THE LEFT           MOVE THE PHONE DOWN
# 15               THIS IS A SPOON               THIS IS A SPOON
# 16             MOVE THE SPOON UP             MOVE THE SPOON UP
# 17               THIS IS A PHONE                 THIS IS A PEN
# 18               THIS IS A SPOON               THIS IS A FFORK
# 19               THIS IS A FORRK                THIS IS A FORK
# 20      OVED THE PAN TO THE LEFT      OVED THE PAN TO THE LEFT
# 21                THIS IS A FORK                THIS IS A FORK
# 22               THIS IS A KNIFE                 THIS IS A PEN
# 23                 THIS IS A PEN                 THIS IS A PEN
# 24                MO THE FORECOP     MOVE THE FORK TO THE LEFT
# 25              ROTATH THE KNIFE             MOVE THE PEN DOWN
# 26     MOVES THE PEN TO THE LEFT      LOOSE A PEN TO THE RIGHT
# 27              MOVED THE PHONAP             MOVE THE PHONE UP
# 28               OO THE FORE COP             OVE THE FORK DOWN
# 29               THIS IS A SPOON               THIS IS A SPOON
# 30               ROTATE THE FAWN                ROTATE THE FON
# 31  MOVED THE SPOON TO THE RIGHT    MOVE THE SPOON TO THE LEFT
# 32             MOVE THE SPOON UP             MOVE THE SPOON UP
# 33               THIS IS A PHONE                 THIS IS A PEN
# 34                ROTATE THE PEN                ROTATE THE PEN
# 35                THIS IS A FORK                THIS IS A FORK
# 36                THIS IS A FAWN                THIS IS A PHON
# 37                 THIS IS A PEN                 THIS IS A PEN
# 38               THIS IS A SPOON               THIS IS A SPOON
# 39              MOO THE KNIFE UP             MOVE THE KNIFE UP
# 40                 THIS IS A PEN                 THIS IS A PEN
# 41    MOVED THE FORK TO THE LEFT      OVE THE FORK TO THE LEFT
# 42              MOVE THE FOREGAP                THIS IS A FORK
# 43    MOVE THE KNIFE TO THE LEFT   MOVED THE KNIFE TO THE LEFT
# 44               THIS IS A PHONE               THIS IS A PHONE
# 45               THIS IS A KNIFE               THIS IS A KNIFE
# 46               THIS IS A PHONE    MOVE THE PHONE TO THE LEFT
# 47               THIS IS A KNIFE               THIS IS A PHONE
# 48                THIS IS A FORK                THIS IS A FORK
# 49    MOVE THE FALL TO THE RIGHT  MOVED THE PHONE TO THE RIGHT
# 50             MOVE THE SPOON UP             MOVE THE SPOON UP
# 51                THIS IS A FORK               THIS IS A KNIFE
# 52                THIS IS A FORK                THIS IS A FORK
# 53               THIS IS A SPERN               THIS IS A SPERN
# 54                MOVE THE KNIFE   MOVE THE KNIFE TO THE RIGHT
# 55               THIS IS A PHONE                THIS IS A FOWN
# 56                 THIS IS A PEN                 THIS IS A PEN
# 57               THIS IS A PHONE               THIS IS A SPOON
# 58               ROTADE THE FORK    MOVED THE FORK TO THE LEFT
# 59               THIS IS A KNIFE               THIS IS A KNIFE
# 60                THIS IS A FOWN                THIS IS A FOWN
# 61               THIS IS A SPOON               THIS IS A SPOON
# 62               THIS IS A KNIFE               THIS IS A KNIFE
# 63               THIS IS A SPOON               THIS IS A SPOON
# 64               THIS IS A SPOON               THIS IS A SPOON
# 65               THIS IS A SPERN               THIS IS A SPERM
# 66               THIS IS A SPOON               THIS IS A SPOON
# 67                    LUCE PANAP    MOVE THE KNIFE TO THE LEFT
# 68             MOVED THE FORECUP                THIS IS A FORK
# 69                 THIS IS A PEN                 THIS IS A PEN
# 70                    LUCE PANAP                 THIS IS A PEN
# 71    MOVED THE FORK TO THE LEFT      OVE THE FORK TO THE LEFT
# 72    MOVHE THE FORK TO THE LEFT    MOVED THE FORK TO THE LEFT
# 73   MOVE THE KNIFE TO THE RIGHT             MOVE THE KNIFE UP
# 74               THIS IS A KNIFE                 THIS IS A NIE
# 75             MOVE THE PEN DOWN              OVE THE PEN DOWN
# 76     MOVE THE FORK TO THE LEFT     MOVE THE FORK TO THE LEFT
# 77               THIS IS A PHONE                HIS IS A PHONE
# 78                THIS IS A FORK                THIS IS A FORK
# 79    MOVE THE KNIFE TO THE LEFT    MOVE THE FORK TO THE RIGHT
# 80               MOVE THE PENDOW             MOVE THE PEN DOWN
# 81               THIS IS A PHONE               THIS IS A PHONE
# 82             RO TAKE THE SPOON           MOVE THE SPOON DOWN
# 83   MOVE THE KNIFE TO THE RIGHT   MOVE THE KNIFE TO THE RIGHT
# 84               MOE THE PENKNOB     MOVE THE PEN TO THE RIGHT
# 85              WROAKE THE KNIFE               ROTATE THE NICE
# 86               THIS IS A PHONE               THIS IS A PHAWN
# 87        O THE PAN TO THE RIGHT      OVED THE PAN TO THE LEFT
# 88                 THIS IS A TAN                THIS IS A FARM
# 89                THIS IS A FOWN                 THIS IS A PEN
# 90              MOVED THE PHONUP             MOVE THE PHONE UP
# 91             MOVE THE SPOON UP            MOVE THE SPOON OUP
# 92               THIS IS A SPURN               THIS IS A SPOON
# 93               THIS IS A SPOON               THIS IS A SPOON
# 94                      MUCIFONA     OVES THE PEN TO THE RIGHT
# 95                THIS IS A FORK                THIS IS A FORK
# 96               THIS IS A KNIFE              ROTATE THE KNIFE
# 97                THIS IS A FORK                 THIS IS A FOR
# 98               THIS IS A KNIFE               THIS IS A KNIFE
# 99                THIS IS A FORK                 THIS IS A FOR

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_11_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_11_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0                            1
# 0     MOVE THE FORK TO THE RIGHT               THIS IS A FORK
# 1               ROTATE THE KNIFE              OVE THE KNIFE O
# 2                THIS IS A SPOON              THIS IS A SPOON
# 3     MOVE THE FORK TO THE RIGHT               THIS IS A FORK
# 4            MOVE THE SPOON DOWN             OOV THE SPONE UP
# 5                 HIS IS A SPURN              THIS IS A SPOON
# 6     MOVED THE FORK TO THE LEFT   OVED THE SPOON TO THE LEFT
# 7               ROTATE THE SPOON              THIS IS A SPOON
# 8                    LUSA PHONAP              THIS IS A PHONE
# 9                THIS IS A SPOON              THIS IS A SPOON
# 10   MOVE THE PHONE TO THE RIGHT          MOVE THE PHONE DOWN
# 11                THIS IS A FORK               THIS IS A FORK
# 12    MOVE THE FORK TO THE RIGHT               THIS IS A FORK
# 13               THIS IS A PHONE              THIS IS A PHONE
# 14    MOVE THE PHONE TO THE LEFT              THIS IS A PHONE
# 15               THIS IS A SPOON              THIS IS A SPOON
# 16             MOVE THE SPOON UP              THIS IS A SPOON
# 17               THIS IS A PHONE              THIS IS A SPOON
# 18               THIS IS A SPOON              THIS IS A SPOON
# 19               THIS IS A FORRK               THIS IS A FORK
# 20      OVED THE PAN TO THE LEFT     OVED THE PEN TO THE LEFT
# 21                THIS IS A FORK               THIS IS A FORK
# 22               THIS IS A KNIFE             OVE THE KNIFE UP
# 23                 THIS IS A PEN    OVE THE KNIFE TO THE LEFT
# 24                MO THE FORECOP               THIS IS A FORK
# 25              ROTATH THE KNIFE              OVE THE KNIFE O
# 26     MOVES THE PEN TO THE LEFT              THIS IS A KNIFE
# 27              MOVED THE PHONAP  MOVE THE PHONE TO THE RIGHT
# 28               OO THE FORE COP                O THE FEMDOWN
# 29               THIS IS A SPOON              THIS IS A SPOON
# 30               ROTATE THE FAWN              THIS IS A PHONE
# 31  MOVED THE SPOON TO THE RIGHT              THIS IS A SPOON
# 32             MOVE THE SPOON UP              THIS IS A SPOON
# 33               THIS IS A PHONE                THIS IS A PEN
# 34                ROTATE THE PEN               ROTATE THE PEN
# 35                THIS IS A FORK               THIS IS A FORK
# 36                THIS IS A FAWN              THIS IS A PHONE
# 37                 THIS IS A PEN              THIS IS A KNIFE
# 38               THIS IS A SPOON              THIS IS A SPOON
# 39              MOO THE KNIFE UP             OVE THE KNIFE UP
# 40                 THIS IS A PEN                THIS IS A PEN
# 41    MOVED THE FORK TO THE LEFT   MOVE THE FORK TO THE RIGHT
# 42              MOVE THE FOREGAP               THIS IS A FORK
# 43    MOVE THE KNIFE TO THE LEFT          OVED THE KNIFE DOWN
# 44               THIS IS A PHONE              THIS IS A PHONE
# 45               THIS IS A KNIFE              THIS IS A KNIFE
# 46               THIS IS A PHONE          MOVE THE PHONE DOWN
# 47               THIS IS A KNIFE              THIS IS A KNIFE
# 48                THIS IS A FORK               THIS IS A FORK
# 49    MOVE THE FALL TO THE RIGHT           OVE THE PHONE DOWN
# 50             MOVE THE SPOON UP              THIS IS A SPOON
# 51                THIS IS A FORK               THIS IS A FORK
# 52                THIS IS A FORK               THIS IS A FORK
# 53               THIS IS A SPERN              THIS IS A SPOON
# 54                MOVE THE KNIFE     MOVE THE PEN TO THE LEFT
# 55               THIS IS A PHONE               THIS IS A PHON
# 56                 THIS IS A PEN                THIS IS A PEN
# 57               THIS IS A PHONE              THIS IS A PHONE
# 58               ROTADE THE FORK               THIS IS A FORK
# 59               THIS IS A KNIFE              THIS IS A KNIFE
# 60                THIS IS A FOWN              THIS IS A PHONE
# 61               THIS IS A SPOON              THIS IS A SPOON
# 62               THIS IS A KNIFE           OVE THE KNIFE DOWN
# 63               THIS IS A SPOON              THIS IS A SPOON
# 64               THIS IS A SPOON              THIS IS A SPOON
# 65               THIS IS A SPERN              THIS IS A SPOON
# 66               THIS IS A SPOON              THIS IS A SPOON
# 67                    LUCE PANAP              THIS IS A KNIFE
# 68             MOVED THE FORECUP               THIS IS A FORK
# 69                 THIS IS A PEN                THIS IS A PEN
# 70                    LUCE PANAP           OVE THE KNIFE DOWN
# 71    MOVED THE FORK TO THE LEFT     OVE THE FORK TO THE LEFT
# 72    MOVHE THE FORK TO THE LEFT    MOVE THE FORK TO THE LEFT
# 73   MOVE THE KNIFE TO THE RIGHT              THIS IS A KNIFE
# 74               THIS IS A KNIFE              THIS IS A KNIFE
# 75             MOVE THE PEN DOWN             OVE THE PEN DOWN
# 76     MOVE THE FORK TO THE LEFT    MOVE THE FORK TO THE LEFT
# 77               THIS IS A PHONE              THIS IS A PHONE
# 78                THIS IS A FORK               THIS IS A FORK
# 79    MOVE THE KNIFE TO THE LEFT   OVE THE KNIFE TO THE RIGHT
# 80               MOVE THE PENDOW              MOVE THE PEN UP
# 81               THIS IS A PHONE              THIS IS A PHONE
# 82             RO TAKE THE SPOON             OVE THE SPOON UP
# 83   MOVE THE KNIFE TO THE RIGHT           OVE THE KNIFE DOWN
# 84               MOE THE PENKNOB            MOVE THE PEN DOWN
# 85              WROAKE THE KNIFE             OVE THE KNIFE UP
# 86               THIS IS A PHONE              THIS IS A PHONE
# 87        O THE PAN TO THE RIGHT     OVE THE KNIFT TO THE LEF
# 88                 THIS IS A TAN              THIS IS A KNIFE
# 89                THIS IS A FOWN              THIS IS A SPOON
# 90              MOVED THE PHONUP  MOVE THE PHONE TO THE RIGHT
# 91             MOVE THE SPOON UP              THIS IS A SPOON
# 92               THIS IS A SPURN              THIS IS A SPOON
# 93               THIS IS A SPOON              THIS IS A SPOON
# 94                      MUCIFONA              THIS IS A PHONE
# 95                THIS IS A FORK               THIS IS A FORK
# 96               THIS IS A KNIFE              THIS IS A KNIFE
# 97                THIS IS A FORK               THIS IS A FORK
# 98               THIS IS A KNIFE              THIS IS A KNIFE
# 99                THIS IS A FORK               THIS IS A FORK

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_12_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_12_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0                1
# 0     MOVE THE FORK TO THE RIGHT  THIS IS A KNIFE
# 1               ROTATE THE KNIFE  THIS IS A KNIFE
# 2                THIS IS A SPOON  THIS IS A KNIFE
# 3     MOVE THE FORK TO THE RIGHT   THIS IS A FOWN
# 4            MOVE THE SPOON DOWN    IS IS A SPOON
# 5                 HIS IS A SPURN  THIS IS A SPOON
# 6     MOVED THE FORK TO THE LEFT   THIS IS A FORK
# 7               ROTATE THE SPOON   THIS IS A FOWN
# 8                    LUSA PHONAP   THIS IS A FORK
# 9                THIS IS A SPOON  THIS IS A SPOON
# 10   MOVE THE PHONE TO THE RIGHT  THIS IS A KNIFE
# 11                THIS IS A FORK  THIS IS A KNIFE
# 12    MOVE THE FORK TO THE RIGHT   THIS IS A FOWN
# 13               THIS IS A PHONE  THIS IS A SPOON
# 14    MOVE THE PHONE TO THE LEFT  THIS IS A SPOON
# 15               THIS IS A SPOON  THIS IS A SPURN
# 16             MOVE THE SPOON UP  THIS IS A SPOON
# 17               THIS IS A PHONE  THIS IS A SPOON
# 18               THIS IS A SPOON  THIS IS A SPOON
# 19               THIS IS A FORRK  THIS IS A KNIFE
# 20      OVED THE PAN TO THE LEFT   THIS IS A FOWN
# 21                THIS IS A FORK   THIS IS A FOWN
# 22               THIS IS A KNIFE  THIS IS A KNIFE
# 23                 THIS IS A PEN  THIS IS A KNIFE
# 24                MO THE FORECOP   THIS IS A FOWN
# 25              ROTATH THE KNIFE  THIS IS A KNIFE
# 26     MOVES THE PEN TO THE LEFT  THIS IS A KNIFE
# 27              MOVED THE PHONAP  THIS IS A KNIFE
# 28               OO THE FORE COP  THIS IS A SPOON
# 29               THIS IS A SPOON  THIS IS A SPOON
# 30               ROTATE THE FAWN  THIS IS A SPOON
# 31  MOVED THE SPOON TO THE RIGHT    IS IS A SPOON
# 32             MOVE THE SPOON UP  THIS IS A SPOON
# 33               THIS IS A PHONE  THIS IS A KNIFE
# 34                ROTATE THE PEN  THIS IS A KNIFE
# 35                THIS IS A FORK  THIS IS A SPOON
# 36                THIS IS A FAWN  THIS IS A KNIFE
# 37                 THIS IS A PEN  THIS IS A KNIFE
# 38               THIS IS A SPOON  THIS IS A SPOON
# 39              MOO THE KNIFE UP   THIS IS A FOWN
# 40                 THIS IS A PEN  THIS IS A KNIFE
# 41    MOVED THE FORK TO THE LEFT  THIS IS A KNIFE
# 42              MOVE THE FOREGAP   THIS IS A FORK
# 43    MOVE THE KNIFE TO THE LEFT  THIS IS A KNIFE
# 44               THIS IS A PHONE   THIS IS A FOWN
# 45               THIS IS A KNIFE  THIS IS A KNIFE
# 46               THIS IS A PHONE  THIS IS A PHONE
# 47               THIS IS A KNIFE   THIS IS A FOWN
# 48                THIS IS A FORK  THIS IS A SPOON
# 49    MOVE THE FALL TO THE RIGHT  THIS IS A PHOAN
# 50             MOVE THE SPOON UP  THIS IS A KNIFE
# 51                THIS IS A FORK  THIS IS A KNIFE
# 52                THIS IS A FORK  THIS IS A FOUND
# 53               THIS IS A SPERN  THIS IS A SPOON
# 54                MOVE THE KNIFE  THIS IS A KNIFE
# 55               THIS IS A PHONE   THIS IS A FOWN
# 56                 THIS IS A PEN  THIS IS A KNIFE
# 57               THIS IS A PHONE  THIS IS A PHONE
# 58               ROTADE THE FORK   THIS IS A FORK
# 59               THIS IS A KNIFE  THIS IS A KNIFE
# 60                THIS IS A FOWN  THIS IS A FOUND
# 61               THIS IS A SPOON  THIS IS A SPOON
# 62               THIS IS A KNIFE  THIS IS A KNIFE
# 63               THIS IS A SPOON  THIS IS A SPOON
# 64               THIS IS A SPOON    IS IS A SPOON
# 65               THIS IS A SPERN  THIS IS A SPOON
# 66               THIS IS A SPOON   THIS IS A FORK
# 67                    LUCE PANAP  THIS IS A KNIFE
# 68             MOVED THE FORECUP  THIS IS A KNIFE
# 69                 THIS IS A PEN  THIS IS A KNIFE
# 70                    LUCE PANAP  THIS IS A KNIFE
# 71    MOVED THE FORK TO THE LEFT  THIS IS A KNIFE
# 72    MOVHE THE FORK TO THE LEFT   THIS IS A FORK
# 73   MOVE THE KNIFE TO THE RIGHT  THIS IS A KNIFE
# 74               THIS IS A KNIFE  THIS IS A KNIFE
# 75             MOVE THE PEN DOWN   THIS IS A FOWN
# 76     MOVE THE FORK TO THE LEFT   THIS IS A FOWN
# 77               THIS IS A PHONE  THIS IS A KNIFE
# 78                THIS IS A FORK  THIS IS A SPOON
# 79    MOVE THE KNIFE TO THE LEFT  THIS IS A SPOON
# 80               MOVE THE PENDOW  THIS IS A KNIFE
# 81               THIS IS A PHONE  THIS IS A SPOON
# 82             RO TAKE THE SPOON  THIS IS A SPURN
# 83   MOVE THE KNIFE TO THE RIGHT  THIS IS A KNIFE
# 84               MOE THE PENKNOB   THIS IS A FOWN
# 85              WROAKE THE KNIFE  THIS IS A KNIFE
# 86               THIS IS A PHONE  THIS IS A PHONE
# 87        O THE PAN TO THE RIGHT   THIS IS A FOWN
# 88                 THIS IS A TAN  THIS IS A KNIFE
# 89                THIS IS A FOWN  THIS IS A SPOON
# 90              MOVED THE PHONUP  THIS IS A KNIFE
# 91             MOVE THE SPOON UP    IS IS A SPOON
# 92               THIS IS A SPURN    IS IS A SPOON
# 93               THIS IS A SPOON  THIS IS A SPOON
# 94                      MUCIFONA  THIS IS A FOUND
# 95                THIS IS A FORK   THIS IS A FORK
# 96               THIS IS A KNIFE  THIS IS A KNIFE
# 97                THIS IS A FORK  THIS IS A KNIFE
# 98               THIS IS A KNIFE  THIS IS A KNIFE
# 99                THIS IS A FORK   THIS IS A FOWN

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_13_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_13_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0                            1
# 0     MOVE THE FORK TO THE RIGHT   MOVE THE FORK TO THE RIGHT
# 1               ROTATE THE KNIFE              THIS IS A KNIFE
# 2                THIS IS A SPOON              THIS IS A SPOON
# 3     MOVE THE FORK TO THE RIGHT              MOVE THE PEN UP
# 4            MOVE THE SPOON DOWN          MOVE THE SPOON DOWN
# 5                 HIS IS A SPURN              THIS IS A SPERN
# 6     MOVED THE FORK TO THE LEFT    MOVE THE FORK TO THE LEFT
# 7               ROTATE THE SPOON             ROTATE THE SPOON
# 8                    LUSA PHONAP               THIS IS A FOWN
# 9                THIS IS A SPOON              THIS IS A SPERN
# 10   MOVE THE PHONE TO THE RIGHT             ROTATE THE PHONE
# 11                THIS IS A FORK               THIS IS A FORK
# 12    MOVE THE FORK TO THE RIGHT   MOVE THE FORK TO THE RIGHT
# 13               THIS IS A PHONE               ROTATE THE PEN
# 14    MOVE THE PHONE TO THE LEFT          MOVE THE PHONE DOWN
# 15               THIS IS A SPOON              THIS IS A SPOON
# 16             MOVE THE SPOON UP            MOVE THE SPOON UP
# 17               THIS IS A PHONE               THIS IS A FORK
# 18               THIS IS A SPOON               THIS IS A FORK
# 19               THIS IS A FORRK               THIS IS A FORK
# 20      OVED THE PAN TO THE LEFT     OVED THE PAN TO THE LEFT
# 21                THIS IS A FORK               THIS IS A FORK
# 22               THIS IS A KNIFE              THIS IS A KNIFE
# 23                 THIS IS A PEN              MOVE THE PEN UP
# 24                MO THE FORECOP             MOVE THE FOREGAP
# 25              ROTATH THE KNIFE              THIS IS A KNIFE
# 26     MOVES THE PEN TO THE LEFT              THIS IS A KNIFE
# 27              MOVED THE PHONAP             ROTATE THE PHONE
# 28               OO THE FORE COP          MOVE THE SPOON DOWN
# 29               THIS IS A SPOON              THIS IS A SPOON
# 30               ROTATE THE FAWN             ROTATE THE SPOON
# 31  MOVED THE SPOON TO THE RIGHT            MOVE THE SPOON UP
# 32             MOVE THE SPOON UP   MOVE THE SPOON TO THE LEFT
# 33               THIS IS A PHONE              THIS IS A PHONE
# 34                ROTATE THE PEN             ROTATE THE KNIFE
# 35                THIS IS A FORK               THIS IS A FORK
# 36                THIS IS A FAWN              THIS IS A PHONE
# 37                 THIS IS A PEN              THIS IS A KNIFE
# 38               THIS IS A SPOON              THIS IS A SPOON
# 39              MOO THE KNIFE UP              THIS IS A KNIFE
# 40                 THIS IS A PEN                THIS IS A PIN
# 41    MOVED THE FORK TO THE LEFT     OVE THE FORK TO THE LEFT
# 42              MOVE THE FOREGAP             MOVE THE FOREGAP
# 43    MOVE THE KNIFE TO THE LEFT   MOVE THE KNIFE TO THE LEFT
# 44               THIS IS A PHONE              THIS IS A PHONE
# 45               THIS IS A KNIFE                THIS IS A PEN
# 46               THIS IS A PHONE              THIS IS A SPOON
# 47               THIS IS A KNIFE              THIS IS A KNIFE
# 48                THIS IS A FORK               THIS IS A FORK
# 49    MOVE THE FALL TO THE RIGHT  MOVE THE PHONE TO THE RIGHT
# 50             MOVE THE SPOON UP            MOVE THE SPOON UP
# 51                THIS IS A FORK              THIS IS A SPOON
# 52                THIS IS A FORK                THIS IS A FOR
# 53               THIS IS A SPERN              THIS IS A SPERN
# 54                MOVE THE KNIFE   MOVE THE KNIFE TO THE LEFT
# 55               THIS IS A PHONE              THIS IS A PHONE
# 56                 THIS IS A PEN                THIS IS A PEN
# 57               THIS IS A PHONE              THIS IS A PHONE
# 58               ROTADE THE FORK           MOVE THE FORK DOWN
# 59               THIS IS A KNIFE              THIS IS A KNIFE
# 60                THIS IS A FOWN               THIS IS A PONE
# 61               THIS IS A SPOON              THIS IS A PHONE
# 62               THIS IS A KNIFE              THIS IS A KNIFE
# 63               THIS IS A SPOON              THIS IS A SPOON
# 64               THIS IS A SPOON              THIS IS A SPOON
# 65               THIS IS A SPERN               THIS IS A FORK
# 66               THIS IS A SPOON              THIS IS A KNIFE
# 67                    LUCE PANAP                   LUSE PENUP
# 68             MOVED THE FORECUP   MOVE THE FORK TO THE RIGHT
# 69                 THIS IS A PEN                THIS IS A PEN
# 70                    LUCE PANAP             OVE THE KNIFE UP
# 71    MOVED THE FORK TO THE LEFT   MOVE THE FORK TO THE RIGHT
# 72    MOVHE THE FORK TO THE LEFT             MOVE THE FORECUP
# 73   MOVE THE KNIFE TO THE RIGHT             MOO THE KNIFE UP
# 74               THIS IS A KNIFE              THIS IS A KNIFE
# 75             MOVE THE PEN DOWN      UE THE PEN TO THE RIGHT
# 76     MOVE THE FORK TO THE LEFT    MOVE THE FORK TO THE LEFT
# 77               THIS IS A PHONE              THIS IS A PHONE
# 78                THIS IS A FORK               THIS IS A FORK
# 79    MOVE THE KNIFE TO THE LEFT   MOVE THE KNIFE TO THE LEFT
# 80               MOVE THE PENDOW           MOVE THE PONE DOWN
# 81               THIS IS A PHONE              THIS IS A PHONE
# 82             RO TAKE THE SPOON                IS IS A SPOON
# 83   MOVE THE KNIFE TO THE RIGHT  MOVE THE KNIFE TO THE RIGHT
# 84               MOE THE PENKNOB            MOVE THE PEN DOWN
# 85              WROAKE THE KNIFE              ROTATE THE NIHE
# 86               THIS IS A PHONE              THIS IS A PHONE
# 87        O THE PAN TO THE RIGHT    OOVE THE PEN TO THE RIGHT
# 88                 THIS IS A TAN                THIS IS A PEN
# 89                THIS IS A FOWN               THIS IS A FORK
# 90              MOVED THE PHONUP             ROTATE THE PHONE
# 91             MOVE THE SPOON UP              MOVE THE PHO UP
# 92               THIS IS A SPURN              THIS IS A SPOON
# 93               THIS IS A SPOON              THIS IS A SPOON
# 94                      MUCIFONA                  LUDE PHONAP
# 95                THIS IS A FORK               THIS IS A FORK
# 96               THIS IS A KNIFE              THIS IS A KNIFE
# 97                THIS IS A FORK           MOVE THE FORK DOWN
# 98               THIS IS A KNIFE              THIS IS A KNIFE
# 99                THIS IS A FORK               THIS IS A FORK

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_14_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_14_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0                             1
# 0     MOVE THE FORK TO THE RIGHT    MOVE THE FORK TO THE RIGHT
# 1               ROTATE THE KNIFE             WROTATE THE KNIFE
# 2                THIS IS A SPOON               THIS IS A SPOON
# 3     MOVE THE FORK TO THE RIGHT    MOVE THE FORK TO THE RIGHT
# 4            MOVE THE SPOON DOWN           MOVE THE SPOON DOWN
# 5                 HIS IS A SPURN               THIS IS A SPERN
# 6     MOVED THE FORK TO THE LEFT              MOVE THE FORECAP
# 7               ROTATE THE SPOON              ROTATE THE SPOON
# 8                    LUSA PHONAP                THIS IS A PONE
# 9                THIS IS A SPOON               THIS IS A SPOON
# 10   MOVE THE PHONE TO THE RIGHT          MOVED THE PHUNE DOWN
# 11                THIS IS A FORK                THIS IS A FORK
# 12    MOVE THE FORK TO THE RIGHT                THIS IS A FORK
# 13               THIS IS A PHONE                THIS IS A FONE
# 14    MOVE THE PHONE TO THE LEFT             MOVE THE PHONE UP
# 15               THIS IS A SPOON               THIS IS A SPOON
# 16             MOVE THE SPOON UP   MOVE THE SPOON TO THE RIGHT
# 17               THIS IS A PHONE               THIS IS A PHONE
# 18               THIS IS A SPOON               THIS IS A SPOON
# 19               THIS IS A FORRK                THIS IS A FORK
# 20      OVED THE PAN TO THE LEFT      OVED THE PAN TO THE LEFT
# 21                THIS IS A FORK                THIS IS A FORK
# 22               THIS IS A KNIFE               THIS IS A KNIFE
# 23                 THIS IS A PEN                 THIS IS A PEN
# 24                MO THE FORECOP               MOE THE FORECOP
# 25              ROTATH THE KNIFE             WROTATE THE KNIFE
# 26     MOVES THE PEN TO THE LEFT       MOVES A PEN TO THE LEFT
# 27              MOVED THE PHONAP    MOVE THE PHONE TO THE LEFT
# 28               OO THE FORE COP            O THE THEPOON DOWN
# 29               THIS IS A SPOON               THIS IS A SPOON
# 30               ROTATE THE FAWN               ROTATE THE FAWN
# 31  MOVED THE SPOON TO THE RIGHT    MOVE THE SPOON TO THE LEFT
# 32             MOVE THE SPOON UP             MOVE THE SPOON UP
# 33               THIS IS A PHONE               THIS IS A PHONE
# 34                ROTATE THE PEN                ROTATE THE PEN
# 35                THIS IS A FORK                THIS IS A FORK
# 36                THIS IS A FAWN                THIS IS A PHON
# 37                 THIS IS A PEN                 THIS IS A PEN
# 38               THIS IS A SPOON               THIS IS A SPOON
# 39              MOO THE KNIFE UP               THIS IS A KNIFE
# 40                 THIS IS A PEN                 THIS IS A PEN
# 41    MOVED THE FORK TO THE LEFT    OVED THE FORK TO THE RIGHT
# 42              MOVE THE FOREGAP                 THIS IS A FOR
# 43    MOVE THE KNIFE TO THE LEFT   MOVED THE KNIFE TO THE LEFT
# 44               THIS IS A PHONE               THIS IS A PHONE
# 45               THIS IS A KNIFE                 THIS IS A PEN
# 46               THIS IS A PHONE                THIS IS A PONE
# 47               THIS IS A KNIFE               THIS IS A KNIFE
# 48                THIS IS A FORK                THIS IS A FORK
# 49    MOVE THE FALL TO THE RIGHT  MOVED THE PHONE TO THE RIGHT
# 50             MOVE THE SPOON UP             O  THE SPOON DOWN
# 51                THIS IS A FORK                THIS IS A FORK
# 52                THIS IS A FORK                THIS IS A FORK
# 53               THIS IS A SPERN               THIS IS A SPERM
# 54                MOVE THE KNIFE                MOVE THE KNIFE
# 55               THIS IS A PHONE               THIS IS A PHONE
# 56                 THIS IS A PEN                 THIS IS A PEN
# 57               THIS IS A PHONE               THIS IS A PHONE
# 58               ROTADE THE FORK               ROTAE THE FORRK
# 59               THIS IS A KNIFE               THIS IS A KNIFE
# 60                THIS IS A FOWN                THIS IS A FOWN
# 61               THIS IS A SPOON               THIS IS A SPOON
# 62               THIS IS A KNIFE               THIS IS A KNIFE
# 63               THIS IS A SPOON               THIS IS A SPOON
# 64               THIS IS A SPOON               THIS IS A SPOON
# 65               THIS IS A SPERN               THIS IS A SPERN
# 66               THIS IS A SPOON               THIS IS A SPOON
# 67                    LUCE PANAP                    LUSE PENUP
# 68             MOVED THE FORECUP             MOVED THE FORECUP
# 69                 THIS IS A PEN                 THIS IS A PEN
# 70                    LUCE PANAP                    LUSE PENUP
# 71    MOVED THE FORK TO THE LEFT               OV THE KNIFE UP
# 72    MOVHE THE FORK TO THE LEFT    MOVED THE FORK TO THE LEFT
# 73   MOVE THE KNIFE TO THE RIGHT    MOVE THE KNIFE TO THE LEFT
# 74               THIS IS A KNIFE               THIS IS A KNIFE
# 75             MOVE THE PEN DOWN              OVE THE PEN DOWN
# 76     MOVE THE FORK TO THE LEFT    MOTHE THE FORK TO THE LEFT
# 77               THIS IS A PHONE               THIS IS A PHONE
# 78                THIS IS A FORK                THIS IS A FORK
# 79    MOVE THE KNIFE TO THE LEFT    MOVE THE KNIFE TO THE LEFT
# 80               MOVE THE PENDOW             MOVE THE PEN DOWN
# 81               THIS IS A PHONE                THIS IS A FOWN
# 82             RO TAKE THE SPOON              O THIS IS A FORK
# 83   MOVE THE KNIFE TO THE RIGHT   MOVE THE KNIFE TO THE RIGHT
# 84               MOE THE PENKNOB               MOVE THE PEN UP
# 85              WROAKE THE KNIFE               ROTATE THE NIFE
# 86               THIS IS A PHONE                   IS IS A FAN
# 87        O THE PAN TO THE RIGHT       UE THE PEN TO THE RIGHT
# 88                 THIS IS A TAN                 THIS IS A PEN
# 89                THIS IS A FOWN               THIS IS A PHONE
# 90              MOVED THE PHONUP    MOVE THE PHONE TO THE LEFT
# 91             MOVE THE SPOON UP             MOVE THE SPOON AP
# 92               THIS IS A SPURN                HIS IS A SPOON
# 93               THIS IS A SPOON               THIS IS A SPOON
# 94                      MUCIFONA   OVES THE PHONE TO THE RIGHT
# 95                THIS IS A FORK                THIS IS A FORK
# 96               THIS IS A KNIFE               THIS IS A KNIFE
# 97                THIS IS A FORK                  IS IS A FORK
# 98               THIS IS A KNIFE               THIS IS A KNIFE
# 99                THIS IS A FORK                THIS IS A FORK

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_15_XTEST.npy', allow_pickle=True))
original_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_15_yTEST.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0                             1
# 0     MOVE THE FORK TO THE RIGHT      OVE THE FORK TO THE LIFT
# 1               ROTATE THE KNIFE     OVE THE KNIFE TO THE LEFT
# 2                THIS IS A SPOON               THIS IS A SPOON
# 3     MOVE THE FORK TO THE RIGHT              MOVE THE FORECAP
# 4            MOVE THE SPOON DOWN              OVES THE FORECUP
# 5                 HIS IS A SPURN               THIS IS A SPURN
# 6     MOVED THE FORK TO THE LEFT                MOVE THE FORCA
# 7               ROTATE THE SPOON              ROTATE THE SPOON
# 8                    LUSA PHONAP                THIS IS A FOWN
# 9                THIS IS A SPOON               THIS IS A SPOON
# 10   MOVE THE PHONE TO THE RIGHT               THIS IS A PHONE
# 11                THIS IS A FORK                THIS IS A FORK
# 12    MOVE THE FORK TO THE RIGHT     MOVE THE FORK TO THE LEFT
# 13               THIS IS A PHONE               THIS IS A PHONE
# 14    MOVE THE PHONE TO THE LEFT             MOVE THE PHONE UP
# 15               THIS IS A SPOON               THIS IS A SPOON
# 16             MOVE THE SPOON UP   MOVE THE SPOON TO THE RIGHT
# 17               THIS IS A PHONE               THIS IS A PHONE
# 18               THIS IS A SPOON               THIS IS A SPOON
# 19               THIS IS A FORRK                THIS IS A FORK
# 20      OVED THE PAN TO THE LEFT               OOVE THE PEN UP
# 21                THIS IS A FORK                THIS IS A FORK
# 22               THIS IS A KNIFE     MOE THE KNIFE TO THE LEFT
# 23                 THIS IS A PEN                 THIS IS A PEN
# 24                MO THE FORECOP               MOE THE FORECOP
# 25              ROTATH THE KNIFE     OVE THE KNIFE TO THE LEFT
# 26     MOVES THE PEN TO THE LEFT           MOVE THE KNIFE DOWN
# 27              MOVED THE PHONAP    MOVE THE PHONE TO THE LEFT
# 28               OO THE FORE COP             OVE THE FORK DOWN
# 29               THIS IS A SPOON               THIS IS A SPOON
# 30               ROTATE THE FAWN               ROTATE THE FAWN
# 31  MOVED THE SPOON TO THE RIGHT  MOVED THE SPOON TO THE RIGHT
# 32             MOVE THE SPOON UP   MOVE THE SPOON TO THE RIGHT
# 33               THIS IS A PHONE               THIS IS A PHONE
# 34                ROTATE THE PEN                ROTATE THE PEN
# 35                THIS IS A FORK                THIS IS A FORK
# 36                THIS IS A FAWN                    IS IS ANUG
# 37                 THIS IS A PEN             MOVE THE PEN DOWN
# 38               THIS IS A SPOON               THIS IS A SPOON
# 39              MOO THE KNIFE UP               THIS IS A KNIFE
# 40                 THIS IS A PEN                 THIS IS A PEN
# 41    MOVED THE FORK TO THE LEFT      OVE THE FORK TO THE LIFT
# 42              MOVE THE FOREGAP            MOVE THE FORK DOWN
# 43    MOVE THE KNIFE TO THE LEFT   MOVE THE KNIFE TO THE RIGHT
# 44               THIS IS A PHONE               THIS IS A PHONE
# 45               THIS IS A KNIFE                 THIS IS A PEN
# 46               THIS IS A PHONE               THIS IS A PHONE
# 47               THIS IS A KNIFE               THIS IS A KNIFE
# 48                THIS IS A FORK                THIS IS A FORK
# 49    MOVE THE FALL TO THE RIGHT                 IS IS A PHONE
# 50             MOVE THE SPOON UP   MOVE THE SPOON TO THE RIGHT
# 51                THIS IS A FORK               THIS IS A KNIFE
# 52                THIS IS A FORK                THIS IS A FORK
# 53               THIS IS A SPERN             MOVE THE SPOON UP
# 54                MOVE THE KNIFE               MOVE THE KNAPER
# 55               THIS IS A PHONE                THIS IS A FARM
# 56                 THIS IS A PEN                 THIS IS A TAN
# 57               THIS IS A PHONE               THIS IS A PHONE
# 58               ROTADE THE FORK               ROTADE THE FORK
# 59               THIS IS A KNIFE               THIS IS A KNIFE
# 60                THIS IS A FOWN                THIS IS A FOWN
# 61               THIS IS A SPOON               THIS IS A SPOON
# 62               THIS IS A KNIFE               THIS IS A KNIFE
# 63               THIS IS A SPOON               THIS IS A SPOON
# 64               THIS IS A SPOON               THIS IS A SPOON
# 65               THIS IS A SPERN               THIS IS A SPOON
# 66               THIS IS A SPOON               THIS IS A SPOON
# 67                    LUCE PANAP                  LOSE TENINOP
# 68             MOVED THE FORECUP            MOVE THE FORK DOWN
# 69                 THIS IS A PEN                 THIS IS A PEN
# 70                    LUCE PANAP              ROTATE THE KNIFE
# 71    MOVED THE FORK TO THE LEFT     OVE THE FORK TO THE LIGHT
# 72    MOVHE THE FORK TO THE LEFT    MOVE THE FORK TO THE RIGHT
# 73   MOVE THE KNIFE TO THE RIGHT               THIS IS A KNIFE
# 74               THIS IS A KNIFE               THIS IS A KNIFE
# 75             MOVE THE PEN DOWN       OVE THE PAN TO THE LEFT
# 76     MOVE THE FORK TO THE LEFT            MOVE THE FORK DOWN
# 77               THIS IS A PHONE               THIS IS A PHONE
# 78                THIS IS A FORK                THIS IS A FORK
# 79    MOVE THE KNIFE TO THE LEFT           MOVE THE KNIFE DOWN
# 80               MOVE THE PENDOW             MOVE THE PEN DOWN
# 81               THIS IS A PHONE               THIS IS A PHONE
# 82             RO TAKE THE SPOON                 IS IS A SPOON
# 83   MOVE THE KNIFE TO THE RIGHT               THIS IS A KNIFE
# 84               MOE THE PENKNOB               MOVE THE PENNOB
# 85              WROAKE THE KNIFE               ROTATE THE NICE
# 86               THIS IS A PHONE               THIS IS A PHAWN
# 87        O THE PAN TO THE RIGHT              OE THE PONE DOWN
# 88                 THIS IS A TAN                 THIS IS A PEN
# 89                THIS IS A FOWN               THIS IS A PHONE
# 90              MOVED THE PHONUP    MOVE THE PHONE TO THE LEFT
# 91             MOVE THE SPOON UP             MOVE THE SPOON UP
# 92               THIS IS A SPURN               THIS IS A SPOON
# 93               THIS IS A SPOON               THIS IS A SPOON
# 94                      MUCIFONA               THIS IS A PHOAN
# 95                THIS IS A FORK                THIS IS A FORK
# 96               THIS IS A KNIFE               THIS IS A KNIFE
# 97                THIS IS A FORK            MOVE THE FORK DOWN
# 98               THIS IS A KNIFE               THIS IS A KNIFE
# 99                THIS IS A FORK                THIS IS A FORK

# %% [markdown]
# # ================================================
# # double check: check the function against the original features - only artificial

# %%
predicted_features_original = pd.DataFrame(load('features/audio_wav2vec_features_0-14500_artificial_onlygood_converted2array.npy', allow_pickle=True))

for i in range(predicted_features_original.shape[0]):
    print(i, "-",tokenizer.batch_decode(torch.tensor([predicted_features_original.iloc[i]]))[0])
# Out:
# 0 - THIS IS A PEN
# 1 - THIS IS A PEN
# 2 - THIS IS A PEN
# 3 - THIS IS A PEN
# 4 - THIS IS A PEN
# 5 - THIS IS A PHONE
# 6 - THIS IS A PHONE
# 7 - THIS IS A PHONE
# 8 - THIS IS A PHONE
# 9 - THIS IS A PHONE
# 10 - THIS IS A SPOON
# 11 - THIS IS A SPOON
# 12 - THIS IS A SPOON
# 13 - THIS IS A SPOON
# 14 - THIS IS A SPOON
# 15 - THIS IS A KNIFE
# 16 - THIS IS A KNIFE
# 17 - THIS IS A KNIFE
# 18 - THIS IS A KNIFE
# 19 - THIS IS A KNIFE
# 20 - THIS IS A FORK
# 21 - THIS IS A FORK
# 22 - THIS IS A FORK
# 23 - THIS IS A FORK
# 24 - THIS IS A FORK
# 25 - MOVE THE PEN TO THE LEFT
# 26 - MOVE THE PEN TO THE RIGHT
# 27 - MOVE THE PEN UP
# 28 - MOVE THE PEN DOWN
# 29 - WROTATE THE PEN
# 30 - MOVE THE PHONE TO THE LEFT
# 31 - MOVE THE PHONE TO THE RIGHT
# 32 - MOVE THE PHONE UP
# 33 - MOVE THE PHONE DOWN
# 34 - ROTATE THE PHONE
# 35 - MOVE THE SPOON TO THE LEFT
# 36 - MOVE THE SPOON TO THE RIGHT
# 37 - MOVE THE SPOON UP
# 38 - MOVE THE SPOON DOWN
# 39 - RO TAKE THE SPOON
# 40 - MOVE THE KNIFE TO THE LEFT
# 41 - MOVE THE KNIFE TO THE RIGHT
# 42 - MOVE THE KNIFE UP
# 43 - MOVE THE KNIFE DOWN
# 44 - RO ATE THE KNIFE
# 45 - MOVE THE FORK TO THE LEFT
# 46 - MOVE THE FORK TO THE RIGHT
# 47 - MOVE THE FORECUP
# 48 - MOVE THE FORK DOWN
# 49 - ROTATE THE FORK
# 50 - THIS IS A PEN
# 51 - THIS IS A PEN
# 52 - THIS IS A PEN
# 53 - THIS IS A PEN
# 54 - THIS IS A PEN
# 55 - THIS IS A FONE
# 56 - THIS IS  A FOWN
# 57 - THIS IS A FONE
# 58 - THIS IS A PHONE
# 59 - THIS IS A PHONE
# 60 - THIS IS A SPOON
# 61 - THIS IS A SPOON
# 62 - THIS IS A SPOON
# 63 - THIS IS A SPOON
# 64 - THIS IS A SPOON
# 65 - THIS IS A KNIFE
# 66 - THIS IS A KNIFE
# 67 - THIS IS A KNIFE
# 68 - THIS IS A KNIFE
# 69 - THIS IS A KNIFE
# 70 - THIS IS A FORK
# 71 - THIS IS A FORK
# 72 - THIS IS A FORK
# 73 - THIS IS A FORK
# 74 - THIS IS A FORK
# 75 - MOTHE THE PEN TO THE LEFT
# 76 - MOVE THE PEN TO THE RIGHT
# 77 - MOE THE PENNOB
# 78 - MOVE THE PEN DOWN
# 79 - ROTATE THE PEN
# 80 - MOOVE THE PHONE TO THE LEFT
# 81 - MOVE THE PHONE TO THE RIGHT
# 82 - MOO THE PHOE KNOP
# 83 - MOVE THE PHONE DOWN
# 84 - ROTATE THE PHONE
# 85 - MOVED THE SPOON TO THE LEFT
# 86 - MOVE THE SPOON TO THE RIGHT
# 87 - MOVE THE SPOON UP
# 88 - MOOTH THE SPOON DOWN
# 89 - ROTATE THE SPOON
# 90 - MOOTHE THE KNIFE TO THE LEFT
# 91 - MOVE THE KNIFE TO THE RIGHT
# 92 - MOVE THE KNIFE UP
# 93 - MOOVE THE KNIFE DOWN
# 94 - ROTATE THE KNIFE
# 95 - MOVE THE FORK TO THE LEFT
# 96 - MOVE THE FORK TO THE RIGHT
# 97 - MOE THE FORECOP
# 98 - MOOTHE THE FORK DOWN
# 99 - ROTE THE FORK
# 100 - THIS IS A PEN
# 101 - THIS IS A PEN
# 102 - THIS IS A PEN
# 103 - THIS IS A PEN
# 104 - THIS IS A PEN
# 105 - THIS IS A PHOAN
# 106 - THIS IS A PHOAN
# 107 - THIS IS A PHOAM
# 108 - THIS IS A PHOAN
# 109 - THIS IS A PHOAN
# 110 - THIS IS A SPOON
# 111 - THIS IS A SPOON
# 112 - THIS IS A SPOON
# 113 - THIS IS A SPOON
# 114 - THIS IS A SPOON
# 115 - THIS IS A KNIFE
# 116 - THIS IS A KNIFE
# 117 - THIS IS A KNIFE
# 118 - THIS IS A KNIFE
# 119 - THIS IS A KNIFE
# 120 - THIS IS A FORK
# 121 - THIS IS A FORK
# 122 - THIS IS A FORK
# 123 - THIS IS A FORK
# 124 - THIS IS A FORK
# 125 - MOVE THE PAN TO THE LEFT
# 126 - MOVE THE PEN TO THE RIGHT
# 127 - MOVE THE PEN UP
# 128 - MOVE THE PEN DOWN
# 129 - ROTATE THE PEN
# 130 - MOVE THE PHONE TO THE LEFT
# 131 - MOVE  THE FON TO THE RIGHT
# 132 - MOVE THE PHONE UP
# 133 - MOVE THE PHONE DOWN
# 134 - ROTATE THE PHONE
# 135 - MOVE THE SPOON TO THE LEFT
# 136 - MOVE THE SPOON TO THE RIGHT
# 137 - MOVE THE SPOON UP
# 138 - MOVE THE SPOON DOWN
# 139 - ROTATE THE SPOON
# 140 - MOVE THE KNIFE TO THE LEFT
# 141 - MOVE THE KNIFE TO THE RIGHT
# 142 - MOVE THE KNIFE UP
# 143 - MOVE THE KNIFE DOWN
# 144 - ROTATE THE KNIFE
# 145 - MOVE THE FORK TO THE LEFT
# 146 - MOVE THE FORK TO THE RIGHT
# 147 - MOVE THE FORECUP
# 148 - MOVE THE ORT DOWN
# 149 - ROTATE THE FORK
# 150 - THIS IS A PEN
# 151 - THIS IS A PEN
# 152 - THIS IS A PEN
# 153 - THIS IS A PEN
# 154 - THIS IS A PEN
# 155 - THIS IS A FONE
# 156 - THIS IS A PHONE
# 157 - THIS IS A FONE
# 158 - THIS IS A PONE
# 159 - THIS IS A PONE
# 160 - THIS IS A SPERN
# 161 - THIS IS A SPERN
# 162 - THIS IS A SPERN
# 163 - THIS IS A SPORN
# 164 - THIS IS A SPORN
# 165 - THIS IS A KNIFE
# 166 - THIS IS A KNIFE
# 167 - THIS IS A KNIFE
# 168 - THIS IS A KNIFE
# 169 - THIS IS A KNIFE
# 170 - THIS IS A FOR
# 171 - THIS IS A FOR
# 172 - THIS IS A FOR
# 173 - THIS IS A FORK
# 174 - THIS IS A FORK
# 175 - MOVES THE PEN TO THE LEFT
# 176 - MOVES THE PEN TO THE RIGHT
# 177 - LUSE PENAP
# 178 - LOOSE THE PEN DOWN
# 179 - WROTATE THE PEN
# 180 - MOVES THE PHONE TO THE LEFT
# 181 - LOSE THE PHONE TO THE RIGHT
# 182 - MUVEEPHONE UP
# 183 - MOVES THE PHONE DOWN
# 184 - ROTETE TEPHONE
# 185 - MOVED THE SPOON TO THE LEFT
# 186 - MOVED THE SPOON TO THE RIGHT
# 187 - MOVED THE SPOON UP
# 188 - MOVED THE SCROON DOWN
# 189 - ROTATE THE SPOON
# 190 - LOOFE THE KNIFE TO THE LEFT
# 191 - LOVES THE KNIFE TO THE RIGHT
# 192 - MOVE THE KNAPER
# 193 - MOVE THE KNIFE DOWN
# 194 - ROTATE THE NIFE
# 195 - MOVE THE FORK TO THE LEFT
# 196 - MOVES THE FORK TO THE RIGHT
# 197 - MOVES THE FORECOP
# 198 - MOVES THE FORK DOWN
# 199 - ROTADE THE FORK
# 200 - THIS IS A PEN
# 201 - THIS IS A PEN
# 202 - THIS IS A PEN
# 203 - THIS IS A PEN
# 204 - THIS IS A PEN
# 205 - THIS IS A PHON
# 206 - THIS IS A FAWN
# 207 - THIS IS A PHONE
# 208 - THIS IS A PHONE
# 209 - THIS IS A PHONE
# 210 - IS IS A SPOON
# 211 - THIS IS A SPOON
# 212 - THIS IS A SPOON
# 213 - THIS IS A SPOON
# 214 - THIS IS A SPOON
# 215 - THIS IS A KNIFE
# 216 - THIS IS A KNIFE
# 217 - THIS IS A KNIFE
# 218 - THIS IS A KNIFE
# 219 - THIS IS A KNIFE
# 220 - THIS IS A FORK
# 221 - THIS IS A FORK
# 222 - THIS IS A FORK
# 223 - THIS IS A FORK
# 224 - THIS IS A FORK
# 225 - OVED THE PAN TO THE LEFT
# 226 - MOVE THE PEN TO THE RIGHT
# 227 - MOVE THE PEN UP
# 228 - OVE THE PEN DOWN
# 229 - ROTAKE THE PEN
# 230 - MOVED THE PHONE TO THE LEFT
# 231 - MOVED THE PHONE TO THE RIGHT
# 232 - OOV THE PHON UP
# 233 - OVE THE FALM DOWN
# 234 - ROUTAKE THE PHONE
# 235 - OOVED THE SPOON TO THE LEFT
# 236 - MOVED THE SPOON TO THE RIGHT
# 237 - MOVE THE SPOON UP
# 238 - OOVE THE SPOON DOWN
# 239 - RO TAKE THE SPOON
# 240 - MOVE THE KNIFE TO THE LEFT
# 241 - MOVE THE KNIFE TO THE RIGHT
# 242 - OO THE KNIFE UP
# 243 - OE THE KNIFE DOWN
# 244 - ROTATE THE KNIFE
# 245 - LOVE THE FORK TO THE LEFT
# 246 - MOVE THE FORK TO THE RIGHT
# 247 - OO THE FORECUP
# 248 - MOVE THE FORK DOWN
# 249 - ROU TAKE THE FORK
# 250 - THIS IS A PEN
# 251 - THIS IS A PEN
# 252 - THIS IS A PEN
# 253 - THIS IS A PEN
# 254 - THIS IS A PEN
# 255 - THIS IS A PHONE
# 256 - THIS IS A PHONE
# 257 - THIS IS A PHONE
# 258 - THIS IS A PHONE
# 259 - THIS IS A PHONE
# 260 - THIS IS A SPOON
# 261 - THIS IS A SPOON
# 262 - THIS IS A SPOON
# 263 - THIS IS A SPOON
# 264 - THIS IS A SPOON
# 265 - THIS IS A KNIFE
# 266 - THIS IS A KNIFE
# 267 - THIS IS A KNIFE
# 268 - THIS IS A KNIFE
# 269 - THIS IS A KNIFE
# 270 - THIS IS A FORK
# 271 - THIS IS A FORK
# 272 - THIS IS A FORK
# 273 - THIS IS A FORK
# 274 - THIS IS A FORK
# 275 - MOVE THE PEN TO THE LEFT
# 276 - MOVE THE PEN TO THE RIGHT
# 277 - MOVE THE PENNOP
# 278 - MOVE THE PEN DOWN
# 279 - ROTATHE THE PEN
# 280 - MOVE THE PHONE TO THE LEFT
# 281 - MOVE THE PHONE TO THE RIGHT
# 282 - MOVE THE PHONA
# 283 - MOVE THE FONE DOWN
# 284 - ROTATE THE PHONE
# 285 - MOVE THE SPOON TO THE LEFT
# 286 - MOVE THE SPOON TO THE RIGHT
# 287 - MOVE THE SPOONER
# 288 - MOVE THE SPOON DOWN
# 289 - ROTATE THE SPOON
# 290 - MOVE THE KNIFE TO THE LEFT
# 291 - MOVE THE KNIFE TO THE RIGHT
# 292 - MOVE THE KNIFE
# 293 - MOVE THE KNIFE DOWN
# 294 - ROTATE THE KNIFE
# 295 - MOVE THE FORK TO THE LEFT
# 296 - MOVE THE FORK TO THE RIGHT
# 297 - MOVE THE FORCA
# 298 - MOVE THE FORK DOWN
# 299 - ROTATE THE FORK
# 300 - THIS IS A PEN
# 301 - THIS IS A PEN
# 302 - THIS IS A PEN
# 303 - THIS IS A PEN
# 304 - THIS IS A PEN
# 305 - THIS IS A PHONE
# 306 - THIS IS A PHONE
# 307 - THIS IS A PHONE
# 308 - THIS IS A PHONE
# 309 - THIS IS A PHONE
# 310 - THIS IS A SPOON
# 311 - THIS IS A SPOON
# 312 - THIS IS A SPOON
# 313 - THIS IS A SPOON
# 314 - THIS IS A SPOON
# 315 - THIS IS A KNIFE
# 316 - THIS IS A KNIFE
# 317 - THIS IS A KNIFE
# 318 - THIS IS A KNIFE
# 319 - THIS IS A KNIFE
# 320 - THIS IS A FORK
# 321 - THIS IS A FORK
# 322 - THIS IS A FORK
# 323 - THIS IS A FORK
# 324 - THIS IS A FORK
# 325 - OVEDTEN TO  LEFT
# 326 - MOVE THE PEN TO THE RIGHT
# 327 - MOVE THE PEN UP
# 328 - MOVE THE PEN DOWN
# 329 - ROTATE THE PEN
# 330 - MOVE THE PHONE TO THE LEFT
# 331 - MOVE THE PHONE TO THE RIGHT
# 332 - MOVE THE PHONE UP
# 333 - MOVE THE PHONE DOWN
# 334 - ROTATE THE PHONE
# 335 - MOVED THE SPOON TO THE LEFT
# 336 - MOVE THE SPOON TO THE RIGHT
# 337 - MOVE THE SPOON UP
# 338 - MOVE THE SPOON DOWN
# 339 - ROTATE THE SPOON
# 340 - OVHE THE KNIFE TO E LEFT
# 341 - MOVE THE KNIFE TO THE RIGHT
# 342 - MOVE THE KNIFE UP
# 343 - MOVE THE KNIFE DOWN
# 344 - ROTATE THE KNIFE
# 345 - MOVE THE FORK TO THE LEFT
# 346 - MOVE THE FORK TO THE RIGHT
# 347 - MOVE THE FORE UP
# 348 - MOVE THE FORK DOWN
# 349 - ROTATE THE FORK
# 350 - THIS IS A PEN
# 351 - THIS IS A PEN
# 352 - THIS IS A PEN
# 353 - THIS IS A PEN
# 354 - THIS IS A PEN
# 355 - THIS IS A PHONE
# 356 - THIS IS A PHONE
# 357 - THIS IS A PHONE
# 358 - THIS IS A PHONE
# 359 - THIS IS A PHONE
# 360 - THIS IS A SPOON
# 361 - THIS IS A SPOON
# 362 - THIS IS A SPOON
# 363 - THIS IS A SPOON
# 364 - THIS IS A SPOON
# 365 - THIS IS A KNIFE
# 366 - THIS IS A KNIFE
# 367 - THIS IS A KNIFE
# 368 - THIS IS A KNIFE
# 369 - THIS IS A KNIFE
# 370 - THIS IS A FORK
# 371 - THIS IS A FORK
# 372 - THIS IS A FORK
# 373 - THIS IS A FORK
# 374 - THIS IS A FORK
# 375 - MOVED THE PEN TO THE LEFT
# 376 - MOVE THE PEN TO THE RIGHT
# 377 - MOVE THE PEN UP
# 378 - MOVE THE PEN DOWN
# 379 - ROT ADE THE PEN
# 380 - MOVE THE FOUND TO THE LEFT
# 381 - MOVE THE PHONE TO THE RIGHT
# 382 - MOVED THE PHONE UP
# 383 - MOVED THE PHONE DOWN
# 384 - ROTADE THE PHONE
# 385 - MOVED THE SPOON TO THE LEFT
# 386 - MOVE THE SPOON TO THE RIGHT
# 387 - MOVED THE SPOON UP
# 388 - MOVE THE SPOON DOWN
# 389 - ROTADE THE SPOON
# 390 - MOVE THE KNIFE TO THE LEFT
# 391 - MOVE THE KNIFE TO THE RIGHT
# 392 - MOVE THE KNIFE AP
# 393 - MOVE THE KNIFE DOWN
# 394 - ROTADE THE KNIFE
# 395 - MOVED THE FORK TO THE LEFT
# 396 - MOVE THE FORK TO THE RIGHT
# 397 - MOVED THE FORECUP
# 398 - MOVE THE FORK DOWN
# 399 - ROTADE THE FORK
# 400 - THIS IS A PEN
# 401 - THIS IS A PEN
# 402 - THIS IS A PEN
# 403 - THIS IS A PEN
# 404 - THIS IS A PEN
# 405 - THIS IS A FOND
# 406 - THIS IS A FOUND
# 407 - THIS IS A FONE
# 408 - THIS IS A PHONE
# 409 - THIS IS A PHONE
# 410 - THIS IS A SPERN
# 411 - THIS IS A SPERN
# 412 - THIS IS A SPURN
# 413 - THIS IS A SPOON
# 414 - THIS IS A SPOON
# 415 - THIS IS A KNIFE
# 416 - THIS IS A KNIFE
# 417 - THIS IS A KNIFE
# 418 - THIS IS A KNIFE
# 419 - THIS IS A KNIFE
# 420 - THIS IS A FOR
# 421 - THIS IS A FORK
# 422 - THIS IS A FORK
# 423 - THIS IS A FORK
# 424 - THIS IS A FORK
# 425 - MOVED THE PEN TO THE LEFT
# 426 - MOVE THE PEN TO THE RIGHT
# 427 - MOVE THE PENNA
# 428 - MOVE THE PEN DOWN
# 429 - ROTE TATE THE PEN
# 430 - MOVE THE PHONE TO THE LEFT
# 431 - MOVE THE PHONE TO THE RIGHT
# 432 - MOVED THE PHONUP
# 433 - MOVE THE PHONE DOWN
# 434 - ROTATE THE FAWN
# 435 - MOVED THE SPOON TO THE LEFT
# 436 - MOVE THE SPOON TO THE RIGHT
# 437 - MOVE THE SPOON UP
# 438 - MOVE THE SPOON DOWN
# 439 - ROTATE THE SPOON
# 440 - MOVED THE KNIFE TO THE LEFT
# 441 - MOVE THE KNIFE TO THE RIGHT
# 442 - MOVE THE KNIFE UP
# 443 - MOVE THE KNIFE DOWN
# 444 - ROTATE THE KNIFE
# 445 - MOVE THE FORK TO THE LEFT
# 446 - MOVE THE FORK TO THE RIGHT
# 447 - MOVE THE FORECUP
# 448 - MOVE THE FORK DOWN
# 449 - ROAD TATE THE FOR
# 450 - THIS IS A PEN
# 451 - THIS IS A PEN
# 452 - THIS IS A PEN
# 453 - THIS IS A PEN
# 454 - THIS IS A PEN
# 455 - THIS IS A PHONE
# 456 - THIS IS A PHONE
# 457 - THIS IS A PHONE
# 458 - THIS IS A PHONE
# 459 - THIS IS A PHONE
# 460 - THIS IS A SPOON
# 461 - THIS IS A SPOON
# 462 - THIS IS A SPOON
# 463 - THIS IS A SPOON
# 464 - THIS IS A SPOON
# 465 - THIS IS A KNIFE
# 466 - THIS IS A KNIFE
# 467 - THIS IS A KNIFE
# 468 - THIS IS A KNIFE
# 469 - THIS IS A KNIFE
# 470 - THIS IS A FORK
# 471 - THIS IS A FORK
# 472 - THIS IS A FORK
# 473 - THIS IS A FORK
# 474 - THIS IS A FORK
# 475 - MOVED THE PAN TO THE LEFT
# 476 - MOVE THE PAN TO THE RIGHT
# 477 - MOVE THE PEN UP
# 478 - MOVE THE PEN DOWN
# 479 - ROTATE THE PEN
# 480 - MOVE THE PHONE TO THE LEFT
# 481 - MOVE THE PHONE TO THE RIGHT
# 482 - MOVE THE PHONE UP
# 483 - MOVE THE PHONE DOWN
# 484 - ROTATE THE PHONE
# 485 - MOVE THE SPOON TO THE LEFT
# 486 - MOVE THE SPOON TO THE RIGHT
# 487 - MOVE THE SPOON UP
# 488 - MOVE THE SPOON DOWN
# 489 - ROTATE THE SPOON
# 490 - MOVE THE KNIFE TO THE LEFT
# 491 - MOVE THE KNIFE TO THE RIGHT
# 492 - MOVE THE KNIFE UP
# 493 - MOVE THE KNIFE DOWN
# 494 - ROTATE THE KNIFE
# 495 - MOVE THE FORK TO THE LEFT
# 496 - MOVE THE FORK TO THE RIGHT
# 497 - MOVE THE FORECUP
# 498 - MOVE THE FORK DOWN
# 499 - ROTATE THE FORK
# 500 - THIS IS A PEN
# 501 - THIS IS A PEN
# 502 - THIS IS A PEN
# 503 - THIS IS A PEN
# 504 - THIS IS A PEN
# 505 - THIS IS A PHONE
# 506 - THIS IS A PHONE
# 507 - THIS IS A PHONE
# 508 - THIS IS A PHONE
# 509 - THIS IS A PHONE
# 510 - THIS IS A SPOON
# 511 - THIS IS A SPOON
# 512 - THIS IS A SPOON
# 513 - THIS IS A SPOON
# 514 - THIS IS A SPOON
# 515 - THIS IS A KNIFE
# 516 - THIS IS A KNIFE
# 517 - THIS IS A KNIFE
# 518 - THIS IS A KNIFE
# 519 - THIS IS A KNIFE
# 520 - THIS IS A FORK
# 521 - THIS IS A FORK
# 522 - THIS IS A FORK
# 523 - THIS IS A FORK
# 524 - THIS IS A FORK
# 525 - MOVE THE PEN TO THE LEFT
# 526 - MOVE THE PEN TO THE RIGHT
# 527 - MOVE THE PEN UP
# 528 - MOVE THE PEN DOWN
# 529 - WROTATE THE PEN
# 530 - MOVE THE PHONE TO THE LEFT
# 531 - MOVE THE PHONE TO THE RIGHT
# 532 - MOVE THE PHONE UP
# 533 - MOVE THE PHONE DOWN
# 534 - ROTATE THE PHONE
# 535 - MOVE THE SPOON TO THE LEFT
# 536 - MOVE THE SPOON TO THE RIGHT
# 537 - MOVE THE SPOON UP
# 538 - MOVE THE SPOON DOWN
# 539 - RO TAKE THE SPOON
# 540 - MOVE THE KNIFE TO THE LEFT
# 541 - MOVE THE KNIFE TO THE RIGHT
# 542 - MOVE THE KNIFE UP
# 543 - MOVE THE KNIFE DOWN
# 544 - RO ATE THE KNIFE
# 545 - MOVE THE FORK TO THE LEFT
# 546 - MOVE THE FORK TO THE RIGHT
# 547 - MOVE THE FORECUP
# 548 - MOVE THE FORK DOWN
# 549 - ROTATE THE FORK
# 550 - THIS IS A PEN
# 551 - THIS IS A PEN
# 552 - THIS IS A PEN
# 553 - THIS IS A PEN
# 554 - THIS IS A PEN
# 555 - THIS IS A FONE
# 556 - THIS IS  A FOWN
# 557 - THIS IS A FONE
# 558 - THIS IS A PHONE
# 559 - THIS IS A PHONE
# 560 - THIS IS A SPOON
# 561 - THIS IS A SPOON
# 562 - THIS IS A SPOON
# 563 - THIS IS A SPOON
# 564 - THIS IS A SPOON
# 565 - THIS IS A KNIFE
# 566 - THIS IS A KNIFE
# 567 - THIS IS A KNIFE
# 568 - THIS IS A KNIFE
# 569 - THIS IS A KNIFE
# 570 - THIS IS A FORK
# 571 - THIS IS A FORK
# 572 - THIS IS A FORK
# 573 - THIS IS A FORK
# 574 - THIS IS A FORK
# 575 - MOTHE THE PEN TO THE LEFT
# 576 - MOVE THE PEN TO THE RIGHT
# 577 - MOE THE PENNOB
# 578 - MOVE THE PEN DOWN
# 579 - ROTATE THE PEN
# 580 - MOOVE THE PHONE TO THE LEFT
# 581 - MOVE THE PHONE TO THE RIGHT
# 582 - MOO THE PHOE KNOP
# 583 - MOVE THE PHONE DOWN
# 584 - ROTATE THE PHONE
# 585 - MOVED THE SPOON TO THE LEFT
# 586 - MOVE THE SPOON TO THE RIGHT
# 587 - MOVE THE SPOON UP
# 588 - MOOTH THE SPOON DOWN
# 589 - ROTATE THE SPOON
# 590 - MOOTHE THE KNIFE TO THE LEFT
# 591 - MOVE THE KNIFE TO THE RIGHT
# 592 - MOVE THE KNIFE UP
# 593 - MOOVE THE KNIFE DOWN
# 594 - ROTATE THE KNIFE
# 595 - MOVE THE FORK TO THE LEFT
# 596 - MOVE THE FORK TO THE RIGHT
# 597 - MOE THE FORECOP
# 598 - MOOTHE THE FORK DOWN
# 599 - ROTE THE FORK
# 600 - THIS IS A PEN
# 601 - THIS IS A PEN
# 602 - THIS IS A PEN
# 603 - THIS IS A PEN
# 604 - THIS IS A PEN
# 605 - THIS IS A PHOAN
# 606 - THIS IS A PHOAN
# 607 - THIS IS A PHOAM
# 608 - THIS IS A PHOAN
# 609 - THIS IS A PHOAN
# 610 - THIS IS A SPOON
# 611 - THIS IS A SPOON
# 612 - THIS IS A SPOON
# 613 - THIS IS A SPOON
# 614 - THIS IS A SPOON
# 615 - THIS IS A KNIFE
# 616 - THIS IS A KNIFE
# 617 - THIS IS A KNIFE
# 618 - THIS IS A KNIFE
# 619 - THIS IS A KNIFE
# 620 - THIS IS A FORK
# 621 - THIS IS A FORK
# 622 - THIS IS A FORK
# 623 - THIS IS A FORK
# 624 - THIS IS A FORK
# 625 - MOVE THE PAN TO THE LEFT
# 626 - MOVE THE PEN TO THE RIGHT
# 627 - MOVE THE PEN UP
# 628 - MOVE THE PEN DOWN
# 629 - ROTATE THE PEN
# 630 - MOVE THE PHONE TO THE LEFT
# 631 - MOVE  THE FON TO THE RIGHT
# 632 - MOVE THE PHONE UP
# 633 - MOVE THE PHONE DOWN
# 634 - ROTATE THE PHONE
# 635 - MOVE THE SPOON TO THE LEFT
# 636 - MOVE THE SPOON TO THE RIGHT
# 637 - MOVE THE SPOON UP
# 638 - MOVE THE SPOON DOWN
# 639 - ROTATE THE SPOON
# 640 - MOVE THE KNIFE TO THE LEFT
# 641 - MOVE THE KNIFE TO THE RIGHT
# 642 - MOVE THE KNIFE UP
# 643 - MOVE THE KNIFE DOWN
# 644 - ROTATE THE KNIFE
# 645 - MOVE THE FORK TO THE LEFT
# 646 - MOVE THE FORK TO THE RIGHT
# 647 - MOVE THE FORECUP
# 648 - MOVE THE ORT DOWN
# 649 - ROTATE THE FORK
# 650 - THIS IS A PEN
# 651 - THIS IS A PEN
# 652 - THIS IS A PEN
# 653 - THIS IS A PEN
# 654 - THIS IS A PEN
# 655 - THIS IS A FONE
# 656 - THIS IS A PHONE
# 657 - THIS IS A FONE
# 658 - THIS IS A PONE
# 659 - THIS IS A PONE
# 660 - THIS IS A SPERN
# 661 - THIS IS A SPERN
# 662 - THIS IS A SPERN
# 663 - THIS IS A SPORN
# 664 - THIS IS A SPORN
# 665 - THIS IS A KNIFE
# 666 - THIS IS A KNIFE
# 667 - THIS IS A KNIFE
# 668 - THIS IS A KNIFE
# 669 - THIS IS A KNIFE
# 670 - THIS IS A FOR
# 671 - THIS IS A FOR
# 672 - THIS IS A FOR
# 673 - THIS IS A FORK
# 674 - THIS IS A FORK
# 675 - MOVES THE PEN TO THE LEFT
# 676 - MOVES THE PEN TO THE RIGHT
# 677 - LUSE PENAP
# 678 - LOOSE THE PEN DOWN
# 679 - WROTATE THE PEN
# 680 - MOVES THE PHONE TO THE LEFT
# 681 - LOSE THE PHONE TO THE RIGHT
# 682 - MUVEEPHONE UP
# 683 - MOVES THE PHONE DOWN
# 684 - ROTETE TEPHONE
# 685 - MOVED THE SPOON TO THE LEFT
# 686 - MOVED THE SPOON TO THE RIGHT
# 687 - MOVED THE SPOON UP
# 688 - MOVED THE SCROON DOWN
# 689 - ROTATE THE SPOON
# 690 - LOOFE THE KNIFE TO THE LEFT
# 691 - LOVES THE KNIFE TO THE RIGHT
# 692 - MOVE THE KNAPER
# 693 - MOVE THE KNIFE DOWN
# 694 - ROTATE THE NIFE
# 695 - MOVE THE FORK TO THE LEFT
# 696 - MOVES THE FORK TO THE RIGHT
# 697 - MOVES THE FORECOP
# 698 - MOVES THE FORK DOWN
# 699 - ROTADE THE FORK
# 700 - THIS IS A PEN
# 701 - THIS IS A PEN
# 702 - THIS IS A PEN
# 703 - THIS IS A PEN
# 704 - THIS IS A PEN
# 705 - THIS IS A PHON
# 706 - THIS IS A FAWN
# 707 - THIS IS A PHONE
# 708 - THIS IS A PHONE
# 709 - THIS IS A PHONE
# 710 - IS IS A SPOON
# 711 - THIS IS A SPOON
# 712 - THIS IS A SPOON
# 713 - THIS IS A SPOON
# 714 - THIS IS A SPOON
# 715 - THIS IS A KNIFE
# 716 - THIS IS A KNIFE
# 717 - THIS IS A KNIFE
# 718 - THIS IS A KNIFE
# 719 - THIS IS A KNIFE
# 720 - THIS IS A FORK
# 721 - THIS IS A FORK
# 722 - THIS IS A FORK
# 723 - THIS IS A FORK
# 724 - THIS IS A FORK
# 725 - OVED THE PAN TO THE LEFT
# 726 - MOVE THE PEN TO THE RIGHT
# 727 - MOVE THE PEN UP
# 728 - OVE THE PEN DOWN
# 729 - ROTAKE THE PEN
# 730 - MOVED THE PHONE TO THE LEFT
# 731 - MOVED THE PHONE TO THE RIGHT
# 732 - OOV THE PHON UP
# 733 - OVE THE FALM DOWN
# 734 - ROUTAKE THE PHONE
# 735 - OOVED THE SPOON TO THE LEFT
# 736 - MOVED THE SPOON TO THE RIGHT
# 737 - MOVE THE SPOON UP
# 738 - OOVE THE SPOON DOWN
# 739 - RO TAKE THE SPOON
# 740 - MOVE THE KNIFE TO THE LEFT
# 741 - MOVE THE KNIFE TO THE RIGHT
# 742 - OO THE KNIFE UP
# 743 - OE THE KNIFE DOWN
# 744 - ROTATE THE KNIFE
# 745 - LOVE THE FORK TO THE LEFT
# 746 - MOVE THE FORK TO THE RIGHT
# 747 - OO THE FORECUP
# 748 - MOVE THE FORK DOWN
# 749 - ROU TAKE THE FORK
# 750 - THIS IS A PEN
# 751 - THIS IS A PEN
# 752 - THIS IS A PEN
# 753 - THIS IS A PEN
# 754 - THIS IS A PEN
# 755 - THIS IS A PHONE
# 756 - THIS IS A PHONE
# 757 - THIS IS A PHONE
# 758 - THIS IS A PHONE
# 759 - THIS IS A PHONE
# 760 - THIS IS A SPOON
# 761 - THIS IS A SPOON
# 762 - THIS IS A SPOON
# 763 - THIS IS A SPOON
# 764 - THIS IS A SPOON
# 765 - THIS IS A KNIFE
# 766 - THIS IS A KNIFE
# 767 - THIS IS A KNIFE
# 768 - THIS IS A KNIFE
# 769 - THIS IS A KNIFE
# 770 - THIS IS A FORK
# 771 - THIS IS A FORK
# 772 - THIS IS A FORK
# 773 - THIS IS A FORK
# 774 - THIS IS A FORK
# 775 - MOVE THE PEN TO THE LEFT
# 776 - MOVE THE PEN TO THE RIGHT
# 777 - MOVE THE PENNOP
# 778 - MOVE THE PEN DOWN
# 779 - ROTATHE THE PEN
# 780 - MOVE THE PHONE TO THE LEFT
# 781 - MOVE THE PHONE TO THE RIGHT
# 782 - MOVE THE PHONA
# 783 - MOVE THE FONE DOWN
# 784 - ROTATE THE PHONE
# 785 - MOVE THE SPOON TO THE LEFT
# 786 - MOVE THE SPOON TO THE RIGHT
# 787 - MOVE THE SPOONER
# 788 - MOVE THE SPOON DOWN
# 789 - ROTATE THE SPOON
# 790 - MOVE THE KNIFE TO THE LEFT
# 791 - MOVE THE KNIFE TO THE RIGHT
# 792 - MOVE THE KNIFE
# 793 - MOVE THE KNIFE DOWN
# 794 - ROTATE THE KNIFE
# 795 - MOVE THE FORK TO THE LEFT
# 796 - MOVE THE FORK TO THE RIGHT
# 797 - MOVE THE FORCA
# 798 - MOVE THE FORK DOWN
# 799 - ROTATE THE FORK
# 800 - THIS IS A PEN
# 801 - THIS IS A PEN
# 802 - THIS IS A PEN
# 803 - THIS IS A PEN
# 804 - THIS IS A PEN
# 805 - THIS IS A PHONE
# 806 - THIS IS A PHONE
# 807 - THIS IS A PHONE
# 808 - THIS IS A PHONE
# 809 - THIS IS A PHONE
# 810 - THIS IS A SPOON
# 811 - THIS IS A SPOON
# 812 - THIS IS A SPOON
# 813 - THIS IS A SPOON
# 814 - THIS IS A SPOON
# 815 - THIS IS A KNIFE
# 816 - THIS IS A KNIFE
# 817 - THIS IS A KNIFE
# 818 - THIS IS A KNIFE
# 819 - THIS IS A KNIFE
# 820 - THIS IS A FORK
# 821 - THIS IS A FORK
# 822 - THIS IS A FORK
# 823 - THIS IS A FORK
# 824 - THIS IS A FORK
# 825 - OVEDTEN TO  LEFT
# 826 - MOVE THE PEN TO THE RIGHT
# 827 - MOVE THE PEN UP
# 828 - MOVE THE PEN DOWN
# 829 - ROTATE THE PEN
# 830 - MOVE THE PHONE TO THE LEFT
# 831 - MOVE THE PHONE TO THE RIGHT
# 832 - MOVE THE PHONE UP
# 833 - MOVE THE PHONE DOWN
# 834 - ROTATE THE PHONE
# 835 - MOVED THE SPOON TO THE LEFT
# 836 - MOVE THE SPOON TO THE RIGHT
# 837 - MOVE THE SPOON UP
# 838 - MOVE THE SPOON DOWN
# 839 - ROTATE THE SPOON
# 840 - OVHE THE KNIFE TO E LEFT
# 841 - MOVE THE KNIFE TO THE RIGHT
# 842 - MOVE THE KNIFE UP
# 843 - MOVE THE KNIFE DOWN
# 844 - ROTATE THE KNIFE
# 845 - MOVE THE FORK TO THE LEFT
# 846 - MOVE THE FORK TO THE RIGHT
# 847 - MOVE THE FORE UP
# 848 - MOVE THE FORK DOWN
# 849 - ROTATE THE FORK
# 850 - THIS IS A PEN
# 851 - THIS IS A PEN
# 852 - THIS IS A PEN
# 853 - THIS IS A PEN
# 854 - THIS IS A PEN
# 855 - THIS IS A PHONE
# 856 - THIS IS A PHONE
# 857 - THIS IS A PHONE
# 858 - THIS IS A PHONE
# 859 - THIS IS A PHONE
# 860 - THIS IS A SPOON
# 861 - THIS IS A SPOON
# 862 - THIS IS A SPOON
# 863 - THIS IS A SPOON
# 864 - THIS IS A SPOON
# 865 - THIS IS A KNIFE
# 866 - THIS IS A KNIFE
# 867 - THIS IS A KNIFE
# 868 - THIS IS A KNIFE
# 869 - THIS IS A KNIFE
# 870 - THIS IS A FORK
# 871 - THIS IS A FORK
# 872 - THIS IS A FORK
# 873 - THIS IS A FORK
# 874 - THIS IS A FORK
# 875 - MOVED THE PEN TO THE LEFT
# 876 - MOVE THE PEN TO THE RIGHT
# 877 - MOVE THE PEN UP
# 878 - MOVE THE PEN DOWN
# 879 - ROT ADE THE PEN
# 880 - MOVE THE FOUND TO THE LEFT
# 881 - MOVE THE PHONE TO THE RIGHT
# 882 - MOVED THE PHONE UP
# 883 - MOVED THE PHONE DOWN
# 884 - ROTADE THE PHONE
# 885 - MOVED THE SPOON TO THE LEFT
# 886 - MOVE THE SPOON TO THE RIGHT
# 887 - MOVED THE SPOON UP
# 888 - MOVE THE SPOON DOWN
# 889 - ROTADE THE SPOON
# 890 - MOVE THE KNIFE TO THE LEFT
# 891 - MOVE THE KNIFE TO THE RIGHT
# 892 - MOVE THE KNIFE AP
# 893 - MOVE THE KNIFE DOWN
# 894 - ROTADE THE KNIFE
# 895 - MOVED THE FORK TO THE LEFT
# 896 - MOVE THE FORK TO THE RIGHT
# 897 - MOVED THE FORECUP
# 898 - MOVE THE FORK DOWN
# 899 - ROTADE THE FORK
# 900 - THIS IS A PEN
# 901 - THIS IS A PEN
# 902 - THIS IS A PEN
# 903 - THIS IS A PEN
# 904 - THIS IS A PEN
# 905 - THIS IS A FOND
# 906 - THIS IS A FOUND
# 907 - THIS IS A FONE
# 908 - THIS IS A PHONE
# 909 - THIS IS A PHONE
# 910 - THIS IS A SPERN
# 911 - THIS IS A SPERN
# 912 - THIS IS A SPURN
# 913 - THIS IS A SPOON
# 914 - THIS IS A SPOON
# 915 - THIS IS A KNIFE
# 916 - THIS IS A KNIFE
# 917 - THIS IS A KNIFE
# 918 - THIS IS A KNIFE
# 919 - THIS IS A KNIFE
# 920 - THIS IS A FOR
# 921 - THIS IS A FORK
# 922 - THIS IS A FORK
# 923 - THIS IS A FORK
# 924 - THIS IS A FORK
# 925 - MOVED THE PEN TO THE LEFT
# 926 - MOVE THE PEN TO THE RIGHT
# 927 - MOVE THE PENNA
# 928 - MOVE THE PEN DOWN
# 929 - ROTE TATE THE PEN
# 930 - MOVE THE PHONE TO THE LEFT
# 931 - MOVE THE PHONE TO THE RIGHT
# 932 - MOVED THE PHONUP
# 933 - MOVE THE PHONE DOWN
# 934 - ROTATE THE FAWN
# 935 - MOVED THE SPOON TO THE LEFT
# 936 - MOVE THE SPOON TO THE RIGHT
# 937 - MOVE THE SPOON UP
# 938 - MOVE THE SPOON DOWN
# 939 - ROTATE THE SPOON
# 940 - MOVED THE KNIFE TO THE LEFT
# 941 - MOVE THE KNIFE TO THE RIGHT
# 942 - MOVE THE KNIFE UP
# 943 - MOVE THE KNIFE DOWN
# 944 - ROTATE THE KNIFE
# 945 - MOVE THE FORK TO THE LEFT
# 946 - MOVE THE FORK TO THE RIGHT
# 947 - MOVE THE FORECUP
# 948 - MOVE THE FORK DOWN
# 949 - ROAD TATE THE FOR
# 950 - THIS IS A PEN
# 951 - THIS IS A PEN
# 952 - THIS IS A PEN
# 953 - THIS IS A PEN
# 954 - THIS IS A PEN
# 955 - THIS IS A PHONE
# 956 - THIS IS A PHONE
# 957 - THIS IS A PHONE
# 958 - THIS IS A PHONE
# 959 - THIS IS A PHONE
# 960 - THIS IS A SPOON
# 961 - THIS IS A SPOON
# 962 - THIS IS A SPOON
# 963 - THIS IS A SPOON
# 964 - THIS IS A SPOON
# 965 - THIS IS A KNIFE
# 966 - THIS IS A KNIFE
# 967 - THIS IS A KNIFE
# 968 - THIS IS A KNIFE
# 969 - THIS IS A KNIFE
# 970 - THIS IS A FORK
# 971 - THIS IS A FORK
# 972 - THIS IS A FORK
# 973 - THIS IS A FORK
# 974 - THIS IS A FORK
# 975 - MOVED THE PAN TO THE LEFT
# 976 - MOVE THE PAN TO THE RIGHT
# 977 - MOVE THE PEN UP
# 978 - MOVE THE PEN DOWN
# 979 - ROTATE THE PEN
# 980 - MOVE THE PHONE TO THE LEFT
# 981 - MOVE THE PHONE TO THE RIGHT
# 982 - MOVE THE PHONE UP
# 983 - MOVE THE PHONE DOWN
# 984 - ROTATE THE PHONE
# 985 - MOVE THE SPOON TO THE LEFT
# 986 - MOVE THE SPOON TO THE RIGHT
# 987 - MOVE THE SPOON UP
# 988 - MOVE THE SPOON DOWN
# 989 - ROTATE THE SPOON
# 990 - MOVE THE KNIFE TO THE LEFT
# 991 - MOVE THE KNIFE TO THE RIGHT
# 992 - MOVE THE KNIFE UP
# 993 - MOVE THE KNIFE DOWN
# 994 - ROTATE THE KNIFE
# 995 - MOVE THE FORK TO THE LEFT
# 996 - MOVE THE FORK TO THE RIGHT
# 997 - MOVE THE FORECUP
# 998 - MOVE THE FORK DOWN
# 999 - ROTATE THE FORK
# 1000 - THIS IS A PEN
# 1001 - THIS IS A PEN
# 1002 - THIS IS A PEN
# 1003 - THIS IS A PEN
# 1004 - THIS IS A PEN
# 1005 - THIS IS A PHONE
# 1006 - THIS IS A PHONE
# 1007 - THIS IS A PHONE
# 1008 - THIS IS A PHONE
# 1009 - THIS IS A PHONE
# 1010 - THIS IS A SPOON
# 1011 - THIS IS A SPOON
# 1012 - THIS IS A SPOON
# 1013 - THIS IS A SPOON
# 1014 - THIS IS A SPOON
# 1015 - THIS IS A KNIFE
# 1016 - THIS IS A KNIFE
# 1017 - THIS IS A KNIFE
# 1018 - THIS IS A KNIFE
# 1019 - THIS IS A KNIFE
# 1020 - THIS IS A FORK
# 1021 - THIS IS A FORK
# 1022 - THIS IS A FORK
# 1023 - THIS IS A FORK
# 1024 - THIS IS A FORK
# 1025 - MOVE THE PEN TO THE LEFT
# 1026 - MOVE THE PEN TO THE RIGHT
# 1027 - MOVE THE PEN UP
# 1028 - MOVE THE PEN DOWN
# 1029 - WROTATE THE PEN
# 1030 - MOVE THE PHONE TO THE LEFT
# 1031 - MOVE THE PHONE TO THE RIGHT
# 1032 - MOVE THE PHONE UP
# 1033 - MOVE THE PHONE DOWN
# 1034 - ROTATE THE PHONE
# 1035 - MOVE THE SPOON TO THE LEFT
# 1036 - MOVE THE SPOON TO THE RIGHT
# 1037 - MOVE THE SPOON UP
# 1038 - MOVE THE SPOON DOWN
# 1039 - RO TAKE THE SPOON
# 1040 - MOVE THE KNIFE TO THE LEFT
# 1041 - MOVE THE KNIFE TO THE RIGHT
# 1042 - MOVE THE KNIFE UP
# 1043 - MOVE THE KNIFE DOWN
# 1044 - RO ATE THE KNIFE
# 1045 - MOVE THE FORK TO THE LEFT
# 1046 - MOVE THE FORK TO THE RIGHT
# 1047 - MOVE THE FORECUP
# 1048 - MOVE THE FORK DOWN
# 1049 - ROTATE THE FORK
# 1050 - THIS IS A PEN
# 1051 - THIS IS A PEN
# 1052 - THIS IS A PEN
# 1053 - THIS IS A PEN
# 1054 - THIS IS A PEN
# 1055 - THIS IS A FONE
# 1056 - THIS IS  A FOWN
# 1057 - THIS IS A FONE
# 1058 - THIS IS A PHONE
# 1059 - THIS IS A PHONE
# 1060 - THIS IS A SPOON
# 1061 - THIS IS A SPOON
# 1062 - THIS IS A SPOON
# 1063 - THIS IS A SPOON
# 1064 - THIS IS A SPOON
# 1065 - THIS IS A KNIFE
# 1066 - THIS IS A KNIFE
# 1067 - THIS IS A KNIFE
# 1068 - THIS IS A KNIFE
# 1069 - THIS IS A KNIFE
# 1070 - THIS IS A FORK
# 1071 - THIS IS A FORK
# 1072 - THIS IS A FORK
# 1073 - THIS IS A FORK
# 1074 - THIS IS A FORK
# 1075 - MOTHE THE PEN TO THE LEFT
# 1076 - MOVE THE PEN TO THE RIGHT
# 1077 - MOE THE PENNOB
# 1078 - MOVE THE PEN DOWN
# 1079 - ROTATE THE PEN
# 1080 - MOOVE THE PHONE TO THE LEFT
# 1081 - MOVE THE PHONE TO THE RIGHT
# 1082 - MOO THE PHOE KNOP
# 1083 - MOVE THE PHONE DOWN
# 1084 - ROTATE THE PHONE
# 1085 - MOVED THE SPOON TO THE LEFT
# 1086 - MOVE THE SPOON TO THE RIGHT
# 1087 - MOVE THE SPOON UP
# 1088 - MOOTH THE SPOON DOWN
# 1089 - ROTATE THE SPOON
# 1090 - MOOTHE THE KNIFE TO THE LEFT
# 1091 - MOVE THE KNIFE TO THE RIGHT
# 1092 - MOVE THE KNIFE UP
# 1093 - MOOVE THE KNIFE DOWN
# 1094 - ROTATE THE KNIFE
# 1095 - MOVE THE FORK TO THE LEFT
# 1096 - MOVE THE FORK TO THE RIGHT
# 1097 - MOE THE FORECOP
# 1098 - MOOTHE THE FORK DOWN
# 1099 - ROTE THE FORK
# 1100 - THIS IS A PEN
# 1101 - THIS IS A PEN
# 1102 - THIS IS A PEN
# 1103 - THIS IS A PEN
# 1104 - THIS IS A PEN
# 1105 - THIS IS A PHOAN
# 1106 - THIS IS A PHOAN
# 1107 - THIS IS A PHOAM
# 1108 - THIS IS A PHOAN
# 1109 - THIS IS A PHOAN
# 1110 - THIS IS A SPOON
# 1111 - THIS IS A SPOON
# 1112 - THIS IS A SPOON
# 1113 - THIS IS A SPOON
# 1114 - THIS IS A SPOON
# 1115 - THIS IS A KNIFE
# 1116 - THIS IS A KNIFE
# 1117 - THIS IS A KNIFE
# 1118 - THIS IS A KNIFE
# 1119 - THIS IS A KNIFE
# 1120 - THIS IS A FORK
# 1121 - THIS IS A FORK
# 1122 - THIS IS A FORK
# 1123 - THIS IS A FORK
# 1124 - THIS IS A FORK
# 1125 - MOVE THE PAN TO THE LEFT
# 1126 - MOVE THE PEN TO THE RIGHT
# 1127 - MOVE THE PEN UP
# 1128 - MOVE THE PEN DOWN
# 1129 - ROTATE THE PEN
# 1130 - MOVE THE PHONE TO THE LEFT
# 1131 - MOVE  THE FON TO THE RIGHT
# 1132 - MOVE THE PHONE UP
# 1133 - MOVE THE PHONE DOWN
# 1134 - ROTATE THE PHONE
# 1135 - MOVE THE SPOON TO THE LEFT
# 1136 - MOVE THE SPOON TO THE RIGHT
# 1137 - MOVE THE SPOON UP
# 1138 - MOVE THE SPOON DOWN
# 1139 - ROTATE THE SPOON
# 1140 - MOVE THE KNIFE TO THE LEFT
# 1141 - MOVE THE KNIFE TO THE RIGHT
# 1142 - MOVE THE KNIFE UP
# 1143 - MOVE THE KNIFE DOWN
# 1144 - ROTATE THE KNIFE
# 1145 - MOVE THE FORK TO THE LEFT
# 1146 - MOVE THE FORK TO THE RIGHT
# 1147 - MOVE THE FORECUP
# 1148 - MOVE THE ORT DOWN
# 1149 - ROTATE THE FORK
# 1150 - THIS IS A PEN
# 1151 - THIS IS A PEN
# 1152 - THIS IS A PEN
# 1153 - THIS IS A PEN
# 1154 - THIS IS A PEN
# 1155 - THIS IS A FONE
# 1156 - THIS IS A PHONE
# 1157 - THIS IS A FONE
# 1158 - THIS IS A PONE
# 1159 - THIS IS A PONE
# 1160 - THIS IS A SPERN
# 1161 - THIS IS A SPERN
# 1162 - THIS IS A SPERN
# 1163 - THIS IS A SPORN
# 1164 - THIS IS A SPORN
# 1165 - THIS IS A KNIFE
# 1166 - THIS IS A KNIFE
# 1167 - THIS IS A KNIFE
# 1168 - THIS IS A KNIFE
# 1169 - THIS IS A KNIFE
# 1170 - THIS IS A FOR
# 1171 - THIS IS A FOR
# 1172 - THIS IS A FOR
# 1173 - THIS IS A FORK
# 1174 - THIS IS A FORK
# 1175 - MOVES THE PEN TO THE LEFT
# 1176 - MOVES THE PEN TO THE RIGHT
# 1177 - LUSE PENAP
# 1178 - LOOSE THE PEN DOWN
# 1179 - WROTATE THE PEN
# 1180 - MOVES THE PHONE TO THE LEFT
# 1181 - LOSE THE PHONE TO THE RIGHT
# 1182 - MUVEEPHONE UP
# 1183 - MOVES THE PHONE DOWN
# 1184 - ROTETE TEPHONE
# 1185 - MOVED THE SPOON TO THE LEFT
# 1186 - MOVED THE SPOON TO THE RIGHT
# 1187 - MOVED THE SPOON UP
# 1188 - MOVED THE SCROON DOWN
# 1189 - ROTATE THE SPOON
# 1190 - LOOFE THE KNIFE TO THE LEFT
# 1191 - LOVES THE KNIFE TO THE RIGHT
# 1192 - MOVE THE KNAPER
# 1193 - MOVE THE KNIFE DOWN
# 1194 - ROTATE THE NIFE
# 1195 - MOVE THE FORK TO THE LEFT
# 1196 - MOVES THE FORK TO THE RIGHT
# 1197 - MOVES THE FORECOP
# 1198 - MOVES THE FORK DOWN
# 1199 - ROTADE THE FORK
# 1200 - THIS IS A PEN
# 1201 - THIS IS A PEN
# 1202 - THIS IS A PEN
# 1203 - THIS IS A PEN
# 1204 - THIS IS A PEN
# 1205 - THIS IS A PHON
# 1206 - THIS IS A FAWN
# 1207 - THIS IS A PHONE
# 1208 - THIS IS A PHONE
# 1209 - THIS IS A PHONE
# 1210 - IS IS A SPOON
# 1211 - THIS IS A SPOON
# 1212 - THIS IS A SPOON
# 1213 - THIS IS A SPOON
# 1214 - THIS IS A SPOON
# 1215 - THIS IS A KNIFE
# 1216 - THIS IS A KNIFE
# 1217 - THIS IS A KNIFE
# 1218 - THIS IS A KNIFE
# 1219 - THIS IS A KNIFE
# 1220 - THIS IS A FORK
# 1221 - THIS IS A FORK
# 1222 - THIS IS A FORK
# 1223 - THIS IS A FORK
# 1224 - THIS IS A FORK
# 1225 - OVED THE PAN TO THE LEFT
# 1226 - MOVE THE PEN TO THE RIGHT
# 1227 - MOVE THE PEN UP
# 1228 - OVE THE PEN DOWN
# 1229 - ROTAKE THE PEN
# 1230 - MOVED THE PHONE TO THE LEFT
# 1231 - MOVED THE PHONE TO THE RIGHT
# 1232 - OOV THE PHON UP
# 1233 - OVE THE FALM DOWN
# 1234 - ROUTAKE THE PHONE
# 1235 - OOVED THE SPOON TO THE LEFT
# 1236 - MOVED THE SPOON TO THE RIGHT
# 1237 - MOVE THE SPOON UP
# 1238 - OOVE THE SPOON DOWN
# 1239 - RO TAKE THE SPOON
# 1240 - MOVE THE KNIFE TO THE LEFT
# 1241 - MOVE THE KNIFE TO THE RIGHT
# 1242 - OO THE KNIFE UP
# 1243 - OE THE KNIFE DOWN
# 1244 - ROTATE THE KNIFE
# 1245 - LOVE THE FORK TO THE LEFT
# 1246 - MOVE THE FORK TO THE RIGHT
# 1247 - OO THE FORECUP
# 1248 - MOVE THE FORK DOWN
# 1249 - ROU TAKE THE FORK
# 1250 - THIS IS A PEN
# 1251 - THIS IS A PEN
# 1252 - THIS IS A PEN
# 1253 - THIS IS A PEN
# 1254 - THIS IS A PEN
# 1255 - THIS IS A PHONE
# 1256 - THIS IS A PHONE
# 1257 - THIS IS A PHONE
# 1258 - THIS IS A PHONE
# 1259 - THIS IS A PHONE
# 1260 - THIS IS A SPOON
# 1261 - THIS IS A SPOON
# 1262 - THIS IS A SPOON
# 1263 - THIS IS A SPOON
# 1264 - THIS IS A SPOON
# 1265 - THIS IS A KNIFE
# 1266 - THIS IS A KNIFE
# 1267 - THIS IS A KNIFE
# 1268 - THIS IS A KNIFE
# 1269 - THIS IS A KNIFE
# 1270 - THIS IS A FORK
# 1271 - THIS IS A FORK
# 1272 - THIS IS A FORK
# 1273 - THIS IS A FORK
# 1274 - THIS IS A FORK
# 1275 - MOVE THE PEN TO THE LEFT
# 1276 - MOVE THE PEN TO THE RIGHT
# 1277 - MOVE THE PENNOP
# 1278 - MOVE THE PEN DOWN
# 1279 - ROTATHE THE PEN
# 1280 - MOVE THE PHONE TO THE LEFT
# 1281 - MOVE THE PHONE TO THE RIGHT
# 1282 - MOVE THE PHONA
# 1283 - MOVE THE FONE DOWN
# 1284 - ROTATE THE PHONE
# 1285 - MOVE THE SPOON TO THE LEFT
# 1286 - MOVE THE SPOON TO THE RIGHT
# 1287 - MOVE THE SPOONER
# 1288 - MOVE THE SPOON DOWN
# 1289 - ROTATE THE SPOON
# 1290 - MOVE THE KNIFE TO THE LEFT
# 1291 - MOVE THE KNIFE TO THE RIGHT
# 1292 - MOVE THE KNIFE
# 1293 - MOVE THE KNIFE DOWN
# 1294 - ROTATE THE KNIFE
# 1295 - MOVE THE FORK TO THE LEFT
# 1296 - MOVE THE FORK TO THE RIGHT
# 1297 - MOVE THE FORCA
# 1298 - MOVE THE FORK DOWN
# 1299 - ROTATE THE FORK
# 1300 - THIS IS A PEN
# 1301 - THIS IS A PEN
# 1302 - THIS IS A PEN
# 1303 - THIS IS A PEN
# 1304 - THIS IS A PEN
# 1305 - THIS IS A PHONE
# 1306 - THIS IS A PHONE
# 1307 - THIS IS A PHONE
# 1308 - THIS IS A PHONE
# 1309 - THIS IS A PHONE
# 1310 - THIS IS A SPOON
# 1311 - THIS IS A SPOON
# 1312 - THIS IS A SPOON
# 1313 - THIS IS A SPOON
# 1314 - THIS IS A SPOON
# 1315 - THIS IS A KNIFE
# 1316 - THIS IS A KNIFE
# 1317 - THIS IS A KNIFE
# 1318 - THIS IS A KNIFE
# 1319 - THIS IS A KNIFE
# 1320 - THIS IS A FORK
# 1321 - THIS IS A FORK
# 1322 - THIS IS A FORK
# 1323 - THIS IS A FORK
# 1324 - THIS IS A FORK
# 1325 - OVEDTEN TO  LEFT
# 1326 - MOVE THE PEN TO THE RIGHT
# 1327 - MOVE THE PEN UP
# 1328 - MOVE THE PEN DOWN
# 1329 - ROTATE THE PEN
# 1330 - MOVE THE PHONE TO THE LEFT
# 1331 - MOVE THE PHONE TO THE RIGHT
# 1332 - MOVE THE PHONE UP
# 1333 - MOVE THE PHONE DOWN
# 1334 - ROTATE THE PHONE
# 1335 - MOVED THE SPOON TO THE LEFT
# 1336 - MOVE THE SPOON TO THE RIGHT
# 1337 - MOVE THE SPOON UP
# 1338 - MOVE THE SPOON DOWN
# 1339 - ROTATE THE SPOON
# 1340 - OVHE THE KNIFE TO E LEFT
# 1341 - MOVE THE KNIFE TO THE RIGHT
# 1342 - MOVE THE KNIFE UP
# 1343 - MOVE THE KNIFE DOWN
# 1344 - ROTATE THE KNIFE
# 1345 - MOVE THE FORK TO THE LEFT
# 1346 - MOVE THE FORK TO THE RIGHT
# 1347 - MOVE THE FORE UP
# 1348 - MOVE THE FORK DOWN
# 1349 - ROTATE THE FORK
# 1350 - THIS IS A PEN
# 1351 - THIS IS A PEN
# 1352 - THIS IS A PEN
# 1353 - THIS IS A PEN
# 1354 - THIS IS A PEN
# 1355 - THIS IS A PHONE
# 1356 - THIS IS A PHONE
# 1357 - THIS IS A PHONE
# 1358 - THIS IS A PHONE
# 1359 - THIS IS A PHONE
# 1360 - THIS IS A SPOON
# 1361 - THIS IS A SPOON
# 1362 - THIS IS A SPOON
# 1363 - THIS IS A SPOON
# 1364 - THIS IS A SPOON
# 1365 - THIS IS A KNIFE
# 1366 - THIS IS A KNIFE
# 1367 - THIS IS A KNIFE
# 1368 - THIS IS A KNIFE
# 1369 - THIS IS A KNIFE
# 1370 - THIS IS A FORK
# 1371 - THIS IS A FORK
# 1372 - THIS IS A FORK
# 1373 - THIS IS A FORK
# 1374 - THIS IS A FORK
# 1375 - MOVED THE PEN TO THE LEFT
# 1376 - MOVE THE PEN TO THE RIGHT
# 1377 - MOVE THE PEN UP
# 1378 - MOVE THE PEN DOWN
# 1379 - ROT ADE THE PEN
# 1380 - MOVE THE FOUND TO THE LEFT
# 1381 - MOVE THE PHONE TO THE RIGHT
# 1382 - MOVED THE PHONE UP
# 1383 - MOVED THE PHONE DOWN
# 1384 - ROTADE THE PHONE
# 1385 - MOVED THE SPOON TO THE LEFT
# 1386 - MOVE THE SPOON TO THE RIGHT
# 1387 - MOVED THE SPOON UP
# 1388 - MOVE THE SPOON DOWN
# 1389 - ROTADE THE SPOON
# 1390 - MOVE THE KNIFE TO THE LEFT
# 1391 - MOVE THE KNIFE TO THE RIGHT
# 1392 - MOVE THE KNIFE AP
# 1393 - MOVE THE KNIFE DOWN
# 1394 - ROTADE THE KNIFE
# 1395 - MOVED THE FORK TO THE LEFT
# 1396 - MOVE THE FORK TO THE RIGHT
# 1397 - MOVED THE FORECUP
# 1398 - MOVE THE FORK DOWN
# 1399 - ROTADE THE FORK
# 1400 - THIS IS A PEN
# 1401 - THIS IS A PEN
# 1402 - THIS IS A PEN
# 1403 - THIS IS A PEN
# 1404 - THIS IS A PEN
# 1405 - THIS IS A FOND
# 1406 - THIS IS A FOUND
# 1407 - THIS IS A FONE
# 1408 - THIS IS A PHONE
# 1409 - THIS IS A PHONE
# 1410 - THIS IS A SPERN
# 1411 - THIS IS A SPERN
# 1412 - THIS IS A SPURN
# 1413 - THIS IS A SPOON
# 1414 - THIS IS A SPOON
# 1415 - THIS IS A KNIFE
# 1416 - THIS IS A KNIFE
# 1417 - THIS IS A KNIFE
# 1418 - THIS IS A KNIFE
# 1419 - THIS IS A KNIFE
# 1420 - THIS IS A FOR
# 1421 - THIS IS A FORK
# 1422 - THIS IS A FORK
# 1423 - THIS IS A FORK
# 1424 - THIS IS A FORK
# 1425 - MOVED THE PEN TO THE LEFT
# 1426 - MOVE THE PEN TO THE RIGHT
# 1427 - MOVE THE PENNA
# 1428 - MOVE THE PEN DOWN
# 1429 - ROTE TATE THE PEN
# 1430 - MOVE THE PHONE TO THE LEFT
# 1431 - MOVE THE PHONE TO THE RIGHT
# 1432 - MOVED THE PHONUP
# 1433 - MOVE THE PHONE DOWN
# 1434 - ROTATE THE FAWN
# 1435 - MOVED THE SPOON TO THE LEFT
# 1436 - MOVE THE SPOON TO THE RIGHT
# 1437 - MOVE THE SPOON UP
# 1438 - MOVE THE SPOON DOWN
# 1439 - ROTATE THE SPOON
# 1440 - MOVED THE KNIFE TO THE LEFT
# 1441 - MOVE THE KNIFE TO THE RIGHT
# 1442 - MOVE THE KNIFE UP
# 1443 - MOVE THE KNIFE DOWN
# 1444 - ROTATE THE KNIFE
# 1445 - MOVE THE FORK TO THE LEFT
# 1446 - MOVE THE FORK TO THE RIGHT
# 1447 - MOVE THE FORECUP
# 1448 - MOVE THE FORK DOWN
# 1449 - ROAD TATE THE FOR
# 1450 - THIS IS A PEN
# 1451 - THIS IS A PEN
# 1452 - THIS IS A PEN
# 1453 - THIS IS A PEN
# 1454 - THIS IS A PEN
# 1455 - THIS IS A PHONE
# 1456 - THIS IS A PHONE
# 1457 - THIS IS A PHONE
# 1458 - THIS IS A PHONE
# 1459 - THIS IS A PHONE
# 1460 - THIS IS A SPOON
# 1461 - THIS IS A SPOON
# 1462 - THIS IS A SPOON
# 1463 - THIS IS A SPOON
# 1464 - THIS IS A SPOON
# 1465 - THIS IS A KNIFE
# 1466 - THIS IS A KNIFE
# 1467 - THIS IS A KNIFE
# 1468 - THIS IS A KNIFE
# 1469 - THIS IS A KNIFE
# 1470 - THIS IS A FORK
# 1471 - THIS IS A FORK
# 1472 - THIS IS A FORK
# 1473 - THIS IS A FORK
# 1474 - THIS IS A FORK
# 1475 - MOVED THE PAN TO THE LEFT
# 1476 - MOVE THE PAN TO THE RIGHT
# 1477 - MOVE THE PEN UP
# 1478 - MOVE THE PEN DOWN
# 1479 - ROTATE THE PEN
# 1480 - MOVE THE PHONE TO THE LEFT
# 1481 - MOVE THE PHONE TO THE RIGHT
# 1482 - MOVE THE PHONE UP
# 1483 - MOVE THE PHONE DOWN
# 1484 - ROTATE THE PHONE
# 1485 - MOVE THE SPOON TO THE LEFT
# 1486 - MOVE THE SPOON TO THE RIGHT
# 1487 - MOVE THE SPOON UP
# 1488 - MOVE THE SPOON DOWN
# 1489 - ROTATE THE SPOON
# 1490 - MOVE THE KNIFE TO THE LEFT
# 1491 - MOVE THE KNIFE TO THE RIGHT
# 1492 - MOVE THE KNIFE UP
# 1493 - MOVE THE KNIFE DOWN
# 1494 - ROTATE THE KNIFE
# 1495 - MOVE THE FORK TO THE LEFT
# 1496 - MOVE THE FORK TO THE RIGHT
# 1497 - MOVE THE FORECUP
# 1498 - MOVE THE FORK DOWN
# 1499 - ROTATE THE FORK
# 1500 - THIS IS A PEN
# 1501 - THIS IS A PEN
# 1502 - THIS IS A PEN
# 1503 - THIS IS A PEN
# 1504 - THIS IS A PEN
# 1505 - THIS IS A PHONE
# 1506 - THIS IS A PHONE
# 1507 - THIS IS A PHONE
# 1508 - THIS IS A PHONE
# 1509 - THIS IS A PHONE
# 1510 - THIS IS A SPOON
# 1511 - THIS IS A SPOON
# 1512 - THIS IS A SPOON
# 1513 - THIS IS A SPOON
# 1514 - THIS IS A SPOON
# 1515 - THIS IS A KNIFE
# 1516 - THIS IS A KNIFE
# 1517 - THIS IS A KNIFE
# 1518 - THIS IS A KNIFE
# 1519 - THIS IS A KNIFE
# 1520 - THIS IS A FORK
# 1521 - THIS IS A FORK
# 1522 - THIS IS A FORK
# 1523 - THIS IS A FORK
# 1524 - THIS IS A FORK
# 1525 - MOVE THE PEN TO THE LEFT
# 1526 - MOVE THE PEN TO THE RIGHT
# 1527 - MOVE THE PEN UP
# 1528 - MOVE THE PEN DOWN
# 1529 - WROTATE THE PEN
# 1530 - MOVE THE PHONE TO THE LEFT
# 1531 - MOVE THE PHONE TO THE RIGHT
# 1532 - MOVE THE PHONE UP
# 1533 - MOVE THE PHONE DOWN
# 1534 - ROTATE THE PHONE
# 1535 - MOVE THE SPOON TO THE LEFT
# 1536 - MOVE THE SPOON TO THE RIGHT
# 1537 - MOVE THE SPOON UP
# 1538 - MOVE THE SPOON DOWN
# 1539 - RO TAKE THE SPOON
# 1540 - MOVE THE KNIFE TO THE LEFT
# 1541 - MOVE THE KNIFE TO THE RIGHT
# 1542 - MOVE THE KNIFE UP
# 1543 - MOVE THE KNIFE DOWN
# 1544 - RO ATE THE KNIFE
# 1545 - MOVE THE FORK TO THE LEFT
# 1546 - MOVE THE FORK TO THE RIGHT
# 1547 - MOVE THE FORECUP
# 1548 - MOVE THE FORK DOWN
# 1549 - ROTATE THE FORK
# 1550 - THIS IS A PEN
# 1551 - THIS IS A PEN
# 1552 - THIS IS A PEN
# 1553 - THIS IS A PEN
# 1554 - THIS IS A PEN
# 1555 - THIS IS A FONE
# 1556 - THIS IS  A FOWN
# 1557 - THIS IS A FONE
# 1558 - THIS IS A PHONE
# 1559 - THIS IS A PHONE
# 1560 - THIS IS A SPOON
# 1561 - THIS IS A SPOON
# 1562 - THIS IS A SPOON
# 1563 - THIS IS A SPOON
# 1564 - THIS IS A SPOON
# 1565 - THIS IS A KNIFE
# 1566 - THIS IS A KNIFE
# 1567 - THIS IS A KNIFE
# 1568 - THIS IS A KNIFE
# 1569 - THIS IS A KNIFE
# 1570 - THIS IS A FORK
# 1571 - THIS IS A FORK
# 1572 - THIS IS A FORK
# 1573 - THIS IS A FORK
# 1574 - THIS IS A FORK
# 1575 - MOTHE THE PEN TO THE LEFT
# 1576 - MOVE THE PEN TO THE RIGHT
# 1577 - MOE THE PENNOB
# 1578 - MOVE THE PEN DOWN
# 1579 - ROTATE THE PEN
# 1580 - MOOVE THE PHONE TO THE LEFT
# 1581 - MOVE THE PHONE TO THE RIGHT
# 1582 - MOO THE PHOE KNOP
# 1583 - MOVE THE PHONE DOWN
# 1584 - ROTATE THE PHONE
# 1585 - MOVED THE SPOON TO THE LEFT
# 1586 - MOVE THE SPOON TO THE RIGHT
# 1587 - MOVE THE SPOON UP
# 1588 - MOOTH THE SPOON DOWN
# 1589 - ROTATE THE SPOON
# 1590 - MOOTHE THE KNIFE TO THE LEFT
# 1591 - MOVE THE KNIFE TO THE RIGHT
# 1592 - MOVE THE KNIFE UP
# 1593 - MOOVE THE KNIFE DOWN
# 1594 - ROTATE THE KNIFE
# 1595 - MOVE THE FORK TO THE LEFT
# 1596 - MOVE THE FORK TO THE RIGHT
# 1597 - MOE THE FORECOP
# 1598 - MOOTHE THE FORK DOWN
# 1599 - ROTE THE FORK
# 1600 - THIS IS A PEN
# 1601 - THIS IS A PEN
# 1602 - THIS IS A PEN
# 1603 - THIS IS A PEN
# 1604 - THIS IS A PEN
# 1605 - THIS IS A PHOAN
# 1606 - THIS IS A PHOAN
# 1607 - THIS IS A PHOAM
# 1608 - THIS IS A PHOAN
# 1609 - THIS IS A PHOAN
# 1610 - THIS IS A SPOON
# 1611 - THIS IS A SPOON
# 1612 - THIS IS A SPOON
# 1613 - THIS IS A SPOON
# 1614 - THIS IS A SPOON
# 1615 - THIS IS A KNIFE
# 1616 - THIS IS A KNIFE
# 1617 - THIS IS A KNIFE
# 1618 - THIS IS A KNIFE
# 1619 - THIS IS A KNIFE
# 1620 - THIS IS A FORK
# 1621 - THIS IS A FORK
# 1622 - THIS IS A FORK
# 1623 - THIS IS A FORK
# 1624 - THIS IS A FORK
# 1625 - MOVE THE PAN TO THE LEFT
# 1626 - MOVE THE PEN TO THE RIGHT
# 1627 - MOVE THE PEN UP
# 1628 - MOVE THE PEN DOWN
# 1629 - ROTATE THE PEN
# 1630 - MOVE THE PHONE TO THE LEFT
# 1631 - MOVE  THE FON TO THE RIGHT
# 1632 - MOVE THE PHONE UP
# 1633 - MOVE THE PHONE DOWN
# 1634 - ROTATE THE PHONE
# 1635 - MOVE THE SPOON TO THE LEFT
# 1636 - MOVE THE SPOON TO THE RIGHT
# 1637 - MOVE THE SPOON UP
# 1638 - MOVE THE SPOON DOWN
# 1639 - ROTATE THE SPOON
# 1640 - MOVE THE KNIFE TO THE LEFT
# 1641 - MOVE THE KNIFE TO THE RIGHT
# 1642 - MOVE THE KNIFE UP
# 1643 - MOVE THE KNIFE DOWN
# 1644 - ROTATE THE KNIFE
# 1645 - MOVE THE FORK TO THE LEFT
# 1646 - MOVE THE FORK TO THE RIGHT
# 1647 - MOVE THE FORECUP
# 1648 - MOVE THE ORT DOWN
# 1649 - ROTATE THE FORK
# 1650 - THIS IS A PEN
# 1651 - THIS IS A PEN
# 1652 - THIS IS A PEN
# 1653 - THIS IS A PEN
# 1654 - THIS IS A PEN
# 1655 - THIS IS A FONE
# 1656 - THIS IS A PHONE
# 1657 - THIS IS A FONE
# 1658 - THIS IS A PONE
# 1659 - THIS IS A PONE
# 1660 - THIS IS A SPERN
# 1661 - THIS IS A SPERN
# 1662 - THIS IS A SPERN
# 1663 - THIS IS A SPORN
# 1664 - THIS IS A SPORN
# 1665 - THIS IS A KNIFE
# 1666 - THIS IS A KNIFE
# 1667 - THIS IS A KNIFE
# 1668 - THIS IS A KNIFE
# 1669 - THIS IS A KNIFE
# 1670 - THIS IS A FOR
# 1671 - THIS IS A FOR
# 1672 - THIS IS A FOR
# 1673 - THIS IS A FORK
# 1674 - THIS IS A FORK
# 1675 - MOVES THE PEN TO THE LEFT
# 1676 - MOVES THE PEN TO THE RIGHT
# 1677 - LUSE PENAP
# 1678 - LOOSE THE PEN DOWN
# 1679 - WROTATE THE PEN
# 1680 - MOVES THE PHONE TO THE LEFT
# 1681 - LOSE THE PHONE TO THE RIGHT
# 1682 - MUVEEPHONE UP
# 1683 - MOVES THE PHONE DOWN
# 1684 - ROTETE TEPHONE
# 1685 - MOVED THE SPOON TO THE LEFT
# 1686 - MOVED THE SPOON TO THE RIGHT
# 1687 - MOVED THE SPOON UP
# 1688 - MOVED THE SCROON DOWN
# 1689 - ROTATE THE SPOON
# 1690 - LOOFE THE KNIFE TO THE LEFT
# 1691 - LOVES THE KNIFE TO THE RIGHT
# 1692 - MOVE THE KNAPER
# 1693 - MOVE THE KNIFE DOWN
# 1694 - ROTATE THE NIFE
# 1695 - MOVE THE FORK TO THE LEFT
# 1696 - MOVES THE FORK TO THE RIGHT
# 1697 - MOVES THE FORECOP
# 1698 - MOVES THE FORK DOWN
# 1699 - ROTADE THE FORK
# 1700 - THIS IS A PEN
# 1701 - THIS IS A PEN
# 1702 - THIS IS A PEN
# 1703 - THIS IS A PEN
# 1704 - THIS IS A PEN
# 1705 - THIS IS A PHON
# 1706 - THIS IS A FAWN
# 1707 - THIS IS A PHONE
# 1708 - THIS IS A PHONE
# 1709 - THIS IS A PHONE
# 1710 - IS IS A SPOON
# 1711 - THIS IS A SPOON
# 1712 - THIS IS A SPOON
# 1713 - THIS IS A SPOON
# 1714 - THIS IS A SPOON
# 1715 - THIS IS A KNIFE
# 1716 - THIS IS A KNIFE
# 1717 - THIS IS A KNIFE
# 1718 - THIS IS A KNIFE
# 1719 - THIS IS A KNIFE
# 1720 - THIS IS A FORK
# 1721 - THIS IS A FORK
# 1722 - THIS IS A FORK
# 1723 - THIS IS A FORK
# 1724 - THIS IS A FORK
# 1725 - OVED THE PAN TO THE LEFT
# 1726 - MOVE THE PEN TO THE RIGHT
# 1727 - MOVE THE PEN UP
# 1728 - OVE THE PEN DOWN
# 1729 - ROTAKE THE PEN
# 1730 - MOVED THE PHONE TO THE LEFT
# 1731 - MOVED THE PHONE TO THE RIGHT
# 1732 - OOV THE PHON UP
# 1733 - OVE THE FALM DOWN
# 1734 - ROUTAKE THE PHONE
# 1735 - OOVED THE SPOON TO THE LEFT
# 1736 - MOVED THE SPOON TO THE RIGHT
# 1737 - MOVE THE SPOON UP
# 1738 - OOVE THE SPOON DOWN
# 1739 - RO TAKE THE SPOON
# 1740 - MOVE THE KNIFE TO THE LEFT
# 1741 - MOVE THE KNIFE TO THE RIGHT
# 1742 - OO THE KNIFE UP
# 1743 - OE THE KNIFE DOWN
# 1744 - ROTATE THE KNIFE
# 1745 - LOVE THE FORK TO THE LEFT
# 1746 - MOVE THE FORK TO THE RIGHT
# 1747 - OO THE FORECUP
# 1748 - MOVE THE FORK DOWN
# 1749 - ROU TAKE THE FORK
# 1750 - THIS IS A PEN
# 1751 - THIS IS A PEN
# 1752 - THIS IS A PEN
# 1753 - THIS IS A PEN
# 1754 - THIS IS A PEN
# 1755 - THIS IS A PHONE
# 1756 - THIS IS A PHONE
# 1757 - THIS IS A PHONE
# 1758 - THIS IS A PHONE
# 1759 - THIS IS A PHONE
# 1760 - THIS IS A SPOON
# 1761 - THIS IS A SPOON
# 1762 - THIS IS A SPOON
# 1763 - THIS IS A SPOON
# 1764 - THIS IS A SPOON
# 1765 - THIS IS A KNIFE
# 1766 - THIS IS A KNIFE
# 1767 - THIS IS A KNIFE
# 1768 - THIS IS A KNIFE
# 1769 - THIS IS A KNIFE
# 1770 - THIS IS A FORK
# 1771 - THIS IS A FORK
# 1772 - THIS IS A FORK
# 1773 - THIS IS A FORK
# 1774 - THIS IS A FORK
# 1775 - MOVE THE PEN TO THE LEFT
# 1776 - MOVE THE PEN TO THE RIGHT
# 1777 - MOVE THE PENNOP
# 1778 - MOVE THE PEN DOWN
# 1779 - ROTATHE THE PEN
# 1780 - MOVE THE PHONE TO THE LEFT
# 1781 - MOVE THE PHONE TO THE RIGHT
# 1782 - MOVE THE PHONA
# 1783 - MOVE THE FONE DOWN
# 1784 - ROTATE THE PHONE
# 1785 - MOVE THE SPOON TO THE LEFT
# 1786 - MOVE THE SPOON TO THE RIGHT
# 1787 - MOVE THE SPOONER
# 1788 - MOVE THE SPOON DOWN
# 1789 - ROTATE THE SPOON
# 1790 - MOVE THE KNIFE TO THE LEFT
# 1791 - MOVE THE KNIFE TO THE RIGHT
# 1792 - MOVE THE KNIFE
# 1793 - MOVE THE KNIFE DOWN
# 1794 - ROTATE THE KNIFE
# 1795 - MOVE THE FORK TO THE LEFT
# 1796 - MOVE THE FORK TO THE RIGHT
# 1797 - MOVE THE FORCA
# 1798 - MOVE THE FORK DOWN
# 1799 - ROTATE THE FORK
# 1800 - THIS IS A PEN
# 1801 - THIS IS A PEN
# 1802 - THIS IS A PEN
# 1803 - THIS IS A PEN
# 1804 - THIS IS A PEN
# 1805 - THIS IS A PHONE
# 1806 - THIS IS A PHONE
# 1807 - THIS IS A PHONE
# 1808 - THIS IS A PHONE
# 1809 - THIS IS A PHONE
# 1810 - THIS IS A SPOON
# 1811 - THIS IS A SPOON
# 1812 - THIS IS A SPOON
# 1813 - THIS IS A SPOON
# 1814 - THIS IS A SPOON
# 1815 - THIS IS A KNIFE
# 1816 - THIS IS A KNIFE
# 1817 - THIS IS A KNIFE
# 1818 - THIS IS A KNIFE
# 1819 - THIS IS A KNIFE
# 1820 - THIS IS A FORK
# 1821 - THIS IS A FORK
# 1822 - THIS IS A FORK
# 1823 - THIS IS A FORK
# 1824 - THIS IS A FORK
# 1825 - OVEDTEN TO  LEFT
# 1826 - MOVE THE PEN TO THE RIGHT
# 1827 - MOVE THE PEN UP
# 1828 - MOVE THE PEN DOWN
# 1829 - ROTATE THE PEN
# 1830 - MOVE THE PHONE TO THE LEFT
# 1831 - MOVE THE PHONE TO THE RIGHT
# 1832 - MOVE THE PHONE UP
# 1833 - MOVE THE PHONE DOWN
# 1834 - ROTATE THE PHONE
# 1835 - MOVED THE SPOON TO THE LEFT
# 1836 - MOVE THE SPOON TO THE RIGHT
# 1837 - MOVE THE SPOON UP
# 1838 - MOVE THE SPOON DOWN
# 1839 - ROTATE THE SPOON
# 1840 - OVHE THE KNIFE TO E LEFT
# 1841 - MOVE THE KNIFE TO THE RIGHT
# 1842 - MOVE THE KNIFE UP
# 1843 - MOVE THE KNIFE DOWN
# 1844 - ROTATE THE KNIFE
# 1845 - MOVE THE FORK TO THE LEFT
# 1846 - MOVE THE FORK TO THE RIGHT
# 1847 - MOVE THE FORE UP
# 1848 - MOVE THE FORK DOWN
# 1849 - ROTATE THE FORK
# 1850 - THIS IS A PEN
# 1851 - THIS IS A PEN
# 1852 - THIS IS A PEN
# 1853 - THIS IS A PEN
# 1854 - THIS IS A PEN
# 1855 - THIS IS A PHONE
# 1856 - THIS IS A PHONE
# 1857 - THIS IS A PHONE
# 1858 - THIS IS A PHONE
# 1859 - THIS IS A PHONE
# 1860 - THIS IS A SPOON
# 1861 - THIS IS A SPOON
# 1862 - THIS IS A SPOON
# 1863 - THIS IS A SPOON
# 1864 - THIS IS A SPOON
# 1865 - THIS IS A KNIFE
# 1866 - THIS IS A KNIFE
# 1867 - THIS IS A KNIFE
# 1868 - THIS IS A KNIFE
# 1869 - THIS IS A KNIFE
# 1870 - THIS IS A FORK
# 1871 - THIS IS A FORK
# 1872 - THIS IS A FORK
# 1873 - THIS IS A FORK
# 1874 - THIS IS A FORK
# 1875 - MOVED THE PEN TO THE LEFT
# 1876 - MOVE THE PEN TO THE RIGHT
# 1877 - MOVE THE PEN UP
# 1878 - MOVE THE PEN DOWN
# 1879 - ROT ADE THE PEN
# 1880 - MOVE THE FOUND TO THE LEFT
# 1881 - MOVE THE PHONE TO THE RIGHT
# 1882 - MOVED THE PHONE UP
# 1883 - MOVED THE PHONE DOWN
# 1884 - ROTADE THE PHONE
# 1885 - MOVED THE SPOON TO THE LEFT
# 1886 - MOVE THE SPOON TO THE RIGHT
# 1887 - MOVED THE SPOON UP
# 1888 - MOVE THE SPOON DOWN
# 1889 - ROTADE THE SPOON
# 1890 - MOVE THE KNIFE TO THE LEFT
# 1891 - MOVE THE KNIFE TO THE RIGHT
# 1892 - MOVE THE KNIFE AP
# 1893 - MOVE THE KNIFE DOWN
# 1894 - ROTADE THE KNIFE
# 1895 - MOVED THE FORK TO THE LEFT
# 1896 - MOVE THE FORK TO THE RIGHT
# 1897 - MOVED THE FORECUP
# 1898 - MOVE THE FORK DOWN
# 1899 - ROTADE THE FORK
# 1900 - THIS IS A PEN
# 1901 - THIS IS A PEN
# 1902 - THIS IS A PEN
# 1903 - THIS IS A PEN
# 1904 - THIS IS A PEN
# 1905 - THIS IS A FOND
# 1906 - THIS IS A FOUND
# 1907 - THIS IS A FONE
# 1908 - THIS IS A PHONE
# 1909 - THIS IS A PHONE
# 1910 - THIS IS A SPERN
# 1911 - THIS IS A SPERN
# 1912 - THIS IS A SPURN
# 1913 - THIS IS A SPOON
# 1914 - THIS IS A SPOON
# 1915 - THIS IS A KNIFE
# 1916 - THIS IS A KNIFE
# 1917 - THIS IS A KNIFE
# 1918 - THIS IS A KNIFE
# 1919 - THIS IS A KNIFE
# 1920 - THIS IS A FOR
# 1921 - THIS IS A FORK
# 1922 - THIS IS A FORK
# 1923 - THIS IS A FORK
# 1924 - THIS IS A FORK
# 1925 - MOVED THE PEN TO THE LEFT
# 1926 - MOVE THE PEN TO THE RIGHT
# 1927 - MOVE THE PENNA
# 1928 - MOVE THE PEN DOWN
# 1929 - ROTE TATE THE PEN
# 1930 - MOVE THE PHONE TO THE LEFT
# 1931 - MOVE THE PHONE TO THE RIGHT
# 1932 - MOVED THE PHONUP
# 1933 - MOVE THE PHONE DOWN
# 1934 - ROTATE THE FAWN
# 1935 - MOVED THE SPOON TO THE LEFT
# 1936 - MOVE THE SPOON TO THE RIGHT
# ...
# 13895 - MOVE THE FORK TO THE LEFT
# 13896 - MOVE THE FORK TO THE RIGHT
# 13897 - MOVED THE FORECUP
# 13898 - MOVED THE FORK DOWN
# 13899 - ROTADE THE FORK
# 13900 - THIS IS A PEN
# 13901 - THIS IS A PEN
# 13902 - THIS IS A PEN
# 13903 - THIS IS A PEN
# 13904 - THIS IS A PEN
# 13905 - THIS IS A FONE
# 13906 - THIS IS A FOUND
# 13907 - THIS IS A FONE
# 13908 - THIS IS A PHONE
# 13909 - THIS IS A PHONE
# 13910 - THIS IS A SPERN
# 13911 - THIS IS A SPERN
# 13912 - THIS IS A SPURN
# 13913 - THIS IS A SPOON
# 13914 - THIS IS A SPURN
# 13915 - THIS IS A KNIFE
# 13916 - THIS IS A KNIFE
# 13917 - THIS IS A KNIFE
# 13918 - THIS IS A KNIFE
# 13919 - THIS IS A KNIFE
# 13920 - THIS IS A FOR
# 13921 - THIS IS A FOR
# 13922 - THIS IS A FORK
# 13923 - THIS IS A FORK
# 13924 - THIS IS A FORK
# 13925 - MOVED THE PEN TO THE LEFT
# 13926 - MOVE THE PEN TO THE RIGHT
# 13927 - MOVE THE PENNER
# 13928 - MOVE THE PEN DOWN
# 13929 - ROTE TATE THE PEN
# 13930 - MOVE THE PHONE TO THE LEFT
# 13931 - MOVE THE PHONE TO THE RIGHT
# 13932 - MOVED THE PHONAP
# 13933 - MOVE THE PHONE DOWN
# 13934 - ROTATE THE FAWN
# 13935 - MOVED THE SPOON TO THE LEFT
# 13936 - MOVE THE SPOON TO THE RIGHT
# 13937 - MOVE THE SPOONUP
# 13938 - MOVE THE SPOON DOWN
# 13939 - ROTATE THE SPOON
# 13940 - MOVED THE KNIFE TO THE LEFT
# 13941 - MOVE THE KNIFE TO THE RIGHT
# 13942 - MOVED THE KNIFE UP
# 13943 - MOVE THE KNIFE DOWN
# 13944 - ROTATE THE KNIFE
# 13945 - MOVE THE FORK TO THE LEFT
# 13946 - MOVE THE FORK TO THE RIGHT
# 13947 - MOVE THE FORECUP
# 13948 - MOVE THE FORK DOWN
# 13949 - ROAD TAKE THE FORK
# 13950 - THIS IS A PEN
# 13951 - THIS IS A PEN
# 13952 - THIS IS A PEN
# 13953 - THIS IS A PEN
# 13954 - THIS IS A PEN
# 13955 - THIS IS A PHONE
# 13956 - THIS IS A PHONE
# 13957 - THIS IS A PHONE
# 13958 - THIS IS A PHONE
# 13959 - THIS IS A PHONE
# 13960 - THIS IS A SPOON
# 13961 - THIS IS A SPOON
# 13962 - THIS IS A SPOON
# 13963 - THIS IS A SPOON
# 13964 - THIS IS A SPOON
# 13965 - THIS IS A KNIFE
# 13966 - THIS IS A KNIFE
# 13967 - THIS IS A KNIFE
# 13968 - THIS IS A KNIFE
# 13969 - THIS IS A KNIFE
# 13970 - THIS IS A FORK
# 13971 - THIS IS A FORK
# 13972 - THIS IS A FORK
# 13973 - THIS IS A FORK
# 13974 - THIS IS A FORK
# 13975 - MOVED THE PAN TO THE LEFT
# 13976 - MOVE THE PAN TO THE RIGHT
# 13977 - MOVE THE PEN UP
# 13978 - MOVE THE PEN DOWN
# 13979 - ROTATE THE PEN
# 13980 - MOVE THE PHONE TO THE LEFT
# 13981 - MOVE THE PHONE TO THE RIGHT
# 13982 - MOVE THE PHONE UP
# 13983 - MOVE THE PHONE DOWN
# 13984 - ROTATE THE PHONE
# 13985 - MOVE THE SPOON TO THE LEFT
# 13986 - MOVE THE SPOON TO THE RIGHT
# 13987 - MOVE THE SPOON UP
# 13988 - MOVE THE SPOON DOWN
# 13989 - ROTATE THE SPOON
# 13990 - MOVED THE KNIFE TO THE LEFT
# 13991 - MOVE THE KNIFE TO THE RIGHT
# 13992 - MOVE THE KNIFE UP
# 13993 - MOVE THE KNIFE DOWN
# 13994 - ROTATE THE KNIFE
# 13995 - MOVE THE FORK TO THE LEFT
# 13996 - MOVE THE FORK TO THE RIGHT
# 13997 - MOVE THE FORECUP
# 13998 - MOVE THE FORK DOWN
# 13999 - ROTATE THE FORK
# 14000 - THIS IS A PEN
# 14001 - THIS IS A PEN
# 14002 - THIS IS A PEN
# 14003 - THIS IS A PEN
# 14004 - THIS IS A PEN
# 14005 - THIS IS A PHONE
# 14006 - THIS IS A PHONE
# 14007 - THIS IS A PHONE
# 14008 - THIS IS A PHONE
# 14009 - THIS IS A PHONE
# 14010 - THIS IS A SPOON
# 14011 - THIS IS A SPOON
# 14012 - THIS IS A SPOON
# 14013 - THIS IS A SPOON
# 14014 - THIS IS A SPOON
# 14015 - THIS IS A KNIFE
# 14016 - THIS IS A KNIFE
# 14017 - THIS IS A KNIFE
# 14018 - THIS IS A KNIFE
# 14019 - THIS IS A KNIFE
# 14020 - THIS IS A FORK
# 14021 - THIS IS A FORK
# 14022 - THIS IS A FORK
# 14023 - THIS IS A FORK
# 14024 - THIS IS A FORK
# 14025 - MOVE THE PEN TO THE LEFT
# 14026 - MOVE THE PEN TO THE RIGHT
# 14027 - MOVE THE PEN UP
# 14028 - MOVE THE PEN DOWN
# 14029 - WROTATE THE PEN
# 14030 - MOVE THE PHONE TO THE LEFT
# 14031 - MOVE THE PHONE TO THE RIGHT
# 14032 - MOVE THE PHONE UP
# 14033 - MOVE THE PHONE DOWN
# 14034 - ROTATE THE PHONE
# 14035 - MOVE THE SPOON TO THE LEFT
# 14036 - MOVE THE SPOON TO THE RIGHT
# 14037 - MOVE THE SPOON UP
# 14038 - MOVE THE SPOON DOWN
# 14039 - ROTATE THE SPOON
# 14040 - MOVE THE KNIFE TO THE LEFT
# 14041 - MOVE THE KNIFE TO THE RIGHT
# 14042 - MOVE THE KNIFE UP
# 14043 - MOVE THE KNIFE DOWN
# 14044 - ROTATE THE KNIFE
# 14045 - MOVE THE FORK TO THE LEFT
# 14046 - MOVE THE FORK TO THE RIGHT
# 14047 - MOVE THE FORECUP
# 14048 - MOVE THE FORK DOWN
# 14049 - ROTATE THE FORK
# 14050 - THIS IS A PEN
# 14051 - THIS IS A PEN
# 14052 - THIS IS A PEN
# 14053 - THIS IS A PEN
# 14054 - THIS IS A PEN
# 14055 - THIS IS A PHONE
# 14056 - THIS IS A FOWN
# 14057 - THIS IS A FOWN
# 14058 - THIS IS A PHONE
# 14059 - THIS IS A PHONE
# 14060 - THIS IS A SPOON
# 14061 - THIS IS A SPOON
# 14062 - THIS IS A SPOON
# 14063 - THIS IS A SPOON
# 14064 - THIS IS A SPOON
# 14065 - THIS IS A KNIFE
# 14066 - THIS IS A KNIFE
# 14067 - THIS IS A KNIFE
# 14068 - THIS IS A KNIFE
# 14069 - THIS IS A KNIFE
# 14070 - THIS IS A FORK
# 14071 - THIS IS A FORK
# 14072 - THIS IS A FORK
# 14073 - THIS IS A FORK
# 14074 - THIS IS A FORK
# 14075 - MOTHE THE PEN TO THE LEFT
# 14076 - MOTHE THE PEN TO THE RIGHT
# 14077 - MOVE THE PENNOB
# 14078 - MOVE THE PEN DOWN
# 14079 - ROTATE THE PEN
# 14080 - MOOTE THE PHONE TO THE LEFT
# 14081 - MOVE THE PHONE TO THE RIGHT
# 14082 - MOO THE PHOE KNOP
# 14083 - MOVE THE PHONE DOWN
# 14084 - ROTATE THE PHONE
# 14085 - MOVED THE SPOON TO THE LEFT
# 14086 - MOVE THE SPOON TO THE RIGHT
# 14087 - MOO THE SPOON UP
# 14088 - MOOTH THE SPOON DOWN
# 14089 - ROTATE THE SPOON
# 14090 - MOOTH THE KNIFE TO THE LEFT
# 14091 - MOVE THE KNIFE TO THE RIGHT
# 14092 - MOVE THE KNIFE UP
# 14093 - MOOVE THE KNIFE DOWN
# 14094 - ROTATE THE KNIFE
# 14095 - MOTHE THE FORK TO THE LEFT
# 14096 - MOVE THE FORK TO THE RIGHT
# 14097 - MOE THE FORECOP
# 14098 - MOOTHE THE FORK DOWN
# 14099 - ROTEE THE FORK
# 14100 - THIS IS A PEN
# 14101 - THIS IS A PEN
# 14102 - THIS IS A PEN
# 14103 - THIS IS A PEN
# 14104 - THIS IS A PEN
# 14105 - THIS IS A PHOAN
# 14106 - THIS IS A PHOAN
# 14107 - THIS IS A PHOAM
# 14108 - THIS IS A PHOAN
# 14109 - THIS IS A PHOAM
# 14110 - THIS IS A SPOON
# 14111 - THIS IS A SPOON
# 14112 - THIS IS A SPOON
# 14113 - THIS IS A SPOON
# 14114 - THIS IS A SPOON
# 14115 - THIS IS A KNIFE
# 14116 - THIS IS A KNIFE
# 14117 - THIS IS A KNIFE
# 14118 - THIS IS A KNIFE
# 14119 - THIS IS A KNIFE
# 14120 - THIS IS A FORK
# 14121 - THIS IS A FORK
# 14122 - THIS IS A FORK
# 14123 - THIS IS A FORK
# 14124 - THIS IS A FORK
# 14125 - MOVE THE PAN TO THE LEFT
# 14126 - MOVE THE PEN TO THE RIGHT
# 14127 - MOVE THE PEN UP
# 14128 - MOVE THE PAN DOWN
# 14129 - ROTATE THE PEN
# 14130 - MOVE THE PHONE TO THE LEFT
# 14131 - MOVE  THE FOWN TO THE RIGHT
# 14132 - MOVE THE PHONE UP
# 14133 - MOVE THE PHONE DOWN
# 14134 - ROTATE THE PHONE
# 14135 - MOVE THE SPOON TO THE LEFT
# 14136 - MOVE THE SPOON TO THE RIGHT
# 14137 - MOVE THE SPOON UP
# 14138 - MOVE THE SPOON DOWN
# 14139 - ROTATE THE SPOON
# 14140 - MOVE THE KNIFE TO THE LEFT
# 14141 - MOVE THE KNIFE TO THE RIGHT
# 14142 - MOVE THE KNIFE UP
# 14143 - MOVE THE KNIFE DOWN
# 14144 - ROTATE THE KNIFE
# 14145 - MOVE THE FORK TO THE LEFT
# 14146 - MOVE THE FORK TO THE RIGHT
# 14147 - MOVE THE FORECUP
# 14148 - MOVE THE FORT DOWN
# 14149 - ROTATE THE FORK
# 14150 - THIS IS A PEN
# 14151 - THIS IS A PEN
# 14152 - THIS IS A PEN
# 14153 - THIS IS A PEN
# 14154 - THIS IS A PEN
# 14155 - THIS IS A PHONE
# 14156 - THIS IS A FONE
# 14157 - THIS IS A PHONE
# 14158 - THIS IS A PHONE
# 14159 - THIS IS A PHONE
# 14160 - THIS IS ASPERN
# 14161 - THIS IS A SPERN
# 14162 - THIS IS A SPERN
# 14163 - THIS IS A SPERN
# 14164 - THIS IS A SPERN
# 14165 - THIS IS A KNIFE
# 14166 - THIS IS A KNIFE
# 14167 - THIS IS A KNIFE
# 14168 - THIS IS A KNIFE
# 14169 - THIS IS A KNIFE
# 14170 - THIS IS A FOR
# 14171 - THIS IS A FOR
# 14172 - THIS IS A FOR
# 14173 - THIS IS A FOR
# 14174 - THIS IS A FOR
# 14175 - MOVES THE PEN TO THE LEFT
# 14176 - MOVES THE PEN TO THE RIGHT
# 14177 - LUSE PENUP
# 14178 - LOOFES THE PENDOWN
# 14179 - ROTATE THE PEN
# 14180 - MOVES THE PHONE TO THE LEFT
# 14181 - LOSE THE PHONE TO THE RIGHT
# 14182 - MOVES THE PHONE UP
# 14183 - MOVES THE PHONE DOWN
# 14184 - ROTETE TEPHONE
# 14185 - MOVED THE SPOON TO THE LEFT
# 14186 - MOVED THE SPOON TO THE RIGHT
# 14187 - MOVED THE SPOON UP
# 14188 - MOVED THE SPOON DOWN
# 14189 - ROTATE THE SPOON
# 14190 - LOVED THE KNIFE TO THE LEFT
# 14191 - MOVES THE KNIFE TO THE RIGHT
# 14192 - MOVE THE KNIFER
# 14193 - MOVE THE KNIFE DOWN
# 14194 - ROTATE THE KNIFE
# 14195 - MOVE THE FORK TO THE LEFT
# 14196 - MOVES THE FORK TO THE RIGHT
# 14197 - MOVES THE FORECOP
# 14198 - MOVES THE FORK DOWN
# 14199 - ROTADE THE FORK
# 14200 - THIS IS A PEN
# 14201 - THIS IS A PEN
# 14202 - THIS IS A PEN
# 14203 - THIS IS A PEN
# 14204 - THIS IS A PEN
# 14205 - THIS IS A PHON
# 14206 - THIS IS A FAWND
# 14207 - THIS IS A PHONE
# 14208 - THIS IS A PHONE
# 14209 - THIS IS A PHONE
# 14210 - IS IS A SPOON
# 14211 - THIS IS A SPOON
# 14212 - THIS IS A SPOON
# 14213 - THIS IS A SPOON
# 14214 - THIS IS A SPOON
# 14215 - THIS IS A KNIFE
# 14216 - THIS IS A KNIFE
# 14217 - THIS IS A KNIFE
# 14218 - THIS IS A KNIFE
# 14219 - THIS IS A KNIFE
# 14220 - THIS IS A FORK
# 14221 - THIS IS A FORK
# 14222 - THIS IS A FORK
# 14223 - THIS IS A FORK
# 14224 - THIS IS A FORK
# 14225 - OVED THE PAN TO THE LEFT
# 14226 - MOVE THE PEN TO THE RIGHT
# 14227 - MOVE THE PEN UP
# 14228 - OVE THE PEN DOWN
# 14229 - ROTAKE THE PEN
# 14230 - MOVED THE PHONE TO THE LEFT
# 14231 - MOVED THE PHONE TO THE RIGHT
# 14232 - OV THE PHON UP
# 14233 - MOVE THE FALL DOWN
# 14234 - ROUTATE THE PHONE
# 14235 - OOVED THE SPOON TO THE LEFT
# 14236 - MOVE THE SPOON TO THE RIGHT
# 14237 - MOVE THE SPOON UP
# 14238 - OOVE THE SPOON DOWN
# 14239 - ROU TAKE THE SPOON
# 14240 - MOVE THE KNIFE TO THE LEFT
# 14241 - MOVE THE KNIFE TO THE RIGHT
# 14242 - OV THE KNIFE UP
# 14243 - OE THE KNIFE DOWN
# 14244 - ROTATE THE KNIFE
# 14245 - MOVE THE FORK TO THE LEFT
# 14246 - MOVE THE FORK TO THE RIGHT
# 14247 - OOV THE FORECUP
# 14248 - MOVE THE FORK DOWN
# 14249 - ROU TAKE THE FORK
# 14250 - THIS IS A PEN
# 14251 - THIS IS A PEN
# 14252 - THIS IS A PEN
# 14253 - THIS IS A PEN
# 14254 - THIS IS A PEN
# 14255 - THIS IS A PHONE
# 14256 - THIS IS A PHONE
# 14257 - THIS IS A PHONE
# 14258 - THIS IS A PHONE
# 14259 - THIS IS A PHONE
# 14260 - THIS IS A SPOON
# 14261 - THIS IS A SPOON
# 14262 - THIS IS A SPOON
# 14263 - THIS IS A SPOON
# 14264 - THIS IS A SPOON
# 14265 - THIS IS A KNIFE
# 14266 - THIS IS A KNIFE
# 14267 - THIS IS A KNIFE
# 14268 - THIS IS A KNIFE
# 14269 - THIS IS A KNIFE
# 14270 - THIS IS A FORK
# 14271 - THIS IS A FORK
# 14272 - THIS IS A FORK
# 14273 - THIS IS A FORK
# 14274 - THIS IS A FORK
# 14275 - MOVE THE PEN TO THE LEFT
# 14276 - MOVE THE PEN TO THE RIGHT
# 14277 - MOVE THE PENNOP
# 14278 - MOVE THE PEN DOWN
# 14279 - ROTATE THE PEN
# 14280 - MOVE THE PHONE TO THE LEFT
# 14281 - MOVE THE PHONE TO THE RIGHT
# 14282 - MOVE THE PHONA
# 14283 - MOVE THE FONE DOWN
# 14284 - ROTATE THE PHONE
# 14285 - MOVE THE SPOON TO THE LEFT
# 14286 - MOVE THE SPOON TO THE RIGHT
# 14287 - MOVE THE SPOONER
# 14288 - MOVE THE SPOON DOWN
# 14289 - ROTATE THE SPOON
# 14290 - MOVE THE KNIFE TO THE LEFT
# 14291 - MOVE THE KNIFE TO THE RIGHT
# 14292 - MOVE THE KNIFE
# 14293 - MOVE THE KNIFE DOWN
# 14294 - ROTATE THE KNIFE
# 14295 - MOVE THE FORK TO THE LEFT
# 14296 - MOVE THE FORK TO THE RIGHT
# 14297 - MOVE THE FORCA
# 14298 - MOVE THE FORK DOWN
# 14299 - ROTATE THE FORK
# 14300 - THIS IS A PEN
# 14301 - THIS IS A PEN
# 14302 - THIS IS A PEN
# 14303 - THIS IS A PEN
# 14304 - THIS IS A PEN
# 14305 - THIS IS A PHONE
# 14306 - HIS IS A PHONE
# 14307 - THIS IS A PHONE
# 14308 - THIS IS A PHONE
# 14309 - THIS IS A PHONE
# 14310 - THIS IS A SPOON
# 14311 - THIS IS A SPOON
# 14312 - THIS IS A SPOON
# 14313 - THIS IS A SPOON
# 14314 - THIS IS A SPOON
# 14315 - THIS IS A KNIFE
# 14316 - THIS IS A KNIFE
# 14317 - THIS IS A KNIFE
# 14318 - THIS IS A KNIFE
# 14319 - THIS IS A KNIFE
# 14320 - THIS IS A FORK
# 14321 - THIS IS A FORK
# 14322 - THIS IS A FORK
# 14323 - THIS IS A FORK
# 14324 - THIS IS A FORK
# 14325 - OVETEN TO  LEFT
# 14326 - MOVE THE PEN TO THE RIGHT
# 14327 - MOVE THE PEN UP
# 14328 - MOVE THE PEN DOWN
# 14329 - ROTATE THE PEN
# 14330 - MOVE THE PHONE TO THE LEFT
# 14331 - MOVE THE PHONE TO THE RIGHT
# 14332 - MOVE THE PHONE OP
# 14333 - MOVE THE PHONE DOWN
# 14334 - ROTATE THE PHONE
# 14335 - MOVED THE SPOON TO THE LEFT
# 14336 - MOVE THE SPOON TO THE RIGHT
# 14337 - MOVE THE SPOON UP
# 14338 - MOVE THE SPOON DOWN
# 14339 - ROTATE THE SPOON
# 14340 - OVHE THE KNIFETO THE LEFT
# 14341 - MOVE THE KNIFE TO THE RIGHT
# 14342 - MOVE THE KNIFE OP
# 14343 - MOVE THE KNIFE DOWN
# 14344 - ROTATE THE KNIFE
# 14345 - MOVE THE FORK TO THE LEFT
# 14346 - MOVE THE FORK TO THE RIGHT
# 14347 - MOVE THE FORE CUP
# 14348 - MOVE THE FORK DOWN
# 14349 - ROTATE THE FORK
# 14350 - THIS IS A PEN
# 14351 - THIS IS A PEN
# 14352 - THIS IS A PEN
# 14353 - THIS IS A PEN
# 14354 - THIS IS A PEN
# 14355 - THIS IS A PHONE
# 14356 - THIS IS A PHONE
# 14357 - THIS IS A PHONE
# 14358 - THIS IS A PHONE
# 14359 - THIS IS A PHONE
# 14360 - THIS IS A SPOON
# 14361 - THIS IS A SPOON
# 14362 - THIS IS A SPOON
# 14363 - THIS IS A SPOON
# 14364 - THIS IS A SPOON
# 14365 - THIS IS A KNIFE
# 14366 - THIS IS A KNIFE
# 14367 - THIS IS A KNIFE
# 14368 - THIS IS A KNIFE
# 14369 - THIS IS A KNIFE
# 14370 - THIS IS A FORK
# 14371 - THIS IS A FORK
# 14372 - THIS IS A FORK
# 14373 - THIS IS A FORK
# 14374 - THIS IS A FORK
# 14375 - MOVED THE PEN TO THE LEFT
# 14376 - MOVE THE PEN TO THE RIGHT
# 14377 - MOVE THE PEN UP
# 14378 - MOVE THE PEN DOWN
# 14379 - ROT ADE THE PEN
# 14380 - MOVED THE FONE TO THE LEFT
# 14381 - MOVE THE PHONE TO THE RIGHT
# 14382 - MOVED THE PHONE UP
# 14383 - MOVED THE PHONE DOWN
# 14384 - ROTADE THE PHONE
# 14385 - MOVED THE SPOON TO THE LEFT
# 14386 - MOVE THE SPOON TO THE RIGHT
# 14387 - MOVE THE SPOON UP
# 14388 - MOVE THE SPOON DOWN
# 14389 - ROTADE THE SPOON
# 14390 - MOVE THE KNIFE TO THE LEFT
# 14391 - MOVE THE KNIFE TO THE RIGHT
# 14392 - MOVE THE KNIFEAP
# 14393 - MOVH THE KNIFE DOWN
# 14394 - ROTADE THE KNIFE
# 14395 - MOVE THE FORK TO THE LEFT
# 14396 - MOVE THE FORK TO THE RIGHT
# 14397 - MOVED THE FORECUP
# 14398 - MOVED THE FORK DOWN
# 14399 - ROTADE THE FORK
# 14400 - THIS IS A PEN
# 14401 - THIS IS A PEN
# 14402 - THIS IS A PEN
# 14403 - THIS IS A PEN
# 14404 - THIS IS A PEN
# 14405 - THIS IS A FONE
# 14406 - THIS IS A FOUND
# 14407 - THIS IS A FONE
# 14408 - THIS IS A PHONE
# 14409 - THIS IS A PHONE
# 14410 - THIS IS A SPERN
# 14411 - THIS IS A SPERN
# 14412 - THIS IS A SPURN
# 14413 - THIS IS A SPOON
# 14414 - THIS IS A SPURN
# 14415 - THIS IS A KNIFE
# 14416 - THIS IS A KNIFE
# 14417 - THIS IS A KNIFE
# 14418 - THIS IS A KNIFE
# 14419 - THIS IS A KNIFE
# 14420 - THIS IS A FOR
# 14421 - THIS IS A FOR
# 14422 - THIS IS A FORK
# 14423 - THIS IS A FORK
# 14424 - THIS IS A FORK
# 14425 - MOVED THE PEN TO THE LEFT
# 14426 - MOVE THE PEN TO THE RIGHT
# 14427 - MOVE THE PENNER
# 14428 - MOVE THE PEN DOWN
# 14429 - ROTE TATE THE PEN
# 14430 - MOVE THE PHONE TO THE LEFT
# 14431 - MOVE THE PHONE TO THE RIGHT
# 14432 - MOVED THE PHONAP
# 14433 - MOVE THE PHONE DOWN
# 14434 - ROTATE THE FAWN
# 14435 - MOVED THE SPOON TO THE LEFT
# 14436 - MOVE THE SPOON TO THE RIGHT
# 14437 - MOVE THE SPOONUP
# 14438 - MOVE THE SPOON DOWN
# 14439 - ROTATE THE SPOON
# 14440 - MOVED THE KNIFE TO THE LEFT
# 14441 - MOVE THE KNIFE TO THE RIGHT
# 14442 - MOVED THE KNIFE UP
# 14443 - MOVE THE KNIFE DOWN
# 14444 - ROTATE THE KNIFE
# 14445 - MOVE THE FORK TO THE LEFT
# 14446 - MOVE THE FORK TO THE RIGHT
# 14447 - MOVE THE FORECUP
# 14448 - MOVE THE FORK DOWN
# 14449 - ROAD TAKE THE FORK
# 14450 - THIS IS A PEN
# 14451 - THIS IS A PEN
# 14452 - THIS IS A PEN
# 14453 - THIS IS A PEN
# 14454 - THIS IS A PEN
# 14455 - THIS IS A PHONE
# 14456 - THIS IS A PHONE
# 14457 - THIS IS A PHONE
# 14458 - THIS IS A PHONE
# 14459 - THIS IS A PHONE
# 14460 - THIS IS A SPOON
# 14461 - THIS IS A SPOON
# 14462 - THIS IS A SPOON
# 14463 - THIS IS A SPOON
# 14464 - THIS IS A SPOON
# 14465 - THIS IS A KNIFE
# 14466 - THIS IS A KNIFE
# 14467 - THIS IS A KNIFE
# 14468 - THIS IS A KNIFE
# 14469 - THIS IS A KNIFE
# 14470 - THIS IS A FORK
# 14471 - THIS IS A FORK
# 14472 - THIS IS A FORK
# 14473 - THIS IS A FORK
# 14474 - THIS IS A FORK
# 14475 - MOVED THE PAN TO THE LEFT
# 14476 - MOVE THE PAN TO THE RIGHT
# 14477 - MOVE THE PEN UP
# 14478 - MOVE THE PEN DOWN
# 14479 - ROTATE THE PEN
# 14480 - MOVE THE PHONE TO THE LEFT
# 14481 - MOVE THE PHONE TO THE RIGHT
# 14482 - MOVE THE PHONE UP
# 14483 - MOVE THE PHONE DOWN
# 14484 - ROTATE THE PHONE
# 14485 - MOVE THE SPOON TO THE LEFT
# 14486 - MOVE THE SPOON TO THE RIGHT
# 14487 - MOVE THE SPOON UP
# 14488 - MOVE THE SPOON DOWN
# 14489 - ROTATE THE SPOON
# 14490 - MOVED THE KNIFE TO THE LEFT
# 14491 - MOVE THE KNIFE TO THE RIGHT
# 14492 - MOVE THE KNIFE UP
# 14493 - MOVE THE KNIFE DOWN
# 14494 - ROTATE THE KNIFE
# 14495 - MOVE THE FORK TO THE LEFT
# 14496 - MOVE THE FORK TO THE RIGHT
# 14497 - MOVE THE FORECUP
# 14498 - MOVE THE FORK DOWN
# 14499 - ROTATE THE FORK
