# %% [markdown]
# # COMPOSITIONAL SEMANTICS RESULTS
#
# Here, we compare the the original audio features with the audio features predicted by the model.
#
# Once video features were mapped onto audio features, an experiment was performed in order to verify if the model developed the ability of combine elements autonomously, i.e. if it developed compositional semantics capabilities. In order to do that, five subsequent tests were performed, one for each object: pen, phone, spoon, knife and fork. For each of them, a reduced dataset was prepared, removing the videos that showed the object moving to the left, to the right, up, down and rotating. The model was trained on the reduced dataset, resulting in 13,050 samples, and then tested against the 1,450 videos that had been removed.
#
# The results are shown in table 12 at page 27 on https://github.com/fabiodeponte/symbol_grounding/blob/main/grounding_words_visual_perceptions.pdf.
#
# The model was able to generalize when similar videos were present during training. However, it was not able to combine information from the videos that showed the objects staying still and information about the movement applied to other objects, to form a sentence composed by “move” and the name of the object.
#
# For example, when videos showing pens moving to the left were part of the training set, the model was able to recognize new videos showing a similar scene. On the contrary, when videos showing pens moving to the left were NOT part of the training set at all, the model was not able to recognize new videos showing that scene, even if it was exposed to videos showing still pens and spoons moving to the left. The (failed) attempt was to let the model compose separate information from different videos and let it apply to a single one.
#
# NOTE: for the sake of clarity, we show here only the first 100 utterances. In the folder https://github.com/fabiodeponte/symbol_grounding/tree/main/seq2seq%20chollet/compositional%20semantics%20-%20complete%20tests the predicted utterance for each of the 1,450 tested videos can be found.

# %%
import numpy as np
import pandas as pd
import os
from numpy import save
from numpy import load
import matplotlib.pyplot as plt
from numpy import argmax

from tensorflow import keras
from keras import models
from keras.models import Sequential
from keras.layers import LSTM, TimeDistributed, RepeatVector, Dense

import librosa
import torch
from transformers import Wav2Vec2ForCTC, Wav2Vec2Tokenizer

import IPython.display as display

# Importing Wav2Vec pretrained model

tokenizer = Wav2Vec2Tokenizer.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Wav2Vec2CTCTokenizer'.
# The class this function is called from is 'Wav2Vec2Tokenizer'.
# /home/digit/miniconda3/envs/keras/lib/python3.9/site-packages/transformers/models/wav2vec2/tokenization_wav2vec2.py:754: FutureWarning: The class `Wav2Vec2Tokenizer` is deprecated and will be removed in version 5 of Transformers. Please use `Wav2Vec2Processor` or `Wav2Vec2CTCTokenizer` instead.
#   warnings.warn(
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # MODEL TRAINED WITHOUT MOVE PEN: TEST ON MOVE PEN

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_06_movepen_0-100.npy', allow_pickle=True))
original_features = pd.DataFrame(load('features/audio_features_move_pen.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                              0                            1
# 0     MOVE THE PEN TO THE LEFT                THIS IS A TAN
# 1    MOVE THE PEN TO THE RIGHT                THIS IS A TAN
# 2              MOVE THE PEN UP                THIS IS A PEN
# 3            MOVE THE PEN DOWN                THIS IS A PEN
# 4              WROTATE THE PEN                THIS IS A PEN
# 5    MOTHE THE PEN TO THE LEFT                THIS IS A TAN
# 6    MOVE THE PEN TO THE RIGHT                THIS IS A PEN
# 7               MOE THE PENNOB                THIS IS A PEN
# 8            MOVE THE PEN DOWN                THIS IS A TAN
# 9               ROTATE THE PEN                THIS IS A PEN
# 10    MOVE THE PAN TO THE LEFT              THIS IS A SPOON
# 11   MOVE THE PEN TO THE RIGHT                THIS IS A PEN
# 12             MOVE THE PEN UP                THIS IS A PEN
# 13           MOVE THE PEN DOWN                THIS IS A PEN
# 14              ROTATE THE PEN              THIS IS A KNIFE
# 15   MOVES THE PEN TO THE LEFT                THIS IS A PEN
# 16  MOVES THE PEN TO THE RIGHT                THIS IS A PEN
# 17                  LUSE PENAP                THIS IS A PEN
# 18          LOOSE THE PEN DOWN                THIS IS A PEN
# 19             WROTATE THE PEN                THIS IS A TAN
# 20    OVED THE PAN TO THE LEFT                THIS IS A PEN
# 21   MOVE THE PEN TO THE RIGHT                THIS IS A PEN
# 22             MOVE THE PEN UP                THIS IS A PEN
# 23            OVE THE PEN DOWN                THIS IS A PEN
# 24              ROTAKE THE PEN                THIS IS A PEN
# 25    MOVE THE PEN TO THE LEFT      OVE THE IFE TO THE LEFT
# 26   MOVE THE PEN TO THE RIGHT                THIS IS A PEN
# 27             MOVE THE PENNOP          MOVE THE KNIFE DOWN
# 28           MOVE THE PEN DOWN                THIS IS A PEN
# 29             ROTATHE THE PEN                THIS IS A PEN
# 30            OVEDTEN TO  LEFT                THIS IS A PEN
# 31   MOVE THE PEN TO THE RIGHT   MOVE THE KNIFE TO THE LEFT
# 32             MOVE THE PEN UP                THIS IS A PEN
# 33           MOVE THE PEN DOWN                THIS IS A PEN
# 34              ROTATE THE PEN                THIS IS A PEN
# 35   MOVED THE PEN TO THE LEFT     OVE THE FON TO THE RIGHT
# 36   MOVE THE PEN TO THE RIGHT                THIS IS A PEN
# 37             MOVE THE PEN UP                THIS IS A PEN
# 38           MOVE THE PEN DOWN                THIS IS A PEN
# 39             ROT ADE THE PEN                THIS IS A PEN
# 40   MOVED THE PEN TO THE LEFT                THIS IS A PEN
# 41   MOVE THE PEN TO THE RIGHT                THIS IS A PEN
# 42              MOVE THE PENNA                THIS IS A PEN
# 43           MOVE THE PEN DOWN               THIS IS A FORK
# 44           ROTE TATE THE PEN                THIS IS A PEN
# 45   MOVED THE PAN TO THE LEFT                THIS IS A PEN
# 46   MOVE THE PAN TO THE RIGHT              THIS IS A SPOON
# 47             MOVE THE PEN UP              THIS IS A SPOON
# 48           MOVE THE PEN DOWN               OV THE FOE NOW
# 49              ROTATE THE PEN              THIS IS A KNIFE
# 50    MOVE THE PEN TO THE LEFT                THIS IS A PEN
# 51   MOVE THE PEN TO THE RIGHT              THIS IS A PHONE
# 52             MOVE THE PEN UP              THIS IS A KNIFE
# 53           MOVE THE PEN DOWN              THIS IS A KNIFE
# 54             WROTATE THE PEN                THIS IS A PEN
# 55   MOTHE THE PEN TO THE LEFT                THIS IS A TAN
# 56   MOVE THE PEN TO THE RIGHT                THIS IS A PEN
# 57              MOE THE PENNOB                THIS IS A PEN
# 58           MOVE THE PEN DOWN                THIS IS A TAN
# 59              ROTATE THE PEN                THIS IS A PEN
# 60    MOVE THE PAN TO THE LEFT                THIS IS A PEN
# 61   MOVE THE PEN TO THE RIGHT              THIS IS A KNIFE
# 62             MOVE THE PEN UP                THIS IS A PEN
# 63           MOVE THE PEN DOWN                THIS IS A PEN
# 64              ROTATE THE PEN  MOVE THE SPOON TO THE RIGHT
# 65   MOVES THE PEN TO THE LEFT            MOVE THE KNIFE UP
# 66  MOVES THE PEN TO THE RIGHT                THIS IS A PEN
# 67                  LUSE PENAP                THIS IS A PEN
# 68          LOOSE THE PEN DOWN                THIS IS A PEN
# 69             WROTATE THE PEN                THIS IS A PEN
# 70    OVED THE PAN TO THE LEFT               HIS IS A KNIFE
# 71   MOVE THE PEN TO THE RIGHT                THIS IS A PEN
# 72             MOVE THE PEN UP                THIS IS A PEN
# 73            OVE THE PEN DOWN                THIS IS A PEN
# 74              ROTAKE THE PEN                THIS IS A PEN
# 75    MOVE THE PEN TO THE LEFT                THIS IS A PEN
# 76   MOVE THE PEN TO THE RIGHT                THIS IS A PEN
# 77             MOVE THE PENNOP      OE THE FORK TO THE LEFT
# 78           MOVE THE PEN DOWN                THIS IS A PEN
# 79             ROTATHE THE PEN                THIS IS A PEN
# 80            OVEDTEN TO  LEFT                THIS IS A PEN
# 81   MOVE THE PEN TO THE RIGHT                THIS IS A PEN
# 82             MOVE THE PEN UP                THIS IS A PEN
# 83           MOVE THE PEN DOWN                THIS IS A PEN
# 84              ROTATE THE PEN                THIS IS A PEN
# 85   MOVED THE PEN TO THE LEFT                THIS IS A PEN
# 86   MOVE THE PEN TO THE RIGHT   MOVE THE KNIFE TO THE LEFT
# 87             MOVE THE PEN UP                THIS IS A PEN
# 88           MOVE THE PEN DOWN                THIS IS A PEN
# 89             ROT ADE THE PEN                THIS IS A PEN
# 90   MOVED THE PEN TO THE LEFT               THIS IS A FORK
# 91   MOVE THE PEN TO THE RIGHT                 O THE FORKNA
# 92              MOVE THE PENNA              THIS IS A KNIFE
# 93           MOVE THE PEN DOWN              THIS IS A KNIFE
# 94           ROTE TATE THE PEN              THIS IS A KNIFE
# 95   MOVED THE PAN TO THE LEFT              THIS IS A SPOON
# 96   MOVE THE PAN TO THE RIGHT                THIS IS A PEN
# 97             MOVE THE PEN UP              THIS IS A SPOON
# 98           MOVE THE PEN DOWN              THIS IS A SPOON
# 99              ROTATE THE PEN                THIS IS A PEN

# %% [markdown]
# # MODEL TRAINED WITHOUT MOVE PEN: TEST ON MOVE PHONE

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_06_move_phone_0-100.npy', allow_pickle=True))
original_features = pd.DataFrame(load('features/audio_features_move_phone.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0                            1
# 0     MOVE THE PHONE TO THE LEFT              THIS IS A PHONE
# 1    MOVE THE PHONE TO THE RIGHT               THIS IS A FOWN
# 2              MOVE THE PHONE UP              THIS IS A SPOON
# 3            MOVE THE PHONE DOWN              THIS IS A PHONE
# 4               ROTATE THE PHONE              THIS IS A PHONE
# 5    MOOVE THE PHONE TO THE LEFT              THIS IS A PHAWN
# 6    MOVE THE PHONE TO THE RIGHT              THIS IS A PHAWN
# 7              MOO THE PHOE KNOP              THIS IS A PHOAM
# 8            MOVE THE PHONE DOWN               THIS IS A FARM
# 9               ROTATE THE PHONE              THIS IS A PHONE
# 10    MOVE THE PHONE TO THE LEFT              THIS IS A PHONE
# 11    MOVE  THE FON TO THE RIGHT               THIS IS A FOAM
# 12             MOVE THE PHONE UP               THIS IS A FOAM
# 13           MOVE THE PHONE DOWN              THIS IS A PHONE
# 14              ROTATE THE PHONE                 IS IS A FARN
# 15   MOVES THE PHONE TO THE LEFT              THIS IS A SPOON
# 16   LOSE THE PHONE TO THE RIGHT              THIS IS A PHONE
# 17                 MUVEEPHONE UP              THIS IS A SPOON
# 18          MOVES THE PHONE DOWN              THIS IS A PHONE
# 19                ROTETE TEPHONE              THIS IS A PHONE
# 20   MOVED THE PHONE TO THE LEFT              THIS IS A PHAWN
# 21  MOVED THE PHONE TO THE RIGHT  MOTHE THE SPOON TO THE LEFT
# 22               OOV THE PHON UP                 IS IS A FARN
# 23             OVE THE FALM DOWN              THIS IS A PHONE
# 24             ROUTAKE THE PHONE              THIS IS A PHAWN
# 25    MOVE THE PHONE TO THE LEFT              THIS IS A PHONE
# 26   MOVE THE PHONE TO THE RIGHT              THIS IS A PHONE
# 27                MOVE THE PHONA              THIS IS A PHONE
# 28            MOVE THE FONE DOWN               THIS IS A FOWN
# 29              ROTATE THE PHONE                THIS IS A PEN
# 30    MOVE THE PHONE TO THE LEFT              THIS IS A PHONE
# 31   MOVE THE PHONE TO THE RIGHT              THIS IS A PHONE
# 32             MOVE THE PHONE UP              THIS IS A PHONE
# 33           MOVE THE PHONE DOWN              THIS IS A PHONE
# 34              ROTATE THE PHONE               THIS IS A FOWN
# 35    MOVE THE FOUND TO THE LEFT               THIS IS A FOWN
# 36   MOVE THE PHONE TO THE RIGHT              THIS IS A PHONE
# 37            MOVED THE PHONE UP              THIS IS A PHONE
# 38          MOVED THE PHONE DOWN              THIS IS A PHONE
# 39              ROTADE THE PHONE              THIS IS A PHONE
# 40    MOVE THE PHONE TO THE LEFT              THIS IS A PHONE
# 41   MOVE THE PHONE TO THE RIGHT              THIS IS A PHONE
# 42              MOVED THE PHONUP              THIS IS A PHOAM
# 43           MOVE THE PHONE DOWN              THIS IS A PHONE
# 44               ROTATE THE FAWN              THIS IS A PHONE
# 45    MOVE THE PHONE TO THE LEFT            THIS IS A SPOOING
# 46   MOVE THE PHONE TO THE RIGHT              THIS IS A PHONE
# 47             MOVE THE PHONE UP              THIS IS A PHONE
# 48           MOVE THE PHONE DOWN              THIS IS A PHONE
# 49              ROTATE THE PHONE              THIS IS A PHONE
# 50    MOVE THE PHONE TO THE LEFT               THIS IS A FOWN
# 51   MOVE THE PHONE TO THE RIGHT               THIS IS A FOWN
# 52             MOVE THE PHONE UP               THIS IS A FOWN
# 53           MOVE THE PHONE DOWN              THIS IS A SPOON
# 54              ROTATE THE PHONE              THIS IS A SPOON
# 55   MOOVE THE PHONE TO THE LEFT              THIS IS A KNIFE
# 56   MOVE THE PHONE TO THE RIGHT              THIS IS A PHAWN
# 57             MOO THE PHOE KNOP                 IS IS A FARN
# 58           MOVE THE PHONE DOWN              THIS IS A PHONE
# 59              ROTATE THE PHONE              THIS IS A PHONE
# 60    MOVE THE PHONE TO THE LEFT                 IS IS A FONE
# 61    MOVE  THE FON TO THE RIGHT              THIS IS A PHAWN
# 62             MOVE THE PHONE UP              THIS IS A PHAWN
# 63           MOVE THE PHONE DOWN              THIS IS A SPOON
# 64              ROTATE THE PHONE              THIS IS A PHONE
# 65   MOVES THE PHONE TO THE LEFT              THIS IS A SPOON
# 66   LOSE THE PHONE TO THE RIGHT              THIS IS A SPOON
# 67                 MUVEEPHONE UP              THIS IS A SPOON
# 68          MOVES THE PHONE DOWN              THIS IS A SPOON
# 69                ROTETE TEPHONE              THIS IS A PHONE
# 70   MOVED THE PHONE TO THE LEFT              THIS IS A PHAWN
# 71  MOVED THE PHONE TO THE RIGHT              THIS IS A SPOON
# 72               OOV THE PHON UP                 IS IS A FARM
# 73             OVE THE FALM DOWN              THIS IS A PHONE
# 74             ROUTAKE THE PHONE                IS IS A SPOON
# 75    MOVE THE PHONE TO THE LEFT              THIS IS A PHONE
# 76   MOVE THE PHONE TO THE RIGHT              THIS IS A PHONE
# 77                MOVE THE PHONA              THIS IS A PHONE
# 78            MOVE THE FONE DOWN              THIS IS A PHONE
# 79              ROTATE THE PHONE               THIS IS A FOWN
# 80    MOVE THE PHONE TO THE LEFT              THIS IS A SPOON
# 81   MOVE THE PHONE TO THE RIGHT              THIS IS A PHONE
# 82             MOVE THE PHONE UP  MOTHE THE SPOON TO THE LEFT
# 83           MOVE THE PHONE DOWN              THIS IS A PHONE
# 84              ROTATE THE PHONE               THIS IS A FOWN
# 85    MOVE THE FOUND TO THE LEFT              THIS IS A PHONE
# 86   MOVE THE PHONE TO THE RIGHT              THIS IS A PHONE
# 87            MOVED THE PHONE UP              THIS IS A PHONE
# 88          MOVED THE PHONE DOWN              THIS IS A SPOON
# 89              ROTADE THE PHONE            THIS IS A SPOOING
# 90    MOVE THE PHONE TO THE LEFT              THIS IS A PHONE
# 91   MOVE THE PHONE TO THE RIGHT              THIS IS A PHONE
# 92              MOVED THE PHONUP               THIS IS A FOAM
# 93           MOVE THE PHONE DOWN              THIS IS A PHONE
# 94               ROTATE THE FAWN              THIS IS A PHONE
# 95    MOVE THE PHONE TO THE LEFT            THIS IS A SPOOING
# 96   MOVE THE PHONE TO THE RIGHT              THIS IS A PHONE
# 97             MOVE THE PHONE UP            THIS IS A SPOOING
# 98           MOVE THE PHONE DOWN            THIS IS A SPOOING
# 99              ROTATE THE PHONE              THIS IS A PHONE

# %% [markdown]
# # MODEL TRAINED WITHOUT MOVE PEN: TEST ON MOVE SPOON

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_06_move_spoon_0-100_02.npy', allow_pickle=True))
original_features = pd.DataFrame(load('features/audio_features_move_spoon.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0                           1
# 0     MOVE THE SPOON TO THE LEFT             THIS IS A SPOON
# 1    MOVE THE SPOON TO THE RIGHT             THIS IS A SPOON
# 2              MOVE THE SPOON UP             THIS IS A SPERN
# 3            MOVE THE SPOON DOWN             THIS IS A SPOON
# 4              RO TAKE THE SPOON             THIS IS A SPOON
# 5    MOVED THE SPOON TO THE LEFT             THIS IS A PHONE
# 6    MOVE THE SPOON TO THE RIGHT             THIS IS A PHONE
# 7              MOVE THE SPOON UP              THIS IS A FONE
# 8           MOOTH THE SPOON DOWN             THIS IS A SPERN
# 9               ROTATE THE SPOON             THIS IS A SPOON
# 10    MOVE THE SPOON TO THE LEFT             THIS IS A SPOON
# 11   MOVE THE SPOON TO THE RIGHT             THIS IS A SPOON
# 12             MOVE THE SPOON UP             THIS IS A PHONE
# 13           MOVE THE SPOON DOWN             THIS IS A PHONE
# 14              ROTATE THE SPOON             THIS IS A PHONE
# 15   MOVED THE SPOON TO THE LEFT           MOVE THE PEN DOWN
# 16  MOVED THE SPOON TO THE RIGHT             THIS IS A PHONE
# 17            MOVED THE SPOON UP   MOVE THE PAN TO THE RIGHT
# 18         MOVED THE SCROON DOWN              THIS IS A FORK
# 19              ROTATE THE SPOON             THIS IS A SPOON
# 20   OOVED THE SPOON TO THE LEFT               IS IS A SPOON
# 21  MOVED THE SPOON TO THE RIGHT               IS IS A SPOON
# 22             MOVE THE SPOON UP             THIS IS A SPOON
# 23           OOVE THE SPOON DOWN              THIS IS A PHON
# 24             RO TAKE THE SPOON             THIS IS A SPOON
# 25    MOVE THE SPOON TO THE LEFT             THIS IS A KNIFE
# 26   MOVE THE SPOON TO THE RIGHT             THIS IS A KS OI
# 27              MOVE THE SPOONER   MOVE THE PAN TO THE RIGHT
# 28           MOVE THE SPOON DOWN               THIS IS A PEN
# 29              ROTATE THE SPOON  MOVE THE KNIFE TO THE LEFT
# 30   MOVED THE SPOON TO THE LEFT             THIS IS A SPOON
# 31   MOVE THE SPOON TO THE RIGHT             THIS IS A SPOON
# 32             MOVE THE SPOON UP             THIS IS A SPOON
# 33           MOVE THE SPOON DOWN             THIS IS A SPOON
# 34              ROTATE THE SPOON             THIS IS A SPOON
# 35   MOVED THE SPOON TO THE LEFT             THIS IS A SPOON
# 36   MOVE THE SPOON TO THE RIGHT               THIS IS A PEN
# 37            MOVED THE SPOON UP             THIS IS A SPOON
# 38           MOVE THE SPOON DOWN             THIS IS A SPERN
# 39              ROTADE THE SPOON             THIS IS A SPOON
# 40   MOVED THE SPOON TO THE LEFT             THIS IS A SPOON
# 41   MOVE THE SPOON TO THE RIGHT             THIS IS A SPURN
# 42             MOVE THE SPOON UP              THIS IS A FORK
# 43           MOVE THE SPOON DOWN             THIS IS A SPOON
# 44              ROTATE THE SPOON             THIS IS A SPURN
# 45    MOVE THE SPOON TO THE LEFT             THIS IS A SPOON
# 46   MOVE THE SPOON TO THE RIGHT              THIS IS A FORK
# 47             MOVE THE SPOON UP                IS IS A PHON
# 48           MOVE THE SPOON DOWN             THIS IS A SPOON
# 49              ROTATE THE SPOON             THIS IS A SPERN
# 50    MOVE THE SPOON TO THE LEFT             THIS IS A SPOON
# 51   MOVE THE SPOON TO THE RIGHT             THIS IS A SPOON
# 52             MOVE THE SPOON UP             THIS IS A SPERN
# 53           MOVE THE SPOON DOWN             THIS IS A SPOON
# 54             RO TAKE THE SPOON             THIS IS A SPOON
# 55   MOVED THE SPOON TO THE LEFT             THIS IS A PHONE
# 56   MOVE THE SPOON TO THE RIGHT             THIS IS A PHAWN
# 57             MOVE THE SPOON UP             THIS IS A SPOON
# 58          MOOTH THE SPOON DOWN             THIS IS A PHONE
# 59              ROTATE THE SPOON             THIS IS A PHONE
# 60    MOVE THE SPOON TO THE LEFT             THIS IS A SPERN
# 61   MOVE THE SPOON TO THE RIGHT              THIS IS A FORK
# 62             MOVE THE SPOON UP             THIS IS A PHONE
# 63           MOVE THE SPOON DOWN               IS IS A SPOON
# 64              ROTATE THE SPOON             THIS IS A SPOON
# 65   MOVED THE SPOON TO THE LEFT             THIS IS A PHAWN
# 66  MOVED THE SPOON TO THE RIGHT              THIS IS A FORK
# 67            MOVED THE SPOON UP             ROTATE THE FORK
# 68         MOVED THE SCROON DOWN  MOVE THE PHONE TO THE LEFT
# 69              ROTATE THE SPOON             THIS IS A SPOON
# 70   OOVED THE SPOON TO THE LEFT             THIS IS A SPERN
# 71  MOVED THE SPOON TO THE RIGHT             THIS IS A SPOON
# 72             MOVE THE SPOON UP             THIS IS A SPOON
# 73           OOVE THE SPOON DOWN               IS IS A SPOON
# 74             RO TAKE THE SPOON             THIS IS A SPOON
# 75    MOVE THE SPOON TO THE LEFT             THIS IS A KNIFE
# 76   MOVE THE SPOON TO THE RIGHT             THIS IS A KNIFE
# 77              MOVE THE SPOONER   MOVE THE PEN TO THE RIGHT
# 78           MOVE THE SPOON DOWN             THIS IS A SPOON
# 79              ROTATE THE SPOON               THIS IS A PEN
# 80   MOVED THE SPOON TO THE LEFT             THIS IS A SPOON
# 81   MOVE THE SPOON TO THE RIGHT             THIS IS A SPOON
# 82             MOVE THE SPOON UP             THIS IS A SPOON
# 83           MOVE THE SPOON DOWN              THIS IS A FORK
# 84              ROTATE THE SPOON              THIS IS A FORK
# 85   MOVED THE SPOON TO THE LEFT               THIS IS A PEN
# 86   MOVE THE SPOON TO THE RIGHT               THIS IS A PEN
# 87            MOVED THE SPOON UP               IS IS A SPOON
# 88           MOVE THE SPOON DOWN               THIS IS A PEN
# 89              ROTADE THE SPOON               IS IS A SPURN
# 90   MOVED THE SPOON TO THE LEFT             THIS IS A SPURN
# 91   MOVE THE SPOON TO THE RIGHT             THIS IS A SPOON
# 92             MOVE THE SPOON UP             THIS IS A PHONE
# 93           MOVE THE SPOON DOWN               IS IS A SPOON
# 94              ROTATE THE SPOON               IS IS A SPOON
# 95    MOVE THE SPOON TO THE LEFT             THIS IS A SPOON
# 96   MOVE THE SPOON TO THE RIGHT             THIS IS A SPOON
# 97             MOVE THE SPOON UP             THIS IS A SPERN
# 98           MOVE THE SPOON DOWN             THIS IS A SPERN
# 99              ROTATE THE SPOON             THIS IS A SPOON

# %% [markdown]
# # MODEL TRAINED WITHOUT MOVE PEN: TEST ON MOVE KNIFE

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_06_move_knife_0-100.npy', allow_pickle=True))
original_features = pd.DataFrame(load('features/audio_features_move_knife.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                                0                            1
# 0     MOVE THE KNIFE TO THE LEFT              THIS IS A KNIFE
# 1    MOVE THE KNIFE TO THE RIGHT              THIS IS A KNIFE
# 2              MOVE THE KNIFE UP              THIS IS A SPOON
# 3            MOVE THE KNIFE DOWN              THIS IS A KNIFE
# 4               RO ATE THE KNIFE                THIS IS A PEN
# 5   MOOTHE THE KNIFE TO THE LEFT              THIS IS A KNIFE
# 6    MOVE THE KNIFE TO THE RIGHT               THIIS IS A PEN
# 7              MOVE THE KNIFE UP              THIS IS A KNIFE
# 8           MOOVE THE KNIFE DOWN              THIS IS A PHONE
# 9               ROTATE THE KNIFE              THIS IS A KNIFE
# 10    MOVE THE KNIFE TO THE LEFT              THIS IS A KNIFE
# 11   MOVE THE KNIFE TO THE RIGHT                THIS IS A FOR
# 12             MOVE THE KNIFE UP             MOVE THE FORECOP
# 13           MOVE THE KNIFE DOWN                THIS IS A PEN
# 14              ROTATE THE KNIFE    OVES THE PEN TO THE RIGHT
# 15   LOOFE THE KNIFE TO THE LEFT              THIS IS A KNIFE
# 16  LOVES THE KNIFE TO THE RIGHT              THIS IS A KNIFE
# 17               MOVE THE KNAPER                THIS IS A PEN
# 18           MOVE THE KNIFE DOWN              THIS IS A KNIFE
# 19               ROTATE THE NIFE              THIS IS A KNIFE
# 20    MOVE THE KNIFE TO THE LEFT              THIS IS A KNIFE
# 21   MOVE THE KNIFE TO THE RIGHT              THIS IS A KNIFE
# 22               OO THE KNIFE UP              THIS IS A KNIFE
# 23             OE THE KNIFE DOWN              THIS IS A KNIFE
# 24              ROTATE THE KNIFE             THIS IS A PKNIFE
# 25    MOVE THE KNIFE TO THE LEFT              MOVE THE PENNOB
# 26   MOVE THE KNIFE TO THE RIGHT            MOVE THE PEN DOWN
# 27                MOVE THE KNIFE            MOVE THE PEN DOWN
# 28           MOVE THE KNIFE DOWN                THIS IS A PEN
# 29              ROTATE THE KNIFE              THIS IS A KNIFE
# 30      OVHE THE KNIFE TO E LEFT                THIS IS A PEN
# 31   MOVE THE KNIFE TO THE RIGHT                THIS IS A PEN
# 32             MOVE THE KNIFE UP               IS THE PHON UP
# 33           MOVE THE KNIFE DOWN              THIS IS A KNIFE
# 34              ROTATE THE KNIFE               THIS IS A FOAM
# 35    MOVE THE KNIFE TO THE LEFT    MOVE THE PEN TO THE RIGHT
# 36   MOVE THE KNIFE TO THE RIGHT                THIS IS A PEN
# 37             MOVE THE KNIFE AP              THIS IS A KNIFE
# 38           MOVE THE KNIFE DOWN    MOVE THE PEN TO THE RIGHT
# 39              ROTADE THE KNIFE                THIS IS A PEN
# 40   MOVED THE KNIFE TO THE LEFT                THIS IS A PEN
# 41   MOVE THE KNIFE TO THE RIGHT              THIS IS A KNIFE
# 42             MOVE THE KNIFE UP                THIS IS A PEN
# 43           MOVE THE KNIFE DOWN              THIS IS A KNIFE
# 44              ROTATE THE KNIFE              THIS IS A KNIFE
# 45    MOVE THE KNIFE TO THE LEFT              THIS IS A KNIFE
# 46   MOVE THE KNIFE TO THE RIGHT              THIS IS A KNIFE
# 47             MOVE THE KNIFE UP              THIS IS A KNIFE
# 48           MOVE THE KNIFE DOWN              THIS IS A KNIFE
# 49              ROTATE THE KNIFE                THIS IS A PEN
# 50    MOVE THE KNIFE TO THE LEFT    MOVE THE PAN TO THE RIGHT
# 51   MOVE THE KNIFE TO THE RIGHT              THIS IS A KNIFE
# 52             MOVE THE KNIFE UP              THIS IS A PHONE
# 53           MOVE THE KNIFE DOWN              THIS IS A KNIFE
# 54              RO ATE THE KNIFE              THIS IS A KNIFE
# 55  MOOTHE THE KNIFE TO THE LEFT              THIS IS A KNIFE
# 56   MOVE THE KNIFE TO THE RIGHT              THIS IS A KNIFE
# 57             MOVE THE KNIFE UP          MOVE THE PHONE DOWN
# 58          MOOVE THE KNIFE DOWN                 IS THE PHONE
# 59              ROTATE THE KNIFE              THIS IS A KNIFE
# 60    MOVE THE KNIFE TO THE LEFT               THIS IS A FORK
# 61   MOVE THE KNIFE TO THE RIGHT   MOVE THE PHONE TO THE LEFT
# 62             MOVE THE KNIFE UP              THIS IS A KNIFE
# 63           MOVE THE KNIFE DOWN              THIS IS A KNIFE
# 64              ROTATE THE KNIFE               THIS IS A FORK
# 65   LOOFE THE KNIFE TO THE LEFT                THIS IS A PEN
# 66  LOVES THE KNIFE TO THE RIGHT                 IV IS APHONE
# 67               MOVE THE KNAPER              THIS IS A KNIFE
# 68           MOVE THE KNIFE DOWN                MOVE THE PENA
# 69               ROTATE THE NIFE             THIS IS A PKNIFE
# 70    MOVE THE KNIFE TO THE LEFT                MOVE THE PENA
# 71   MOVE THE KNIFE TO THE RIGHT                THIS IS A PEN
# 72               OO THE KNIFE UP               THIS IS A FORK
# 73             OE THE KNIFE DOWN              THIS IS A KNIFE
# 74              ROTATE THE KNIFE              RO TAKE THE PEN
# 75    MOVE THE KNIFE TO THE LEFT               ROTATE THE PAN
# 76   MOVE THE KNIFE TO THE RIGHT              THIS IS A KNIFE
# 77                MOVE THE KNIFE            MOVE THE PEN DOWN
# 78           MOVE THE KNIFE DOWN                THIS IS A PEN
# 79              ROTATE THE KNIFE                THIS IS A PEN
# 80      OVHE THE KNIFE TO E LEFT  OVES THE PHONE TO THE RIGHT
# 81   MOVE THE KNIFE TO THE RIGHT     OVED THE PAN TO THE LEFT
# 82             MOVE THE KNIFE UP    OVES THE PEN TO THE RIGHT
# 83           MOVE THE KNIFE DOWN              THIS IS A KNIFE
# 84              ROTATE THE KNIFE                THIS IS A PEN
# 85    MOVE THE KNIFE TO THE LEFT                 IS IS A FORK
# 86   MOVE THE KNIFE TO THE RIGHT     MOVE THE PAN TO THE LEFT
# 87             MOVE THE KNIFE AP              THIS IS A KNIFE
# 88           MOVE THE KNIFE DOWN                THIS IS A PEN
# 89              ROTADE THE KNIFE            MOVE THE PEN DOWN
# 90   MOVED THE KNIFE TO THE LEFT              THIS IS A KNIFE
# 91   MOVE THE KNIFE TO THE RIGHT              THIS IS A KNIFE
# 92             MOVE THE KNIFE UP                THIS IS A PEN
# 93           MOVE THE KNIFE DOWN                THIS IS A PEN
# 94              ROTATE THE KNIFE              THIS IS A KNIFE
# 95    MOVE THE KNIFE TO THE LEFT              THIS IS A KNIFE
# 96   MOVE THE KNIFE TO THE RIGHT              THIS IS A KNIFE
# 97             MOVE THE KNIFE UP                THIS IS A PEN
# 98           MOVE THE KNIFE DOWN              THIS IS A KNIFE
# 99              ROTATE THE KNIFE              THIS IS A KNIFE

# %% [markdown]
# # MODEL TRAINED WITHOUT MOVE PEN: TEST ON MOVE FORK

# %%
# lstm model - CHOLLET - TEST NEW ENCODER
predicted_features = pd.DataFrame(load('predictions/PREDICTED_MODEL_CHOLLET_06_movefork_0-100.npy', allow_pickle=True))
original_features = pd.DataFrame(load('features/audio_features_move_fork.npy', allow_pickle=True))

out = []
for i in range(predicted_features.shape[0]):
#for i in range(100):
    #print(i, "-",tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], "\t-\t", tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0])
    new_row=[tokenizer.batch_decode(torch.tensor([original_features.iloc[i]]))[0], tokenizer.batch_decode(torch.tensor([predicted_features.iloc[i]]))[0]]
    out.append(new_row)
    
pd.set_option('display.max_rows', None)

# %%
pd.DataFrame(out)
# Out:
#                               0                            1
# 0     MOVE THE FORK TO THE LEFT               THIS IS A FORK
# 1    MOVE THE FORK TO THE RIGHT               THIS IS A FORK
# 2              MOVE THE FORECUP                THIS IS A FOR
# 3            MOVE THE FORK DOWN               THIS IS A FORK
# 4               ROTATE THE FORK              THIS IS A PHONE
# 5     MOVE THE FORK TO THE LEFT               THIS IS A FORK
# 6    MOVE THE FORK TO THE RIGHT               THIS IS A FORK
# 7               MOE THE FORECOP                THIS IS A PEN
# 8          MOOTHE THE FORK DOWN               THIS IS A FORK
# 9                 ROTE THE FORK              THIS IS A FFORK
# 10    MOVE THE FORK TO THE LEFT               THIS IS A FORK
# 11   MOVE THE FORK TO THE RIGHT               THIS IS A FORK
# 12             MOVE THE FORECUP               THIS IS A FORK
# 13            MOVE THE ORT DOWN               THIS IS A FORK
# 14              ROTATE THE FORK               THIS IS A FORK
# 15    MOVE THE FORK TO THE LEFT                THIS IS A FOR
# 16  MOVES THE FORK TO THE RIGHT               THIS IS A FORK
# 17            MOVES THE FORECOP                THIS IS A FOR
# 18          MOVES THE FORK DOWN                THIS IS A FOR
# 19              ROTADE THE FORK               THIS IS A FORK
# 20    LOVE THE FORK TO THE LEFT               THIS IS A FORK
# 21   MOVE THE FORK TO THE RIGHT             OVE THE KNIFE UP
# 22               OO THE FORECUP               THIS IS A FORK
# 23           MOVE THE FORK DOWN               THIS IS A FORK
# 24            ROU TAKE THE FORK     OVES THE PEN TO THE RATE
# 25    MOVE THE FORK TO THE LEFT               THIS IS A FORK
# 26   MOVE THE FORK TO THE RIGHT               THIS IS A FORK
# 27               MOVE THE FORCA               THIS IS A FORK
# 28           MOVE THE FORK DOWN               THIS IS A FORK
# 29              ROTATE THE FORK               THIS IS A FORK
# 30    MOVE THE FORK TO THE LEFT               THIS IS A FORK
# 31   MOVE THE FORK TO THE RIGHT               THIS IS A FORK
# 32             MOVE THE FORE UP               THIS IS A FORK
# 33           MOVE THE FORK DOWN               THIS IS A FORK
# 34              ROTATE THE FORK               THIS IS A FORK
# 35   MOVED THE FORK TO THE LEFT               THIS IS A FORK
# 36   MOVE THE FORK TO THE RIGHT               THIS IS A FORK
# 37            MOVED THE FORECUP               THIS IS A FORK
# 38           MOVE THE FORK DOWN               THIS IS A FORK
# 39              ROTADE THE FORK               THIS IS A FORK
# 40    MOVE THE FORK TO THE LEFT               OV THE FOE NOW
# 41   MOVE THE FORK TO THE RIGHT               THIS IS A FORK
# 42             MOVE THE FORECUP              THIS IS A KNIFE
# 43           MOVE THE FORK DOWN                THIS IS A FOR
# 44            ROAD TATE THE FOR                THIS IS A FOR
# 45    MOVE THE FORK TO THE LEFT              THIS IS A KNIFE
# 46   MOVE THE FORK TO THE RIGHT              THIS IS A PHONE
# 47             MOVE THE FORECUP               THIS IS A FORK
# 48           MOVE THE FORK DOWN               THIS IS A FORK
# 49              ROTATE THE FORK               THIS IS A FORK
# 50    MOVE THE FORK TO THE LEFT                THIS IS A PEN
# 51   MOVE THE FORK TO THE RIGHT               THIS IS A FORK
# 52             MOVE THE FORECUP               THIS IS A FORK
# 53           MOVE THE FORK DOWN                THIS IS A FOR
# 54              ROTATE THE FORK               THIS IS A FORK
# 55    MOVE THE FORK TO THE LEFT     OVED THE PAN TO THE LEFT
# 56   MOVE THE FORK TO THE RIGHT                THIS IS A PEN
# 57              MOE THE FORECOP                THIS IS A FOR
# 58         MOOTHE THE FORK DOWN               THIS IS A FORK
# 59                ROTE THE FORK               THIS IS A FORK
# 60    MOVE THE FORK TO THE LEFT          MOVE THE KNIFE DOWN
# 61   MOVE THE FORK TO THE RIGHT               THIS IS A FORK
# 62             MOVE THE FORECUP               THIS IS A FORK
# 63            MOVE THE ORT DOWN               THIS IS A FORK
# 64              ROTATE THE FORK               THIS IS A FORK
# 65    MOVE THE FORK TO THE LEFT     MOVES A PEN TO THE RIGHT
# 66  MOVES THE FORK TO THE RIGHT          MOVE THE PHONE DOWN
# 67            MOVES THE FORECOP               THIS IS A FORK
# 68          MOVES THE FORK DOWN               THIS IS A FORK
# 69              ROTADE THE FORK               THIS IS A FORK
# 70    LOVE THE FORK TO THE LEFT             OVE THE KNIFE UP
# 71   MOVE THE FORK TO THE RIGHT    MOVE THE PEN TO THE RIGHT
# 72               OO THE FORECUP    OVH THE KNIFE TO THE LEFT
# 73           MOVE THE FORK DOWN              THIS IS A KNIFE
# 74            ROU TAKE THE FORK    MOVE THE PEN TO THE RIGHT
# 75    MOVE THE FORK TO THE LEFT              THIS IS A KNIFE
# 76   MOVE THE FORK TO THE RIGHT              THIS IS A KNIFE
# 77               MOVE THE FORCA               THIS IS A FORK
# 78           MOVE THE FORK DOWN               THIS IS A FORK
# 79              ROTATE THE FORK               THIS IS A FORK
# 80    MOVE THE FORK TO THE LEFT               THIS IS A FORK
# 81   MOVE THE FORK TO THE RIGHT              THIS IS A PHONE
# 82             MOVE THE FORE UP               THIS IS A FORK
# 83           MOVE THE FORK DOWN               THIS IS A FORK
# 84              ROTATE THE FORK               THIS IS A FORK
# 85   MOVED THE FORK TO THE LEFT              THIS IS A KNIFE
# 86   MOVE THE FORK TO THE RIGHT  OVES THE KNIFE TO THE RIGHT
# 87            MOVED THE FORECUP              THIS IS A KNIFE
# 88           MOVE THE FORK DOWN               THIS IS A FORK
# 89              ROTADE THE FORK               THIS IS A FORK
# 90    MOVE THE FORK TO THE LEFT              THIS IS A KNIFE
# 91   MOVE THE FORK TO THE RIGHT               THIS IS A FORK
# 92             MOVE THE FORECUP                THIS IS A FOR
# 93           MOVE THE FORK DOWN               THIS IS A FORK
# 94            ROAD TATE THE FOR                THIS IS A FOR
# 95    MOVE THE FORK TO THE LEFT               THIS IS A FORK
# 96   MOVE THE FORK TO THE RIGHT               THIS IS A FORK
# 97             MOVE THE FORECUP               THIS IS A FORK
# 98           MOVE THE FORK DOWN      OVE THE PEN TO THE RATE
# 99              ROTATE THE FORK                THIS IS A PEN
